# %%
# !pip install numpy==1.16.1
# !pip install tensorflow-gpu==2.0.0-beta1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
from sklearn.model_selection import TimeSeriesSplit
from sklearn.utils import class_weight
from sklearn.metrics import f1_score, confusion_matrix, classification_report, accuracy_score, precision_score, recall_score
import time

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, AveragePooling2D, BatchNormalization, LeakyReLU
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam, Nadam, SGD, RMSprop
from tensorflow.keras.callbacks import EarlyStopping

LR = LeakyReLU(alpha = .3)
LR.__name__ = 'leakyrelu'

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Requirement already satisfied: numpy==1.16.1 in /usr/local/lib/python3.6/dist-packages (1.16.1)
# Requirement already satisfied: tensorflow-gpu==2.0.0-beta1 in /usr/local/lib/python3.6/dist-packages (2.0.0b1)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.8.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (3.7.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.15.0)
# Requirement already satisfied: tf-estimator-nightly<1.14.0.dev2019060502,>=1.14.0.dev2019060501 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.14.0.dev2019060501)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.11.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.1.7)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.33.4)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.2.2)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.16.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.7.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.12.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: tb-nightly<1.14.0a20190604,>=1.14.0a20190603 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.14.0a20190603)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==2.0.0-beta1) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==2.0.0-beta1) (41.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (0.15.5)
# Found GPU at: /device:GPU:0

# %%
# fix random seed for reproducibility
seed = 2
np.random.seed(seed)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Pre-Settings

# %%
Test = "test3"
Version = "_indiv_" #="univ"
VarName = "GSPC"

if Test == "test1":
  tr_direct = "data_train_to2005"
  ts_direct = "data_test_2005Decto_2007Dec"
elif Test == "test2":
  tr_direct = "data_train_to2008"
  ts_direct = "data_test_2009Jan_to_2011Jan"
else:
  tr_direct = "data_train_to2017May"
  ts_direct = "data_test_2017May_to_2019last"

# %% [markdown]
# # Load data

# %%
if Version == "_indiv_":
  train_filename = "LW5_IW30/" + tr_direct + "/" + Version[1:] + "train" + Test[-1] + "_" + VarName + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"
else:
  train_filename = "LW5_IW30/" + tr_direct + "/" + Version[1:] + "train" + Test[-1] + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"
  
test_filename = "LW5_IW30/" + ts_direct + "/" + Test + "_" + VarName + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"

# %% [markdown]
# ### Image window sizes

# %%
Image_window_size = np.int(train_filename[train_filename.find('_IWS') + 4 : train_filename.find("_Trf")])
Image_window_size
# Out:
# 30

# %% [markdown]
# ### Transformation types

# %%
Image_trf = eval(train_filename[train_filename.find('_Trf')+4:train_filename.find('.npz')])
Image_trf
# Out:
# ['RP', 'GASF', 'MTF']

# %%
num_color_channels = len(Image_trf)
num_color_channels
# Out:
# 3

# %% [markdown]
# #### In case file is missing run the data-check-and-prep with preferred settings and use the new file's name (cannot upload too big files to Git)

# %%
data_train = np.load('/content/drive/My Drive/Colab Notebooks/CNN/' + train_filename)
data_test = np.load('/content/drive/My Drive/Colab Notebooks/CNN/' + test_filename)

# %%
images_train = data_train['images']
images_test = data_test['images']
image_labels_train = data_train['image_labels']
image_labels_test = data_test['image_labels']
train_prices = data_train['price_at_image']
test_prices = data_test['price_at_image']

label_names = data_train['label_names'] # same everywhere

# %% [markdown]
# # Check data

# %%
image_labels_train.shape
# Out:
# (17555, 3)

# %% [markdown]
# Get label names array for later visualization

# %%
label_names = label_names.item()
label_names
# Out:
# {0: 'Sell', 1: 'Buy', 2: 'Hold'}

# %%
label_names_array = np.chararray(3, itemsize = 4).decode("utf-8")

for key, value in label_names.items():
  label_names_array[key] = value
label_names_array
# Out:
# array(['Sell', 'Buy', 'Hold'], dtype='<U4')

# %% [markdown]
# ## e.g.:

# %%
for trfidx, trf in enumerate(Image_trf):
    print('Transformation type: ' + trf)
    for idx, image in enumerate(images_train[:2,:,:, trfidx]):
        plt.imshow(image, cmap = "Greys")
        plt.title(label_names[np.int(np.argwhere(image_labels_train[idx]))])
        plt.show()
# Out:
# Transformation type: RP
# Transformation type: GASF
# Transformation type: MTF

# %%
print("Train images shape : {}; Train labels shape : {}".format(images_train.shape, image_labels_train.shape))
# Out:
# Train images shape : (17555, 30, 30, 3); Train labels shape : (17555, 3)

# %%
print("Test images shape : {}; Test labels shape : {}".format(images_test.shape, image_labels_test.shape))
# Out:
# Test images shape : (525, 30, 30, 3); Test labels shape : (525, 3)

# %% [markdown]
# # Baseline predictions
# Choosing the biggest class to be the class of all

# %%
basepred = np.zeros(image_labels_test.shape)
basepred[:, np.argmax(np.sum(image_labels_test, 0))] = 1.0

base_acc = sum(np.equal(np.argmax(basepred, 1), np.argmax(image_labels_test, 1)))/np.sum(image_labels_test)
base_f1 = f1_score(y_true = image_labels_test, y_pred = basepred, average = 'macro')
# warning F1 due to only label 2 being predicted in baseline

print("Accuracy: {:.5f}".format(base_acc))
print("Categorical Accuracy: {:.5f}".format(accuracy_score(np.argmax(basepred, 1), np.argmax(image_labels_test, 1))))

print("F1 score: {:.5f}".format(base_f1))

print(classification_report(np.argmax(basepred, 1), np.argmax(image_labels_test, 1)))
# Out:
# Accuracy: 0.71619
# Categorical Accuracy: 0.71619
# F1 score: 0.27821
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         0
#            2       1.00      0.72      0.83       525
#
#     accuracy                           0.72       525
#    macro avg       0.33      0.24      0.28       525
# weighted avg       1.00      0.72      0.83       525
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %% [markdown]
# # The Deep CNN

# %% [markdown]
# ### Custom Keras Eval metrics: F1 Score
# https://medium.com/@thongonary/how-to-compute-f1-score-for-each-epoch-in-keras-a1acd17715a2

# %%
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import fbeta_score

# Some default constants

START = 0.5
END = 0.95
STEP = 0.05
N_STEPS = int((END - START) / STEP) + 2
DEFAULT_THRESHOLDS = np.linspace(START, END, N_STEPS)
DEFAULT_BETA = 1
DEFAULT_LOGS = {}
FBETA_METRIC_NAME = "val_fbeta"

class FBetaMetricCallback(Callback):

    def __init__(self, beta=DEFAULT_BETA, thresholds=DEFAULT_THRESHOLDS):
        self.beta = beta
        self.thresholds = thresholds
        # Will be initialized when the training starts
        self.val_fbeta = None

    def on_train_begin(self, logs=DEFAULT_LOGS):
        """ This is where the validation Fbeta
        validation scores will be saved during training: one value per
        epoch.
        """
        self.val_fbeta = []

    def _score_per_threshold(self, predictions, targets, threshold):
        """ Compute the Fbeta score per threshold.
        """
        # Notice that here I am using the sklearn fbeta_score function.
        # You can read more about it here:
        # http://scikit-learn.org/stable/modules/generated/sklearn.metrics.fbeta_score.html
        thresholded_predictions = (predictions > threshold).astype(int)
        return fbeta_score(targets, thresholded_predictions, beta=self.beta)

    def on_epoch_end(self, epoch, logs=DEFAULT_LOGS):
        val_predictions = self.model.predict(self.validation_data[0])
        val_targets = self.validation_data[1]
        _val_fbeta = np.mean([self._score_per_threshold(val_predictions,
                                                        val_targets, threshold)
                              for threshold in self.thresholds])
        self.val_fbeta.append(_val_fbeta)
        print("Current F{} metric is: {}".format(str(self.beta), str(_val_fbeta)))
        return

    def on_train_end(self, logs=DEFAULT_LOGS):
        """ Assign the validation Fbeta computed metric to the History object.
        """
        self.model.history.history[FBETA_METRIC_NAME] = self.val_fbeta
        
f1_score = FBetaMetricCallback(beta=1)

# %% [markdown]
# ### Custom Time Logging

# %%
import tensorflow.keras.callbacks as keras_cb

class TimeHistory(keras_cb.Callback):
  def on_train_begin(self, logs={}):
    self.times = []

  def on_epoch_begin(self, epoch, logs={}):
    self.epoch_time_start = time.time()

  def on_epoch_end(self, epoch, logs={}):
    self.times.append(time.time() - self.epoch_time_start)

time_callback = TimeHistory()

# %% [markdown]
# ### Network Parameters

# %%
# image shape (d x d)
n_input = images_train.shape[1]
inputShape = (n_input, n_input, num_color_channels)

# number of classes
n_classes =  image_labels_train.shape[1]

# dropout
to_drop = 0.3 # prob. to DROP

# %% [markdown]
# ## Building the model

# %%
def createModel(input_shape, dropout = .2):
    model = Sequential()
    # Input
    model.add(Conv2D(32, 
                     (3, 3), 
                     padding='same', 
                     activation=LR, 
                     input_shape=input_shape
                    ))
    model.add(BatchNormalization())
    # model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))
    
    # 1Convolution,relu then pooling
    model.add(Conv2D(64, (3, 3), 
                     padding='same', 
                     activation=LR,
                     kernel_regularizer=regularizers.l2(0.01)
                    ))
    model.add(BatchNormalization())
    model.add(AveragePooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))
    
    # Flatten & Dense layers 
    model.add(Flatten())
    
    model.add(Dense(128, activation=LR, kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(Dropout(.5))
    model.add(Dense(n_classes, activation='softmax'))
  
    return model

# %%
model1 = createModel(dropout = to_drop, input_shape = inputShape)
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 30, 30, 32)        128
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 64)        256
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 15, 15, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 15, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 14400)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1843328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 1,864,003
# Trainable params: 1,863,555
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# ## Hyperparameter settings

# %%
training_iters = 450
batch_size = 512

# %% [markdown]
# ### Accounting for imbalance

# %%
label_names
# Out:
# {0: 'Sell', 1: 'Buy', 2: 'Hold'}

# %%
np.sum(image_labels_train, axis = 0)/np.sum(image_labels_train)
# Out:
# array([0.13454856, 0.13688408, 0.72856736])

# %%
y_ints = [y.argmax() for y in image_labels_train]
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_ints),
                                                 y_ints)
class_weight_dict = dict(enumerate(class_weights))
class_weight_dict
# Out:
# {0: 2.4774202653118826, 1: 2.435150506311555, 2: 0.4575188949700287}

# %% [markdown]
# ## Compiling

# %%
model1.compile(optimizer=SGD(nesterov=True),#Adam(lr=0.0001, amsgrad = True), #Nadam(lr=0.0005), #
               loss='kullback_leibler_divergence', 
               metrics=['categorical_accuracy'])

# %% [markdown]
# ## Training

# %%
es2 = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
history = model1.fit(images_train, 
                     image_labels_train, 
                     batch_size=batch_size, 
                     epochs=training_iters, verbose=1,
                     validation_data=(images_test, image_labels_test),
                     class_weight=class_weight_dict,
                     callbacks=[time_callback, es2]
                    )
  
model1.evaluate(images_test, image_labels_test)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0728 17:01:56.074704 140510766282624 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 17555 samples, validate on 525 samples
# Epoch 1/450
# 17555/17555 [==============================] - 9s 535us/sample - loss: 4.7281 - categorical_accuracy: 0.3354 - val_loss: 4.0140 - val_categorical_accuracy: 0.3105
# Epoch 2/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 4.4632 - categorical_accuracy: 0.3384 - val_loss: 4.0878 - val_categorical_accuracy: 0.1410
# Epoch 3/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 4.2785 - categorical_accuracy: 0.3453 - val_loss: 4.0479 - val_categorical_accuracy: 0.1333
# Epoch 4/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 4.1757 - categorical_accuracy: 0.3512 - val_loss: 4.0156 - val_categorical_accuracy: 0.1390
# Epoch 5/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 4.0626 - categorical_accuracy: 0.3623 - val_loss: 3.9536 - val_categorical_accuracy: 0.1448
# Epoch 6/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 3.9902 - categorical_accuracy: 0.3622 - val_loss: 3.9132 - val_categorical_accuracy: 0.1714
# Epoch 7/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 3.9121 - categorical_accuracy: 0.3649 - val_loss: 3.8491 - val_categorical_accuracy: 0.1829
# Epoch 8/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 3.8331 - categorical_accuracy: 0.3704 - val_loss: 3.8049 - val_categorical_accuracy: 0.2038
# Epoch 9/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 3.7772 - categorical_accuracy: 0.3706 - val_loss: 3.7604 - val_categorical_accuracy: 0.2286
# Epoch 10/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 3.7154 - categorical_accuracy: 0.3768 - val_loss: 3.7099 - val_categorical_accuracy: 0.2305
# Epoch 11/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 3.6755 - categorical_accuracy: 0.3727 - val_loss: 3.6580 - val_categorical_accuracy: 0.2914
# Epoch 12/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 3.6292 - categorical_accuracy: 0.3728 - val_loss: 3.6029 - val_categorical_accuracy: 0.3543
# Epoch 13/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 3.5836 - categorical_accuracy: 0.3719 - val_loss: 3.5640 - val_categorical_accuracy: 0.3467
# Epoch 14/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 3.5399 - categorical_accuracy: 0.3819 - val_loss: 3.5210 - val_categorical_accuracy: 0.3524
# Epoch 15/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 3.5025 - categorical_accuracy: 0.3750 - val_loss: 3.4789 - val_categorical_accuracy: 0.3752
# Epoch 16/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 3.4608 - categorical_accuracy: 0.3814 - val_loss: 3.4492 - val_categorical_accuracy: 0.3505
# Epoch 17/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 3.4222 - categorical_accuracy: 0.3786 - val_loss: 3.4170 - val_categorical_accuracy: 0.3562
# Epoch 18/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 3.3863 - categorical_accuracy: 0.3741 - val_loss: 3.3781 - val_categorical_accuracy: 0.3810
# Epoch 19/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 3.3512 - categorical_accuracy: 0.3825 - val_loss: 3.3496 - val_categorical_accuracy: 0.3448
# Epoch 20/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 3.3170 - categorical_accuracy: 0.3721 - val_loss: 3.3200 - val_categorical_accuracy: 0.3486
# Epoch 21/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 3.2888 - categorical_accuracy: 0.3721 - val_loss: 3.2838 - val_categorical_accuracy: 0.3581
# Epoch 22/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 3.2489 - categorical_accuracy: 0.3850 - val_loss: 3.2497 - val_categorical_accuracy: 0.3657
# Epoch 23/450
# 17555/17555 [==============================] - 3s 188us/sample - loss: 3.2206 - categorical_accuracy: 0.3810 - val_loss: 3.2196 - val_categorical_accuracy: 0.3714
# Epoch 24/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 3.1817 - categorical_accuracy: 0.3908 - val_loss: 3.1943 - val_categorical_accuracy: 0.3733
# Epoch 25/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 3.1510 - categorical_accuracy: 0.3833 - val_loss: 3.1597 - val_categorical_accuracy: 0.3695
# Epoch 26/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 3.1242 - categorical_accuracy: 0.3836 - val_loss: 3.1342 - val_categorical_accuracy: 0.3486
# Epoch 27/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 3.0924 - categorical_accuracy: 0.3846 - val_loss: 3.1036 - val_categorical_accuracy: 0.3638
# Epoch 28/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 3.0617 - categorical_accuracy: 0.3867 - val_loss: 3.0771 - val_categorical_accuracy: 0.3600
# Epoch 29/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 3.0348 - categorical_accuracy: 0.3876 - val_loss: 3.0435 - val_categorical_accuracy: 0.3848
# Epoch 30/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 3.0039 - categorical_accuracy: 0.3954 - val_loss: 3.0144 - val_categorical_accuracy: 0.3771
# Epoch 31/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.9716 - categorical_accuracy: 0.3954 - val_loss: 2.9858 - val_categorical_accuracy: 0.3676
# Epoch 32/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.9457 - categorical_accuracy: 0.3882 - val_loss: 2.9598 - val_categorical_accuracy: 0.3733
# Epoch 33/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 2.9184 - categorical_accuracy: 0.3944 - val_loss: 2.9336 - val_categorical_accuracy: 0.3638
# Epoch 34/450
# 17555/17555 [==============================] - 3s 192us/sample - loss: 2.8896 - categorical_accuracy: 0.3965 - val_loss: 2.9125 - val_categorical_accuracy: 0.3600
# Epoch 35/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.8618 - categorical_accuracy: 0.3976 - val_loss: 2.8894 - val_categorical_accuracy: 0.3619
# Epoch 36/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.8353 - categorical_accuracy: 0.4004 - val_loss: 2.8596 - val_categorical_accuracy: 0.3638
# Epoch 37/450
# 17555/17555 [==============================] - 3s 185us/sample - loss: 2.7992 - categorical_accuracy: 0.4093 - val_loss: 2.8421 - val_categorical_accuracy: 0.3524
# Epoch 38/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.7783 - categorical_accuracy: 0.4085 - val_loss: 2.8157 - val_categorical_accuracy: 0.3562
# Epoch 39/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.7536 - categorical_accuracy: 0.4051 - val_loss: 2.7923 - val_categorical_accuracy: 0.3543
# Epoch 40/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 2.7243 - categorical_accuracy: 0.4063 - val_loss: 2.7607 - val_categorical_accuracy: 0.3581
# Epoch 41/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.7012 - categorical_accuracy: 0.4073 - val_loss: 2.7413 - val_categorical_accuracy: 0.3638
# Epoch 42/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.6765 - categorical_accuracy: 0.4100 - val_loss: 2.7201 - val_categorical_accuracy: 0.3638
# Epoch 43/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 2.6570 - categorical_accuracy: 0.4137 - val_loss: 2.6982 - val_categorical_accuracy: 0.3638
# Epoch 44/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 2.6290 - categorical_accuracy: 0.4175 - val_loss: 2.6774 - val_categorical_accuracy: 0.3657
# Epoch 45/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 2.6004 - categorical_accuracy: 0.4248 - val_loss: 2.6552 - val_categorical_accuracy: 0.3752
# Epoch 46/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 2.5752 - categorical_accuracy: 0.4226 - val_loss: 2.6366 - val_categorical_accuracy: 0.3714
# Epoch 47/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.5485 - categorical_accuracy: 0.4244 - val_loss: 2.6137 - val_categorical_accuracy: 0.3714
# Epoch 48/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 2.5316 - categorical_accuracy: 0.4249 - val_loss: 2.5931 - val_categorical_accuracy: 0.3638
# Epoch 49/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 2.5012 - categorical_accuracy: 0.4285 - val_loss: 2.5633 - val_categorical_accuracy: 0.3810
# Epoch 50/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 2.4799 - categorical_accuracy: 0.4292 - val_loss: 2.5465 - val_categorical_accuracy: 0.3829
# Epoch 51/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.4580 - categorical_accuracy: 0.4284 - val_loss: 2.5244 - val_categorical_accuracy: 0.3848
# Epoch 52/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 2.4350 - categorical_accuracy: 0.4343 - val_loss: 2.5090 - val_categorical_accuracy: 0.3657
# Epoch 53/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.4215 - categorical_accuracy: 0.4286 - val_loss: 2.4871 - val_categorical_accuracy: 0.3695
# Epoch 54/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 2.3939 - categorical_accuracy: 0.4275 - val_loss: 2.4652 - val_categorical_accuracy: 0.3714
# Epoch 55/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 2.3659 - categorical_accuracy: 0.4366 - val_loss: 2.4463 - val_categorical_accuracy: 0.3562
# Epoch 56/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.3520 - categorical_accuracy: 0.4363 - val_loss: 2.4285 - val_categorical_accuracy: 0.3771
# Epoch 57/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.3281 - categorical_accuracy: 0.4411 - val_loss: 2.4023 - val_categorical_accuracy: 0.3771
# Epoch 58/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.3099 - categorical_accuracy: 0.4434 - val_loss: 2.3837 - val_categorical_accuracy: 0.3943
# Epoch 59/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.2861 - categorical_accuracy: 0.4455 - val_loss: 2.3799 - val_categorical_accuracy: 0.3790
# Epoch 60/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.2699 - categorical_accuracy: 0.4396 - val_loss: 2.3602 - val_categorical_accuracy: 0.3638
# Epoch 61/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 2.2436 - categorical_accuracy: 0.4474 - val_loss: 2.3357 - val_categorical_accuracy: 0.3790
# Epoch 62/450
# 17555/17555 [==============================] - 3s 192us/sample - loss: 2.2268 - categorical_accuracy: 0.4481 - val_loss: 2.3151 - val_categorical_accuracy: 0.3733
# Epoch 63/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 2.2075 - categorical_accuracy: 0.4510 - val_loss: 2.3042 - val_categorical_accuracy: 0.3790
# Epoch 64/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 2.1770 - categorical_accuracy: 0.4586 - val_loss: 2.2851 - val_categorical_accuracy: 0.3810
# Epoch 65/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 2.1651 - categorical_accuracy: 0.4554 - val_loss: 2.2669 - val_categorical_accuracy: 0.3848
# Epoch 66/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 2.1396 - categorical_accuracy: 0.4579 - val_loss: 2.2560 - val_categorical_accuracy: 0.3943
# Epoch 67/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.1201 - categorical_accuracy: 0.4628 - val_loss: 2.2436 - val_categorical_accuracy: 0.3962
# Epoch 68/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 2.1007 - categorical_accuracy: 0.4672 - val_loss: 2.2164 - val_categorical_accuracy: 0.3829
# Epoch 69/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 2.0872 - categorical_accuracy: 0.4644 - val_loss: 2.1929 - val_categorical_accuracy: 0.4057
# Epoch 70/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 2.0697 - categorical_accuracy: 0.4669 - val_loss: 2.1794 - val_categorical_accuracy: 0.3886
# Epoch 71/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.0520 - categorical_accuracy: 0.4658 - val_loss: 2.1672 - val_categorical_accuracy: 0.3829
# Epoch 72/450
# 17555/17555 [==============================] - 3s 184us/sample - loss: 2.0312 - categorical_accuracy: 0.4721 - val_loss: 2.1673 - val_categorical_accuracy: 0.3790
# Epoch 73/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 2.0086 - categorical_accuracy: 0.4760 - val_loss: 2.1577 - val_categorical_accuracy: 0.3581
# Epoch 74/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.9959 - categorical_accuracy: 0.4757 - val_loss: 2.1289 - val_categorical_accuracy: 0.3829
# Epoch 75/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.9778 - categorical_accuracy: 0.4692 - val_loss: 2.1246 - val_categorical_accuracy: 0.3638
# Epoch 76/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.9670 - categorical_accuracy: 0.4681 - val_loss: 2.1193 - val_categorical_accuracy: 0.3581
# Epoch 77/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.9506 - categorical_accuracy: 0.4779 - val_loss: 2.0935 - val_categorical_accuracy: 0.3829
# Epoch 78/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.9203 - categorical_accuracy: 0.4804 - val_loss: 2.0793 - val_categorical_accuracy: 0.3905
# Epoch 79/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.9063 - categorical_accuracy: 0.4801 - val_loss: 2.0700 - val_categorical_accuracy: 0.3733
# Epoch 80/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.8994 - categorical_accuracy: 0.4829 - val_loss: 2.0415 - val_categorical_accuracy: 0.3981
# Epoch 81/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.8829 - categorical_accuracy: 0.4859 - val_loss: 2.0445 - val_categorical_accuracy: 0.3867
# Epoch 82/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.8599 - categorical_accuracy: 0.4877 - val_loss: 2.0178 - val_categorical_accuracy: 0.4095
# Epoch 83/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.8504 - categorical_accuracy: 0.4872 - val_loss: 2.0071 - val_categorical_accuracy: 0.3943
# Epoch 84/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.8347 - categorical_accuracy: 0.4877 - val_loss: 1.9937 - val_categorical_accuracy: 0.4076
# Epoch 85/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.8094 - categorical_accuracy: 0.4941 - val_loss: 1.9646 - val_categorical_accuracy: 0.4267
# Epoch 86/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.7942 - categorical_accuracy: 0.4952 - val_loss: 1.9619 - val_categorical_accuracy: 0.3924
# Epoch 87/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.7870 - categorical_accuracy: 0.4961 - val_loss: 1.9830 - val_categorical_accuracy: 0.3810
# Epoch 88/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.7686 - categorical_accuracy: 0.4993 - val_loss: 1.9483 - val_categorical_accuracy: 0.3924
# Epoch 89/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.7573 - categorical_accuracy: 0.5037 - val_loss: 1.9355 - val_categorical_accuracy: 0.4057
# Epoch 90/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.7416 - categorical_accuracy: 0.5005 - val_loss: 1.9209 - val_categorical_accuracy: 0.4210
# Epoch 91/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.7176 - categorical_accuracy: 0.5114 - val_loss: 1.9221 - val_categorical_accuracy: 0.4152
# Epoch 92/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.7039 - categorical_accuracy: 0.5093 - val_loss: 1.8997 - val_categorical_accuracy: 0.4057
# Epoch 93/450
# 17555/17555 [==============================] - 3s 188us/sample - loss: 1.6908 - categorical_accuracy: 0.5152 - val_loss: 1.8663 - val_categorical_accuracy: 0.4362
# Epoch 94/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.6777 - categorical_accuracy: 0.5138 - val_loss: 1.8712 - val_categorical_accuracy: 0.4133
# Epoch 95/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.6559 - categorical_accuracy: 0.5177 - val_loss: 1.8439 - val_categorical_accuracy: 0.4286
# Epoch 96/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.6474 - categorical_accuracy: 0.5150 - val_loss: 1.8466 - val_categorical_accuracy: 0.4076
# Epoch 97/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.6434 - categorical_accuracy: 0.5135 - val_loss: 1.8431 - val_categorical_accuracy: 0.4114
# Epoch 98/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.6235 - categorical_accuracy: 0.5194 - val_loss: 1.8475 - val_categorical_accuracy: 0.4171
# Epoch 99/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.5966 - categorical_accuracy: 0.5270 - val_loss: 1.8552 - val_categorical_accuracy: 0.3886
# Epoch 100/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.5959 - categorical_accuracy: 0.5242 - val_loss: 1.8115 - val_categorical_accuracy: 0.4114
# Epoch 101/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.5832 - categorical_accuracy: 0.5244 - val_loss: 1.8297 - val_categorical_accuracy: 0.3924
# Epoch 102/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.5599 - categorical_accuracy: 0.5345 - val_loss: 1.7650 - val_categorical_accuracy: 0.4152
# Epoch 103/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.5438 - categorical_accuracy: 0.5379 - val_loss: 1.7551 - val_categorical_accuracy: 0.4400
# Epoch 104/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.5346 - categorical_accuracy: 0.5330 - val_loss: 1.7806 - val_categorical_accuracy: 0.4133
# Epoch 105/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.5181 - categorical_accuracy: 0.5422 - val_loss: 1.7499 - val_categorical_accuracy: 0.4267
# Epoch 106/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.5070 - categorical_accuracy: 0.5433 - val_loss: 1.7605 - val_categorical_accuracy: 0.4114
# Epoch 107/450
# 17555/17555 [==============================] - 3s 185us/sample - loss: 1.4930 - categorical_accuracy: 0.5411 - val_loss: 1.7449 - val_categorical_accuracy: 0.4171
# Epoch 108/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.4815 - categorical_accuracy: 0.5461 - val_loss: 1.7011 - val_categorical_accuracy: 0.4571
# Epoch 109/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.4716 - categorical_accuracy: 0.5454 - val_loss: 1.7016 - val_categorical_accuracy: 0.4267
# Epoch 110/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.4656 - categorical_accuracy: 0.5484 - val_loss: 1.7256 - val_categorical_accuracy: 0.4210
# Epoch 111/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.4486 - categorical_accuracy: 0.5508 - val_loss: 1.6922 - val_categorical_accuracy: 0.4229
# Epoch 112/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.4340 - categorical_accuracy: 0.5546 - val_loss: 1.7425 - val_categorical_accuracy: 0.3848
# Epoch 113/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.4241 - categorical_accuracy: 0.5523 - val_loss: 1.6962 - val_categorical_accuracy: 0.4076
# Epoch 114/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.4067 - categorical_accuracy: 0.5606 - val_loss: 1.6888 - val_categorical_accuracy: 0.4076
# Epoch 115/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.4017 - categorical_accuracy: 0.5592 - val_loss: 1.6778 - val_categorical_accuracy: 0.4171
# Epoch 116/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.3814 - categorical_accuracy: 0.5617 - val_loss: 1.6662 - val_categorical_accuracy: 0.4152
# Epoch 117/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.3753 - categorical_accuracy: 0.5647 - val_loss: 1.6540 - val_categorical_accuracy: 0.4324
# Epoch 118/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.3559 - categorical_accuracy: 0.5633 - val_loss: 1.6769 - val_categorical_accuracy: 0.4057
# Epoch 119/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.3452 - categorical_accuracy: 0.5724 - val_loss: 1.6570 - val_categorical_accuracy: 0.4229
# Epoch 120/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.3463 - categorical_accuracy: 0.5685 - val_loss: 1.6275 - val_categorical_accuracy: 0.4343
# Epoch 121/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.3299 - categorical_accuracy: 0.5802 - val_loss: 1.6056 - val_categorical_accuracy: 0.4419
# Epoch 122/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.3110 - categorical_accuracy: 0.5799 - val_loss: 1.6231 - val_categorical_accuracy: 0.4343
# Epoch 123/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.2962 - categorical_accuracy: 0.5859 - val_loss: 1.6369 - val_categorical_accuracy: 0.4343
# Epoch 124/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.2935 - categorical_accuracy: 0.5801 - val_loss: 1.5736 - val_categorical_accuracy: 0.4743
# Epoch 125/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.2753 - categorical_accuracy: 0.5909 - val_loss: 1.5919 - val_categorical_accuracy: 0.4438
# Epoch 126/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.2855 - categorical_accuracy: 0.5826 - val_loss: 1.6060 - val_categorical_accuracy: 0.4533
# Epoch 127/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.2524 - categorical_accuracy: 0.5883 - val_loss: 1.5947 - val_categorical_accuracy: 0.4324
# Epoch 128/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.2534 - categorical_accuracy: 0.5933 - val_loss: 1.5703 - val_categorical_accuracy: 0.4610
# Epoch 129/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.2333 - categorical_accuracy: 0.5977 - val_loss: 1.5642 - val_categorical_accuracy: 0.4495
# Epoch 130/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.2357 - categorical_accuracy: 0.5941 - val_loss: 1.5450 - val_categorical_accuracy: 0.4533
# Epoch 131/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.2215 - categorical_accuracy: 0.6018 - val_loss: 1.5539 - val_categorical_accuracy: 0.4362
# Epoch 132/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.2184 - categorical_accuracy: 0.5985 - val_loss: 1.5625 - val_categorical_accuracy: 0.4343
# Epoch 133/450
# 17555/17555 [==============================] - 3s 188us/sample - loss: 1.1994 - categorical_accuracy: 0.6084 - val_loss: 1.5639 - val_categorical_accuracy: 0.4305
# Epoch 134/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.1906 - categorical_accuracy: 0.6064 - val_loss: 1.5250 - val_categorical_accuracy: 0.4686
# Epoch 135/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.1873 - categorical_accuracy: 0.6076 - val_loss: 1.5484 - val_categorical_accuracy: 0.4362
# Epoch 136/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.1681 - categorical_accuracy: 0.6133 - val_loss: 1.5543 - val_categorical_accuracy: 0.4305
# Epoch 137/450
# 17555/17555 [==============================] - 3s 192us/sample - loss: 1.1598 - categorical_accuracy: 0.6130 - val_loss: 1.5456 - val_categorical_accuracy: 0.4381
# Epoch 138/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.1495 - categorical_accuracy: 0.6171 - val_loss: 1.4949 - val_categorical_accuracy: 0.4819
# Epoch 139/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.1369 - categorical_accuracy: 0.6220 - val_loss: 1.4823 - val_categorical_accuracy: 0.4800
# Epoch 140/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.1334 - categorical_accuracy: 0.6239 - val_loss: 1.4967 - val_categorical_accuracy: 0.4686
# Epoch 141/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.1200 - categorical_accuracy: 0.6208 - val_loss: 1.4609 - val_categorical_accuracy: 0.4800
# Epoch 142/450
# 17555/17555 [==============================] - 3s 186us/sample - loss: 1.1173 - categorical_accuracy: 0.6301 - val_loss: 1.4706 - val_categorical_accuracy: 0.4743
# Epoch 143/450
# 17555/17555 [==============================] - 3s 186us/sample - loss: 1.1012 - categorical_accuracy: 0.6304 - val_loss: 1.4452 - val_categorical_accuracy: 0.4914
# Epoch 144/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.0983 - categorical_accuracy: 0.6298 - val_loss: 1.4346 - val_categorical_accuracy: 0.4952
# Epoch 145/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.0801 - categorical_accuracy: 0.6370 - val_loss: 1.4442 - val_categorical_accuracy: 0.5105
# Epoch 146/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.0750 - categorical_accuracy: 0.6389 - val_loss: 1.4604 - val_categorical_accuracy: 0.4762
# Epoch 147/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.0684 - categorical_accuracy: 0.6403 - val_loss: 1.4451 - val_categorical_accuracy: 0.4971
# Epoch 148/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.0595 - categorical_accuracy: 0.6432 - val_loss: 1.4501 - val_categorical_accuracy: 0.4819
# Epoch 149/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.0529 - categorical_accuracy: 0.6447 - val_loss: 1.4131 - val_categorical_accuracy: 0.5143
# Epoch 150/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 1.0444 - categorical_accuracy: 0.6457 - val_loss: 1.4562 - val_categorical_accuracy: 0.4705
# Epoch 151/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.0330 - categorical_accuracy: 0.6565 - val_loss: 1.4315 - val_categorical_accuracy: 0.4781
# Epoch 152/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.0325 - categorical_accuracy: 0.6492 - val_loss: 1.4386 - val_categorical_accuracy: 0.4686
# Epoch 153/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 1.0131 - categorical_accuracy: 0.6563 - val_loss: 1.4590 - val_categorical_accuracy: 0.4571
# Epoch 154/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 1.0132 - categorical_accuracy: 0.6568 - val_loss: 1.4346 - val_categorical_accuracy: 0.4724
# Epoch 155/450
# 17555/17555 [==============================] - 3s 192us/sample - loss: 1.0074 - categorical_accuracy: 0.6583 - val_loss: 1.4504 - val_categorical_accuracy: 0.4667
# Epoch 156/450
# 17555/17555 [==============================] - 3s 192us/sample - loss: 1.0036 - categorical_accuracy: 0.6568 - val_loss: 1.4474 - val_categorical_accuracy: 0.5029
# Epoch 157/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.9866 - categorical_accuracy: 0.6653 - val_loss: 1.3830 - val_categorical_accuracy: 0.5257
# Epoch 158/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.9828 - categorical_accuracy: 0.6712 - val_loss: 1.4157 - val_categorical_accuracy: 0.4933
# Epoch 159/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.9669 - categorical_accuracy: 0.6742 - val_loss: 1.3924 - val_categorical_accuracy: 0.4762
# Epoch 160/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.9735 - categorical_accuracy: 0.6696 - val_loss: 1.3786 - val_categorical_accuracy: 0.5010
# Epoch 161/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.9489 - categorical_accuracy: 0.6750 - val_loss: 1.3892 - val_categorical_accuracy: 0.4914
# Epoch 162/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.9514 - categorical_accuracy: 0.6766 - val_loss: 1.3881 - val_categorical_accuracy: 0.4990
# Epoch 163/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.9495 - categorical_accuracy: 0.6780 - val_loss: 1.3926 - val_categorical_accuracy: 0.4933
# Epoch 164/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.9263 - categorical_accuracy: 0.6828 - val_loss: 1.3752 - val_categorical_accuracy: 0.4990
# Epoch 165/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.9388 - categorical_accuracy: 0.6804 - val_loss: 1.3778 - val_categorical_accuracy: 0.5048
# Epoch 166/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.9149 - categorical_accuracy: 0.6862 - val_loss: 1.3968 - val_categorical_accuracy: 0.4857
# Epoch 167/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.9067 - categorical_accuracy: 0.6931 - val_loss: 1.3698 - val_categorical_accuracy: 0.5048
# Epoch 168/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.9086 - categorical_accuracy: 0.6908 - val_loss: 1.3250 - val_categorical_accuracy: 0.5390
# Epoch 169/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.9001 - categorical_accuracy: 0.6926 - val_loss: 1.3232 - val_categorical_accuracy: 0.5562
# Epoch 170/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.8951 - categorical_accuracy: 0.6934 - val_loss: 1.3532 - val_categorical_accuracy: 0.5257
# Epoch 171/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.8887 - categorical_accuracy: 0.6981 - val_loss: 1.3347 - val_categorical_accuracy: 0.5371
# Epoch 172/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.8797 - categorical_accuracy: 0.7007 - val_loss: 1.3511 - val_categorical_accuracy: 0.5105
# Epoch 173/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.8805 - categorical_accuracy: 0.7003 - val_loss: 1.4098 - val_categorical_accuracy: 0.4914
# Epoch 174/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.8722 - categorical_accuracy: 0.6987 - val_loss: 1.3704 - val_categorical_accuracy: 0.4914
# Epoch 175/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.8548 - categorical_accuracy: 0.7030 - val_loss: 1.3352 - val_categorical_accuracy: 0.5143
# Epoch 176/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.8530 - categorical_accuracy: 0.7077 - val_loss: 1.3119 - val_categorical_accuracy: 0.5276
# Epoch 177/450
# 17555/17555 [==============================] - 3s 186us/sample - loss: 0.8616 - categorical_accuracy: 0.7022 - val_loss: 1.3386 - val_categorical_accuracy: 0.5200
# Epoch 178/450
# 17555/17555 [==============================] - 3s 187us/sample - loss: 0.8497 - categorical_accuracy: 0.7143 - val_loss: 1.3611 - val_categorical_accuracy: 0.5010
# Epoch 179/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.8415 - categorical_accuracy: 0.7089 - val_loss: 1.3708 - val_categorical_accuracy: 0.4990
# Epoch 180/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.8333 - categorical_accuracy: 0.7158 - val_loss: 1.3463 - val_categorical_accuracy: 0.5200
# Epoch 181/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.8150 - categorical_accuracy: 0.7205 - val_loss: 1.3747 - val_categorical_accuracy: 0.4876
# Epoch 182/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.8039 - categorical_accuracy: 0.7198 - val_loss: 1.3505 - val_categorical_accuracy: 0.5067
# Epoch 183/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.8183 - categorical_accuracy: 0.7217 - val_loss: 1.3350 - val_categorical_accuracy: 0.5162
# Epoch 184/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.8120 - categorical_accuracy: 0.7242 - val_loss: 1.3188 - val_categorical_accuracy: 0.5429
# Epoch 185/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.7954 - categorical_accuracy: 0.7276 - val_loss: 1.3508 - val_categorical_accuracy: 0.5276
# Epoch 186/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.8019 - categorical_accuracy: 0.7256 - val_loss: 1.3065 - val_categorical_accuracy: 0.5352
# Epoch 187/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.7999 - categorical_accuracy: 0.7281 - val_loss: 1.3382 - val_categorical_accuracy: 0.5124
# Epoch 188/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.7975 - categorical_accuracy: 0.7297 - val_loss: 1.3073 - val_categorical_accuracy: 0.5333
# Epoch 189/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.7830 - categorical_accuracy: 0.7356 - val_loss: 1.3422 - val_categorical_accuracy: 0.5200
# Epoch 190/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.7679 - categorical_accuracy: 0.7380 - val_loss: 1.2942 - val_categorical_accuracy: 0.5448
# Epoch 191/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.7868 - categorical_accuracy: 0.7307 - val_loss: 1.3403 - val_categorical_accuracy: 0.5276
# Epoch 192/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.7691 - categorical_accuracy: 0.7391 - val_loss: 1.3317 - val_categorical_accuracy: 0.5276
# Epoch 193/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.7660 - categorical_accuracy: 0.7364 - val_loss: 1.3206 - val_categorical_accuracy: 0.5352
# Epoch 194/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.7618 - categorical_accuracy: 0.7411 - val_loss: 1.3197 - val_categorical_accuracy: 0.5333
# Epoch 195/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.7674 - categorical_accuracy: 0.7430 - val_loss: 1.3596 - val_categorical_accuracy: 0.5314
# Epoch 196/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.7605 - categorical_accuracy: 0.7416 - val_loss: 1.2820 - val_categorical_accuracy: 0.5505
# Epoch 197/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.7576 - categorical_accuracy: 0.7409 - val_loss: 1.2866 - val_categorical_accuracy: 0.5352
# Epoch 198/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.7489 - categorical_accuracy: 0.7426 - val_loss: 1.2816 - val_categorical_accuracy: 0.5619
# Epoch 199/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.7422 - categorical_accuracy: 0.7451 - val_loss: 1.2687 - val_categorical_accuracy: 0.5752
# Epoch 200/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.7379 - categorical_accuracy: 0.7529 - val_loss: 1.2811 - val_categorical_accuracy: 0.5314
# Epoch 201/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.7440 - categorical_accuracy: 0.7484 - val_loss: 1.2898 - val_categorical_accuracy: 0.5390
# Epoch 202/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.7231 - categorical_accuracy: 0.7498 - val_loss: 1.2886 - val_categorical_accuracy: 0.5448
# Epoch 203/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.7197 - categorical_accuracy: 0.7534 - val_loss: 1.2877 - val_categorical_accuracy: 0.5410
# Epoch 204/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.7211 - categorical_accuracy: 0.7570 - val_loss: 1.3096 - val_categorical_accuracy: 0.5200
# Epoch 205/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.7103 - categorical_accuracy: 0.7534 - val_loss: 1.3431 - val_categorical_accuracy: 0.5162
# Epoch 206/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.7145 - categorical_accuracy: 0.7581 - val_loss: 1.2907 - val_categorical_accuracy: 0.5524
# Epoch 207/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.7051 - categorical_accuracy: 0.7600 - val_loss: 1.2943 - val_categorical_accuracy: 0.5276
# Epoch 208/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.7047 - categorical_accuracy: 0.7594 - val_loss: 1.3174 - val_categorical_accuracy: 0.5295
# Epoch 209/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6983 - categorical_accuracy: 0.7622 - val_loss: 1.3008 - val_categorical_accuracy: 0.5505
# Epoch 210/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.7017 - categorical_accuracy: 0.7613 - val_loss: 1.3161 - val_categorical_accuracy: 0.5505
# Epoch 211/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.7080 - categorical_accuracy: 0.7565 - val_loss: 1.2976 - val_categorical_accuracy: 0.5524
# Epoch 212/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6891 - categorical_accuracy: 0.7655 - val_loss: 1.2689 - val_categorical_accuracy: 0.5600
# Epoch 213/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.6735 - categorical_accuracy: 0.7647 - val_loss: 1.3094 - val_categorical_accuracy: 0.5676
# Epoch 214/450
# 17555/17555 [==============================] - 3s 184us/sample - loss: 0.6795 - categorical_accuracy: 0.7678 - val_loss: 1.2950 - val_categorical_accuracy: 0.5333
# Epoch 215/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6845 - categorical_accuracy: 0.7699 - val_loss: 1.2516 - val_categorical_accuracy: 0.5581
# Epoch 216/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6844 - categorical_accuracy: 0.7666 - val_loss: 1.2788 - val_categorical_accuracy: 0.5543
# Epoch 217/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6681 - categorical_accuracy: 0.7728 - val_loss: 1.2951 - val_categorical_accuracy: 0.5543
# Epoch 218/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.6671 - categorical_accuracy: 0.7732 - val_loss: 1.2880 - val_categorical_accuracy: 0.5619
# Epoch 219/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6669 - categorical_accuracy: 0.7773 - val_loss: 1.2479 - val_categorical_accuracy: 0.5600
# Epoch 220/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.6639 - categorical_accuracy: 0.7783 - val_loss: 1.2826 - val_categorical_accuracy: 0.5829
# Epoch 221/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.6660 - categorical_accuracy: 0.7780 - val_loss: 1.2626 - val_categorical_accuracy: 0.5771
# Epoch 222/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6637 - categorical_accuracy: 0.7769 - val_loss: 1.2733 - val_categorical_accuracy: 0.5790
# Epoch 223/450
# 17555/17555 [==============================] - 3s 188us/sample - loss: 0.6544 - categorical_accuracy: 0.7795 - val_loss: 1.3126 - val_categorical_accuracy: 0.5390
# Epoch 224/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.6544 - categorical_accuracy: 0.7822 - val_loss: 1.3051 - val_categorical_accuracy: 0.5657
# Epoch 225/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6418 - categorical_accuracy: 0.7799 - val_loss: 1.2847 - val_categorical_accuracy: 0.5638
# Epoch 226/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6559 - categorical_accuracy: 0.7780 - val_loss: 1.2659 - val_categorical_accuracy: 0.5505
# Epoch 227/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.6325 - categorical_accuracy: 0.7863 - val_loss: 1.2700 - val_categorical_accuracy: 0.5810
# Epoch 228/450
# 17555/17555 [==============================] - 3s 188us/sample - loss: 0.6400 - categorical_accuracy: 0.7896 - val_loss: 1.3068 - val_categorical_accuracy: 0.5600
# Epoch 229/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.6513 - categorical_accuracy: 0.7816 - val_loss: 1.2681 - val_categorical_accuracy: 0.6000
# Epoch 230/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6349 - categorical_accuracy: 0.7897 - val_loss: 1.2635 - val_categorical_accuracy: 0.5638
# Epoch 231/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6346 - categorical_accuracy: 0.7831 - val_loss: 1.2636 - val_categorical_accuracy: 0.5676
# Epoch 232/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6299 - categorical_accuracy: 0.7855 - val_loss: 1.2921 - val_categorical_accuracy: 0.5638
# Epoch 233/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.6282 - categorical_accuracy: 0.7878 - val_loss: 1.3008 - val_categorical_accuracy: 0.5676
# Epoch 234/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6228 - categorical_accuracy: 0.7891 - val_loss: 1.2915 - val_categorical_accuracy: 0.5790
# Epoch 235/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.6420 - categorical_accuracy: 0.7861 - val_loss: 1.2594 - val_categorical_accuracy: 0.5752
# Epoch 236/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.6160 - categorical_accuracy: 0.7937 - val_loss: 1.2437 - val_categorical_accuracy: 0.6000
# Epoch 237/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.6243 - categorical_accuracy: 0.7910 - val_loss: 1.2791 - val_categorical_accuracy: 0.5410
# Epoch 238/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6292 - categorical_accuracy: 0.7872 - val_loss: 1.2836 - val_categorical_accuracy: 0.5638
# Epoch 239/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.6154 - categorical_accuracy: 0.7918 - val_loss: 1.2446 - val_categorical_accuracy: 0.5886
# Epoch 240/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.6121 - categorical_accuracy: 0.7978 - val_loss: 1.2692 - val_categorical_accuracy: 0.5600
# Epoch 241/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.6163 - categorical_accuracy: 0.7909 - val_loss: 1.2686 - val_categorical_accuracy: 0.5638
# Epoch 242/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.6171 - categorical_accuracy: 0.7973 - val_loss: 1.2670 - val_categorical_accuracy: 0.5810
# Epoch 243/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6151 - categorical_accuracy: 0.7940 - val_loss: 1.2893 - val_categorical_accuracy: 0.5543
# Epoch 244/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6120 - categorical_accuracy: 0.7948 - val_loss: 1.2948 - val_categorical_accuracy: 0.5467
# Epoch 245/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.6048 - categorical_accuracy: 0.8010 - val_loss: 1.3053 - val_categorical_accuracy: 0.5371
# Epoch 246/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.6030 - categorical_accuracy: 0.7990 - val_loss: 1.3000 - val_categorical_accuracy: 0.5505
# Epoch 247/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6002 - categorical_accuracy: 0.8021 - val_loss: 1.2612 - val_categorical_accuracy: 0.5543
# Epoch 248/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.6004 - categorical_accuracy: 0.7982 - val_loss: 1.2427 - val_categorical_accuracy: 0.5848
# Epoch 249/450
# 17555/17555 [==============================] - 3s 186us/sample - loss: 0.6002 - categorical_accuracy: 0.8039 - val_loss: 1.2674 - val_categorical_accuracy: 0.5924
# Epoch 250/450
# 17555/17555 [==============================] - 3s 192us/sample - loss: 0.6026 - categorical_accuracy: 0.8005 - val_loss: 1.2556 - val_categorical_accuracy: 0.5790
# Epoch 251/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.5905 - categorical_accuracy: 0.8038 - val_loss: 1.2769 - val_categorical_accuracy: 0.5581
# Epoch 252/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.5961 - categorical_accuracy: 0.8016 - val_loss: 1.3083 - val_categorical_accuracy: 0.5676
# Epoch 253/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.5892 - categorical_accuracy: 0.8110 - val_loss: 1.3293 - val_categorical_accuracy: 0.5657
# Epoch 254/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.5906 - categorical_accuracy: 0.8060 - val_loss: 1.2758 - val_categorical_accuracy: 0.5714
# Epoch 255/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.6021 - categorical_accuracy: 0.7938 - val_loss: 1.2780 - val_categorical_accuracy: 0.5810
# Epoch 256/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.5789 - categorical_accuracy: 0.8079 - val_loss: 1.3227 - val_categorical_accuracy: 0.5371
# Epoch 257/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.5768 - categorical_accuracy: 0.8097 - val_loss: 1.2741 - val_categorical_accuracy: 0.5676
# Epoch 258/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.5877 - categorical_accuracy: 0.8060 - val_loss: 1.3011 - val_categorical_accuracy: 0.5600
# Epoch 259/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.5921 - categorical_accuracy: 0.8085 - val_loss: 1.2822 - val_categorical_accuracy: 0.5467
# Epoch 260/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.5927 - categorical_accuracy: 0.8027 - val_loss: 1.3020 - val_categorical_accuracy: 0.5543
# Epoch 261/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.5792 - categorical_accuracy: 0.8091 - val_loss: 1.2995 - val_categorical_accuracy: 0.5619
# Epoch 262/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.5770 - categorical_accuracy: 0.8062 - val_loss: 1.2911 - val_categorical_accuracy: 0.5695
# Epoch 263/450
# 17555/17555 [==============================] - 3s 192us/sample - loss: 0.5839 - categorical_accuracy: 0.8089 - val_loss: 1.3245 - val_categorical_accuracy: 0.5448
# Epoch 264/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.5879 - categorical_accuracy: 0.8038 - val_loss: 1.2641 - val_categorical_accuracy: 0.5867
# Epoch 265/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.5852 - categorical_accuracy: 0.8099 - val_loss: 1.2816 - val_categorical_accuracy: 0.5619
# Epoch 266/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.5759 - categorical_accuracy: 0.8121 - val_loss: 1.2571 - val_categorical_accuracy: 0.5714
# Epoch 267/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.5751 - categorical_accuracy: 0.8122 - val_loss: 1.2782 - val_categorical_accuracy: 0.5581
# Epoch 268/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.5721 - categorical_accuracy: 0.8151 - val_loss: 1.3079 - val_categorical_accuracy: 0.5562
# Epoch 269/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.5699 - categorical_accuracy: 0.8137 - val_loss: 1.2979 - val_categorical_accuracy: 0.5676
# Epoch 270/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.5692 - categorical_accuracy: 0.8144 - val_loss: 1.2596 - val_categorical_accuracy: 0.5752
# Epoch 271/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.5620 - categorical_accuracy: 0.8182 - val_loss: 1.2830 - val_categorical_accuracy: 0.5962
# Epoch 272/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.5809 - categorical_accuracy: 0.8103 - val_loss: 1.3183 - val_categorical_accuracy: 0.5581
# Epoch 273/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.5707 - categorical_accuracy: 0.8166 - val_loss: 1.3006 - val_categorical_accuracy: 0.5790
# Epoch 274/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.5538 - categorical_accuracy: 0.8179 - val_loss: 1.3508 - val_categorical_accuracy: 0.5524
# Epoch 275/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.5563 - categorical_accuracy: 0.8166 - val_loss: 1.3067 - val_categorical_accuracy: 0.5771
# Epoch 276/450
# 17555/17555 [==============================] - 3s 189us/sample - loss: 0.5633 - categorical_accuracy: 0.8173 - val_loss: 1.3175 - val_categorical_accuracy: 0.5771
# Epoch 277/450
# 17555/17555 [==============================] - 3s 191us/sample - loss: 0.5638 - categorical_accuracy: 0.8150 - val_loss: 1.3185 - val_categorical_accuracy: 0.5790
# Epoch 278/450
# 17555/17555 [==============================] - 3s 190us/sample - loss: 0.5607 - categorical_accuracy: 0.8193 - val_loss: 1.2573 - val_categorical_accuracy: 0.6152
# Epoch 00278: early stopping
# 525/525 [==============================] - 0s 413us/sample - loss: 1.2573 - categorical_accuracy: 0.6152
# [1.257329967703138, 0.6152381]

# %% [markdown]
# ## Loss & Accuracy Curves

# %%
# Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
  
# Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['categorical_accuracy'],'r',linewidth=3.0)
plt.plot(history.history['val_categorical_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %% [markdown]
# # Performance

# %%
t0 = time.time()
image_labels_pred = model1.predict(images_test)
image_labels_pred = np.where(image_labels_pred > 0.5, 1, 0)
t1 = time.time()

total_prediction_time = t1-t0

# %%
y_true = np.argmax(image_labels_test,1) 
y_pred = np.argmax(image_labels_pred,1)

# %% [markdown]
# ## Confusion Matrix

# %%
cm =  pd.DataFrame(confusion_matrix(y_true, y_pred), 
                                 index = label_names_array, 
                                 columns = label_names_array)

plt.figure(figsize=[8,6])
sn.heatmap(cm, annot=True,cmap='Blues', fmt='g')

# %% [markdown]
# ## Classification Metrics

# %%
target_names = label_names_array
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         Sell       0.16      0.18      0.17        74
#          Buy       0.28      0.20      0.23        75
#         Hold       0.72      0.75      0.74       376
#
#     accuracy                           0.59       525
#    macro avg       0.39      0.38      0.38       525
# weighted avg       0.58      0.59      0.58       525

# %% [markdown]
# ## Time spent

# %%
total_training_time = sum(time_callback.times)
print("Time spent on entire model training: {:4f} seconds".format(total_training_time))
# Out:
# Time spent on entire model training: 932.767588 seconds

# %% [markdown]
# ## Financial Evaluation, Save predicton data in given format

# %%
#custom library
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/CNN/evaluation')
import financial_evaluation

# %%
# Create Signals from numbers here 
Signals = y_pred

prediction = pd.DataFrame(test_prices, columns = [VarName])
prediction['Signals'] = Signals
prediction['Signals'].loc[prediction['Signals'] == 0] = "Sell"
prediction['Signals'].loc[prediction['Signals'] == 1] = "Buy"
prediction['Signals'].loc[prediction['Signals'] == 2] = "Hold"
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#save results
prediction.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/PredForFinEval.csv")

# %%
fin_res = financial_evaluation.financial_evaluation(VarName, test_prices, prediction['Signals'])
print("Annualized return is {}, cumulative return is {} and number of trades are {}.".format(fin_res['annualized_return'], fin_res['cumulative_return'], fin_res['all_trades']))
# Out:
# Annualized return is [0.04649943], cumulative return is [0.0961187] and number of trades are 68.

# %% [markdown]
# ## Save Model

# %%
model1.save('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/model.h5")

# %% [markdown]
# ## Save true and pred

# %%
TruePred = pd.DataFrame(y_true, columns = [VarName])
TruePred['Prediction'] = y_pred
TruePred.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/True&Pred.csv")

# %% [markdown]
# ## Save Classification Metrics &  Save Times

# %%
Acc = np.float(accuracy_score(y_true=y_true, y_pred=y_pred))
#F1 = np.float(f1_score(y_true = y_true, y_pred = y_pred, average = 'macro'))
Prec = np.float(precision_score(y_true=y_true, y_pred=y_pred, average = 'macro'))
Recall = np.float(recall_score(y_true=y_true, y_pred=y_pred, average = 'macro'))

F1 = 2 * (Prec * Recall) / (Prec + Recall)

print(Acc, F1, Prec, Recall)
# Out:
# 0.5904761904761905 0.38107796348305417 0.3871161760050649 0.3752252252252252

# %%
np.savez('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/Time&ClassificationEval.npz",
         accuracy = Acc,
         MacF1 = F1,
         MacPrecision = Prec,
         MacRecall = Recall,
         TrainTime = np.float(total_training_time),
         PredTime = np.float(total_prediction_time)
        )
