# %%
# !pip install numpy==1.16.1
# !pip install tensorflow-gpu==2.0.0-beta1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
from sklearn.model_selection import TimeSeriesSplit
from sklearn.utils import class_weight
from sklearn.metrics import f1_score, confusion_matrix, classification_report, accuracy_score, precision_score, recall_score
import time

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, AveragePooling2D, BatchNormalization, LeakyReLU
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam, Nadam, SGD, RMSprop
from tensorflow.keras.callbacks import EarlyStopping

LR = LeakyReLU(alpha = .3)
LR.__name__ = 'leakyrelu'

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Requirement already satisfied: numpy==1.16.1 in /usr/local/lib/python3.6/dist-packages (1.16.1)
# Requirement already satisfied: tensorflow-gpu==2.0.0-beta1 in /usr/local/lib/python3.6/dist-packages (2.0.0b1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.15.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.2.2)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.16.1)
# Requirement already satisfied: tb-nightly<1.14.0a20190604,>=1.14.0a20190603 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.14.0a20190603)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.11.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.12.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.1.7)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.0.8)
# Requirement already satisfied: tf-estimator-nightly<1.14.0.dev2019060502,>=1.14.0.dev2019060501 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.14.0.dev2019060501)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.7.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.33.4)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (3.7.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (41.0.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (0.15.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (3.1.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==2.0.0-beta1) (2.8.0)
# Found GPU at: /device:GPU:0

# %%
# fix random seed for reproducibility
seed = 2
np.random.seed(seed)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Pre-Settings

# %%
Test = "test2"
Version = "_univ_" #="univ"
VarName = "GSPC"


if Test == "test1":
  tr_direct = "data_train_to2005"
  ts_direct = "data_test_2005Decto_2007Dec"
elif Test == "test2":
  tr_direct = "data_train_to2007"
  ts_direct = "data_test_2008Jan_to_2010Jan"
else:
  tr_direct = "data_train_to2017May"
  ts_direct = "data_test_2017May_to_2019last"

# %% [markdown]
# # Load data

# %%
if Version == "_indiv_":
  train_filename = "LW5_IW30/" + tr_direct + "/" + Version[1:] + "train" + Test[-1] + "_" + VarName + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"
else:
  train_filename = "LW5_IW30/" + tr_direct + "/" + Version[1:] + "train" + Test[-1] + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"
  
test_filename = "LW5_IW30/" + ts_direct + "/" + Test + "_" + VarName + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"

# %% [markdown]
# ### Image window sizes

# %%
Image_window_size = np.int(train_filename[train_filename.find('_IWS') + 4 : train_filename.find("_Trf")])
Image_window_size
# Out:
# 30

# %% [markdown]
# ### Transformation types

# %%
Image_trf = eval(train_filename[train_filename.find('_Trf')+4:train_filename.find('.npz')])
Image_trf
# Out:
# ['RP', 'GASF', 'MTF']

# %%
num_color_channels = len(Image_trf)
num_color_channels
# Out:
# 3

# %% [markdown]
# #### In case file is missing run the data-check-and-prep with preferred settings and use the new file's name (cannot upload too big files to Git)

# %%
data_train = np.load('/content/drive/My Drive/Colab Notebooks/CNN/' + train_filename)
data_test = np.load('/content/drive/My Drive/Colab Notebooks/CNN/' + test_filename)

# %%
images_train = data_train['images']
images_test = data_test['images']
image_labels_train = data_train['image_labels']
image_labels_test = data_test['image_labels']
train_prices = data_train['price_at_image']
test_prices = data_test['price_at_image']

label_names = data_train['label_names'] # same everywhere

# %% [markdown]
# Load all test files into one big concatenated one for validation

# %%
Names = ['IXIC', 'AAPL', 'N225', 'SPY']
for names in Names:
  test_filename = "LW5_IW30/" + ts_direct + "/" + Test + "_" + names + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"
  data_test = np.load('/content/drive/My Drive/Colab Notebooks/CNN/' + test_filename)
  
  images_test = np.append(images_test, data_test['images'], axis = 0)
  image_labels_test = np.append(image_labels_test, data_test['image_labels'], axis = 0)
  test_prices = np.append(test_prices, data_test['price_at_image'], axis = 0)

# %% [markdown]
# # Check data

# %%
image_labels_train.shape
# Out:
# (216072, 3)

# %% [markdown]
# Get label names array for later visualization

# %%
label_names = label_names.item()
label_names
# Out:
# {0: 'Sell', 1: 'Buy', 2: 'Hold'}

# %%
label_names_array = np.chararray(3, itemsize = 4).decode("utf-8")

for key, value in label_names.items():
  label_names_array[key] = value
label_names_array
# Out:
# array(['Sell', 'Buy', 'Hold'], dtype='<U4')

# %% [markdown]
# ## e.g.:

# %%
for trfidx, trf in enumerate(Image_trf):
    print('Transformation type: ' + trf)
    for idx, image in enumerate(images_train[:2,:,:, trfidx]):
        plt.imshow(image, cmap = "Greys")
        plt.title(label_names[np.int(np.argwhere(image_labels_train[idx]))])
        plt.show()
# Out:
# Transformation type: RP
# Transformation type: GASF
# Transformation type: MTF

# %%
print("Train images shape : {}; Train labels shape : {}".format(images_train.shape, image_labels_train.shape))
# Out:
# Train images shape : (216072, 30, 30, 3); Train labels shape : (216072, 3)

# %%
print("Test images shape : {}; Test labels shape : {}".format(images_test.shape, image_labels_test.shape))
# Out:
# Test images shape : (2605, 30, 30, 3); Test labels shape : (2605, 3)

# %% [markdown]
# # Baseline predictions
# Choosing the biggest class to be the class of all

# %%
basepred = np.zeros(image_labels_test.shape)
basepred[:, np.argmax(np.sum(image_labels_test, 0))] = 1.0

base_acc = sum(np.equal(np.argmax(basepred, 1), np.argmax(image_labels_test, 1)))/np.sum(image_labels_test)
base_f1 = f1_score(y_true = image_labels_test, y_pred = basepred, average = 'macro')
# warning F1 due to only label 2 being predicted in baseline

print("Accuracy: {:.5f}".format(base_acc))
print("Categorical Accuracy: {:.5f}".format(accuracy_score(np.argmax(basepred, 1), np.argmax(image_labels_test, 1))))

print("F1 score: {:.5f}".format(base_f1))

print(classification_report(np.argmax(basepred, 1), np.argmax(image_labels_test, 1)))
# Out:
# Accuracy: 0.71209
# Categorical Accuracy: 0.71209
# F1 score: 0.27728
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         0
#            2       1.00      0.71      0.83      2605
#
#     accuracy                           0.71      2605
#    macro avg       0.33      0.24      0.28      2605
# weighted avg       1.00      0.71      0.83      2605
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %% [markdown]
# # The Deep CNN

# %% [markdown]
# ### Custom Keras Eval metrics: F1 Score
# https://medium.com/@thongonary/how-to-compute-f1-score-for-each-epoch-in-keras-a1acd17715a2

# %%
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import fbeta_score

# Some default constants

START = 0.5
END = 0.95
STEP = 0.05
N_STEPS = int((END - START) / STEP) + 2
DEFAULT_THRESHOLDS = np.linspace(START, END, N_STEPS)
DEFAULT_BETA = 1
DEFAULT_LOGS = {}
FBETA_METRIC_NAME = "val_fbeta"

class FBetaMetricCallback(Callback):

    def __init__(self, beta=DEFAULT_BETA, thresholds=DEFAULT_THRESHOLDS):
        self.beta = beta
        self.thresholds = thresholds
        # Will be initialized when the training starts
        self.val_fbeta = None

    def on_train_begin(self, logs=DEFAULT_LOGS):
        """ This is where the validation Fbeta
        validation scores will be saved during training: one value per
        epoch.
        """
        self.val_fbeta = []

    def _score_per_threshold(self, predictions, targets, threshold):
        """ Compute the Fbeta score per threshold.
        """
        # Notice that here I am using the sklearn fbeta_score function.
        # You can read more about it here:
        # http://scikit-learn.org/stable/modules/generated/sklearn.metrics.fbeta_score.html
        thresholded_predictions = (predictions > threshold).astype(int)
        return fbeta_score(targets, thresholded_predictions, beta=self.beta)

    def on_epoch_end(self, epoch, logs=DEFAULT_LOGS):
        val_predictions = self.model.predict(self.validation_data[0])
        val_targets = self.validation_data[1]
        _val_fbeta = np.mean([self._score_per_threshold(val_predictions,
                                                        val_targets, threshold)
                              for threshold in self.thresholds])
        self.val_fbeta.append(_val_fbeta)
        print("Current F{} metric is: {}".format(str(self.beta), str(_val_fbeta)))
        return

    def on_train_end(self, logs=DEFAULT_LOGS):
        """ Assign the validation Fbeta computed metric to the History object.
        """
        self.model.history.history[FBETA_METRIC_NAME] = self.val_fbeta
        
f1_score = FBetaMetricCallback(beta=1)

# %% [markdown]
# ### Custom Time Logging

# %%
import tensorflow.keras.callbacks as keras_cb

class TimeHistory(keras_cb.Callback):
  def on_train_begin(self, logs={}):
    self.times = []

  def on_epoch_begin(self, epoch, logs={}):
    self.epoch_time_start = time.time()

  def on_epoch_end(self, epoch, logs={}):
    self.times.append(time.time() - self.epoch_time_start)

time_callback = TimeHistory()

# %% [markdown]
# ### Network Parameters

# %%
# image shape (d x d)
n_input = images_train.shape[1]
inputShape = (n_input, n_input, num_color_channels)

# number of classes
n_classes =  image_labels_train.shape[1]

# dropout
to_drop = 0.25 # prob. to DROP

# %% [markdown]
# ## Building the model

# %%
def createModel(input_shape, dropout = .2):
    model = Sequential()
    # Input
    model.add(Conv2D(32, 
                     (3, 3), 
                     padding='same', 
                     activation=LR, 
                     input_shape=input_shape
                    ))
    model.add(BatchNormalization())
    # model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))
    
    # 1Convolution,relu then pooling
    model.add(Conv2D(64, (3, 3), 
                     padding='same', 
                     activation=LR,
                     kernel_regularizer=regularizers.l2(0.01)
                    ))
    model.add(BatchNormalization())
    model.add(AveragePooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))
    
    # Flatten & Dense layers 
    model.add(Flatten())
    
    model.add(Dense(128, activation=LR, kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(Dropout(.25))
    model.add(Dense(n_classes, activation='softmax'))
  
    return model

# %%
model1 = createModel(dropout = to_drop, input_shape = inputShape)
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 30, 30, 32)        128
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 64)        256
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 15, 15, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 15, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 14400)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1843328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 1,864,003
# Trainable params: 1,863,555
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# ## Hyperparameter settings

# %%
training_iters = 450
batch_size = 2048

# %% [markdown]
# ### Accounting for imbalance

# %%
label_names
# Out:
# {0: 'Sell', 1: 'Buy', 2: 'Hold'}

# %%
np.sum(image_labels_train, axis = 0)/np.sum(image_labels_train)
# Out:
# array([0.14106409, 0.1424664 , 0.71646951])

# %%
clweight_custom = {0: 0.6 , 1: 2.4, 2: 0.4}

# %%
y_ints = [y.argmax() for y in image_labels_train]
class_weights = class_weight.compute_class_weight(clweight_custom,
                                                 np.unique(y_ints),
                                                 y_ints)
class_weight_dict = dict(enumerate(class_weights))
class_weight_dict
# Out:
# {0: 0.6, 1: 2.4, 2: 0.4}

# %% [markdown]
# ## Compiling

# %%
model1.compile(optimizer=SGD(nesterov=True, momentum = 0.7, decay=1e-6),#Adam(lr=0.0001, amsgrad = True), #Nadam(lr=0.0005), 
               loss='kullback_leibler_divergence', 
               metrics=['categorical_accuracy'])

# %% [markdown]
# ## Training

# %%
es2 = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
history = model1.fit(images_train, 
                     image_labels_train, 
                     batch_size=batch_size, 
                     epochs=training_iters, verbose=1,
                     validation_data=(images_test, image_labels_test),
                     class_weight=class_weight_dict,
                     callbacks=[time_callback, es2]
                    )
  
model1.evaluate(images_test, image_labels_test)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0815 09:07:26.709468 140494204376960 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 216072 samples, validate on 2605 samples
# Epoch 1/450
# 216072/216072 [==============================] - 43s 200us/sample - loss: 3.6612 - categorical_accuracy: 0.3748 - val_loss: 3.7296 - val_categorical_accuracy: 0.1428
# Epoch 2/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 3.1520 - categorical_accuracy: 0.3957 - val_loss: 3.4367 - val_categorical_accuracy: 0.1428
# Epoch 3/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 2.8043 - categorical_accuracy: 0.3897 - val_loss: 3.1057 - val_categorical_accuracy: 0.1428
# Epoch 4/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 2.5157 - categorical_accuracy: 0.3846 - val_loss: 2.8066 - val_categorical_accuracy: 0.1455
# Epoch 5/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 2.2690 - categorical_accuracy: 0.3801 - val_loss: 2.5563 - val_categorical_accuracy: 0.2046
# Epoch 6/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 2.0567 - categorical_accuracy: 0.3881 - val_loss: 2.3493 - val_categorical_accuracy: 0.2683
# Epoch 7/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 1.8725 - categorical_accuracy: 0.3984 - val_loss: 2.1725 - val_categorical_accuracy: 0.3002
# Epoch 8/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 1.7128 - categorical_accuracy: 0.4095 - val_loss: 2.0210 - val_categorical_accuracy: 0.3336
# Epoch 9/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 1.5738 - categorical_accuracy: 0.4155 - val_loss: 1.8976 - val_categorical_accuracy: 0.3386
# Epoch 10/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 1.4541 - categorical_accuracy: 0.4209 - val_loss: 1.7724 - val_categorical_accuracy: 0.3716
# Epoch 11/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 1.3498 - categorical_accuracy: 0.4251 - val_loss: 1.6856 - val_categorical_accuracy: 0.3605
# Epoch 12/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 1.2584 - categorical_accuracy: 0.4303 - val_loss: 1.6101 - val_categorical_accuracy: 0.3593
# Epoch 13/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 1.1803 - categorical_accuracy: 0.4304 - val_loss: 1.5229 - val_categorical_accuracy: 0.3827
# Epoch 14/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 1.1113 - categorical_accuracy: 0.4358 - val_loss: 1.4545 - val_categorical_accuracy: 0.3927
# Epoch 15/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 1.0518 - categorical_accuracy: 0.4377 - val_loss: 1.3803 - val_categorical_accuracy: 0.4169
# Epoch 16/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.9999 - categorical_accuracy: 0.4401 - val_loss: 1.3593 - val_categorical_accuracy: 0.3850
# Epoch 17/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.9548 - categorical_accuracy: 0.4419 - val_loss: 1.2934 - val_categorical_accuracy: 0.4265
# Epoch 18/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.9158 - categorical_accuracy: 0.4446 - val_loss: 1.2576 - val_categorical_accuracy: 0.4100
# Epoch 19/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 0.8814 - categorical_accuracy: 0.4460 - val_loss: 1.1929 - val_categorical_accuracy: 0.4534
# Epoch 20/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.8509 - categorical_accuracy: 0.4490 - val_loss: 1.1504 - val_categorical_accuracy: 0.4860
# Epoch 21/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.8262 - categorical_accuracy: 0.4517 - val_loss: 1.1441 - val_categorical_accuracy: 0.4653
# Epoch 22/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 0.8034 - categorical_accuracy: 0.4551 - val_loss: 1.1847 - val_categorical_accuracy: 0.4019
# Epoch 23/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 0.7833 - categorical_accuracy: 0.4559 - val_loss: 1.1041 - val_categorical_accuracy: 0.4630
# Epoch 24/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.7661 - categorical_accuracy: 0.4580 - val_loss: 1.1389 - val_categorical_accuracy: 0.4127
# Epoch 25/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 0.7510 - categorical_accuracy: 0.4618 - val_loss: 1.0977 - val_categorical_accuracy: 0.4507
# Epoch 26/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 0.7381 - categorical_accuracy: 0.4646 - val_loss: 1.0488 - val_categorical_accuracy: 0.4998
# Epoch 27/450
# 216072/216072 [==============================] - 35s 162us/sample - loss: 0.7267 - categorical_accuracy: 0.4656 - val_loss: 1.0850 - val_categorical_accuracy: 0.4392
# Epoch 28/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 0.7168 - categorical_accuracy: 0.4689 - val_loss: 1.0356 - val_categorical_accuracy: 0.4737
# Epoch 29/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.7072 - categorical_accuracy: 0.4724 - val_loss: 1.0402 - val_categorical_accuracy: 0.4821
# Epoch 30/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 0.6997 - categorical_accuracy: 0.4755 - val_loss: 1.0399 - val_categorical_accuracy: 0.4821
# Epoch 31/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.6933 - categorical_accuracy: 0.4786 - val_loss: 1.0573 - val_categorical_accuracy: 0.4622
# Epoch 32/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.6874 - categorical_accuracy: 0.4826 - val_loss: 1.0461 - val_categorical_accuracy: 0.4591
# Epoch 33/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 0.6818 - categorical_accuracy: 0.4862 - val_loss: 1.0776 - val_categorical_accuracy: 0.4322
# Epoch 34/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 0.6777 - categorical_accuracy: 0.4890 - val_loss: 1.0236 - val_categorical_accuracy: 0.4706
# Epoch 35/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 0.6738 - categorical_accuracy: 0.4905 - val_loss: 1.0563 - val_categorical_accuracy: 0.4476
# Epoch 36/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 0.6689 - categorical_accuracy: 0.4958 - val_loss: 1.0501 - val_categorical_accuracy: 0.4583
# Epoch 37/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 0.6663 - categorical_accuracy: 0.4984 - val_loss: 1.0620 - val_categorical_accuracy: 0.4495
# Epoch 38/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.6637 - categorical_accuracy: 0.5018 - val_loss: 1.0540 - val_categorical_accuracy: 0.4522
# Epoch 39/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.6613 - categorical_accuracy: 0.5053 - val_loss: 1.0522 - val_categorical_accuracy: 0.4668
# Epoch 40/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.6589 - categorical_accuracy: 0.5084 - val_loss: 1.0334 - val_categorical_accuracy: 0.4768
# Epoch 41/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.6567 - categorical_accuracy: 0.5140 - val_loss: 1.0355 - val_categorical_accuracy: 0.4791
# Epoch 42/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.6558 - categorical_accuracy: 0.5141 - val_loss: 1.0524 - val_categorical_accuracy: 0.4468
# Epoch 43/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 0.6534 - categorical_accuracy: 0.5199 - val_loss: 1.0662 - val_categorical_accuracy: 0.4595
# Epoch 44/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 0.6517 - categorical_accuracy: 0.5214 - val_loss: 0.9949 - val_categorical_accuracy: 0.5244
# Epoch 45/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.6508 - categorical_accuracy: 0.5248 - val_loss: 0.9997 - val_categorical_accuracy: 0.5248
# Epoch 46/450
# 216072/216072 [==============================] - 35s 164us/sample - loss: 0.6499 - categorical_accuracy: 0.5268 - val_loss: 1.0930 - val_categorical_accuracy: 0.4472
# Epoch 47/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.6489 - categorical_accuracy: 0.5302 - val_loss: 1.0171 - val_categorical_accuracy: 0.5175
# Epoch 48/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.6478 - categorical_accuracy: 0.5326 - val_loss: 1.0014 - val_categorical_accuracy: 0.5152
# Epoch 49/450
# 216072/216072 [==============================] - 36s 165us/sample - loss: 0.6468 - categorical_accuracy: 0.5348 - val_loss: 1.0056 - val_categorical_accuracy: 0.5248
# Epoch 50/450
# 216072/216072 [==============================] - 35s 163us/sample - loss: 0.6456 - categorical_accuracy: 0.5398 - val_loss: 1.0660 - val_categorical_accuracy: 0.4802
# Epoch 51/450
# 216072/216072 [==============================] - 36s 165us/sample - loss: 0.6454 - categorical_accuracy: 0.5411 - val_loss: 1.0289 - val_categorical_accuracy: 0.5033
# Epoch 52/450
# 216072/216072 [==============================] - 36s 167us/sample - loss: 0.6453 - categorical_accuracy: 0.5434 - val_loss: 1.0320 - val_categorical_accuracy: 0.5063
# Epoch 53/450
# 216072/216072 [==============================] - 36s 168us/sample - loss: 0.6436 - categorical_accuracy: 0.5459 - val_loss: 1.0332 - val_categorical_accuracy: 0.5067
# Epoch 54/450
# 216072/216072 [==============================] - 36s 168us/sample - loss: 0.6450 - categorical_accuracy: 0.5475 - val_loss: 1.0060 - val_categorical_accuracy: 0.5286
# Epoch 00054: early stopping
# 2605/2605 [==============================] - 0s 191us/sample - loss: 1.0060 - categorical_accuracy: 0.5286
# [1.0060373584505693, 0.52859885]

# %% [markdown]
# ## Loss & Accuracy Curves

# %%
# Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
  
# Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['categorical_accuracy'],'r',linewidth=3.0)
plt.plot(history.history['val_categorical_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %% [markdown]
# # Performance: GSPC

# %%
VarName = 'GSPC'

test_filename = "LW5_IW30/" + ts_direct + "/" + Test + "_" + VarName + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"

data_test = np.load('/content/drive/My Drive/Colab Notebooks/CNN/' + test_filename)

# %%
images_test = data_test['images']
image_labels_test = data_test['image_labels']
test_prices = data_test['price_at_image']

# %%
t0 = time.time()
image_labels_pred = model1.predict(images_test)
image_labels_pred = np.where(image_labels_pred > 0.5, 1, 0)
t1 = time.time()

total_prediction_time = t1-t0

# %%
y_true = np.argmax(image_labels_test,1) 
y_pred = np.argmax(image_labels_pred,1)

# %% [markdown]
# ## Confusion Matrix

# %%
cm =  pd.DataFrame(confusion_matrix(y_true, y_pred), 
                                 index = label_names_array, 
                                 columns = label_names_array)

plt.figure(figsize=[8,6])
sn.heatmap(cm, annot=True,cmap='Blues', fmt='g')

# %% [markdown]
# ## Classification Metrics

# %%
target_names = label_names_array
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         Sell       0.17      0.36      0.24        77
#          Buy       0.18      0.34      0.24        74
#         Hold       0.80      0.49      0.61       370
#
#     accuracy                           0.45       521
#    macro avg       0.39      0.40      0.36       521
# weighted avg       0.62      0.45      0.50       521

# %% [markdown]
# ## Time spent

# %%
total_training_time = sum(time_callback.times)
print("Time spent on entire model training: {:4f} seconds".format(total_training_time))
# Out:
# Time spent on entire model training: 1918.390671 seconds

# %% [markdown]
# ## Financial Evaluation, Save predicton data in given format

# %%
#custom library
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/CNN/evaluation')
import financial_evaluation

# %%
# Create Signals from numbers here 
Signals = y_pred

prediction = pd.DataFrame(test_prices, columns = [VarName])
prediction['Signals'] = Signals
prediction['Signals'].loc[prediction['Signals'] == 0] = "Sell"
prediction['Signals'].loc[prediction['Signals'] == 1] = "Buy"
prediction['Signals'].loc[prediction['Signals'] == 2] = "Hold"
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#save results
prediction.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/PredForFinEval.csv")

# %%
fin_res = financial_evaluation.financial_evaluation(VarName, test_prices, prediction['Signals'], safety = True)
print(VarName + ": Annualized return is {}, cumulative return is {} and number of trades are {}.".format(fin_res['annualized_return'], fin_res['cumulative_return'], fin_res['all_trades']))
# Out:
# GSPC: Annualized return is [0.15414776], cumulative return is [0.33279175] and number of trades are 74.

# %% [markdown]
# ## Save Model

# %%
model1.save('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/model.h5")

# %% [markdown]
# ## Save true and pred

# %%
TruePred = pd.DataFrame(y_true, columns = [VarName])
TruePred['Prediction'] = y_pred
TruePred.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/True&Pred.csv")

# %% [markdown]
# ## Save Classification Metrics &  Save Times

# %%
Acc = np.float(accuracy_score(y_true=y_true, y_pred=y_pred))
#F1 = np.float(f1_score(y_true = y_true, y_pred = y_pred, average = 'macro'))
Prec = np.float(precision_score(y_true=y_true, y_pred=y_pred, average = 'macro'))
Recall = np.float(recall_score(y_true=y_true, y_pred=y_pred, average = 'macro'))

F1 = 2 * (Prec * Recall) / (Prec + Recall)

print(Acc, F1, Prec, Recall)
# Out:
# 0.4472168905950096 0.3914509413283395 0.3870177267987487 0.39598689598689596

# %%
np.savez('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/Time&ClassificationEval.npz",
         accuracy = Acc,
         MacF1 = F1,
         MacPrecision = Prec,
         MacRecall = Recall,
         TrainTime = np.float(total_training_time),
         PredTime = np.float(total_prediction_time)
        )

# %% [markdown]
# # Performance: AAPL

# %%
VarName = 'AAPL'

test_filename = "LW5_IW30/" + ts_direct + "/" + Test + "_" + VarName + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"

data_test = np.load('/content/drive/My Drive/Colab Notebooks/CNN/' + test_filename)

# %%
images_test = data_test['images']
image_labels_test = data_test['image_labels']
test_prices = data_test['price_at_image']

# %%
t0 = time.time()
image_labels_pred = model1.predict(images_test)
image_labels_pred = np.where(image_labels_pred > 0.5, 1, 0)
t1 = time.time()

total_prediction_time = t1-t0

# %%
y_true = np.argmax(image_labels_test,1) 
y_pred = np.argmax(image_labels_pred,1)

# %% [markdown]
# ## Confusion Matrix

# %%
cm =  pd.DataFrame(confusion_matrix(y_true, y_pred), 
                                 index = label_names_array, 
                                 columns = label_names_array)

plt.figure(figsize=[8,6])
sn.heatmap(cm, annot=True,cmap='Blues', fmt='g')

# %% [markdown]
# ## Classification Metrics

# %%
target_names = label_names_array
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         Sell       0.16      0.32      0.21        73
#          Buy       0.20      0.36      0.26        72
#         Hold       0.78      0.51      0.62       376
#
#     accuracy                           0.46       521
#    macro avg       0.38      0.40      0.36       521
# weighted avg       0.62      0.46      0.51       521

# %% [markdown]
# ## Financial Evaluation, Save predicton data in given format

# %%
#custom library
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/CNN/evaluation')
import financial_evaluation

# %%
# Create Signals from numbers here 
Signals = y_pred

prediction = pd.DataFrame(test_prices, columns = [VarName])
prediction['Signals'] = Signals
prediction['Signals'].loc[prediction['Signals'] == 0] = "Sell"
prediction['Signals'].loc[prediction['Signals'] == 1] = "Buy"
prediction['Signals'].loc[prediction['Signals'] == 2] = "Hold"
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#save results
prediction.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/PredForFinEval.csv")

# %%
fin_res = financial_evaluation.financial_evaluation(VarName, test_prices, prediction['Signals'], safety = True)
print(VarName + ": Annualized return is {}, cumulative return is {} and number of trades are {}.".format(fin_res['annualized_return'], fin_res['cumulative_return'], fin_res['all_trades']))
# Out:
# AAPL: Annualized return is [0.03998955], cumulative return is [0.08174138] and number of trades are 72.

# %% [markdown]
# ## Save Model

# %%
model1.save('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/model.h5")

# %% [markdown]
# ## Save true and pred

# %%
TruePred = pd.DataFrame(y_true, columns = [VarName])
TruePred['Prediction'] = y_pred
TruePred.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/True&Pred.csv")

# %% [markdown]
# ## Save Classification Metrics &  Save Times

# %%
Acc = np.float(accuracy_score(y_true=y_true, y_pred=y_pred))
#F1 = np.float(f1_score(y_true = y_true, y_pred = y_pred, average = 'macro'))
Prec = np.float(precision_score(y_true=y_true, y_pred=y_pred, average = 'macro'))
Recall = np.float(recall_score(y_true=y_true, y_pred=y_pred, average = 'macro'))

F1 = 2 * (Prec * Recall) / (Prec + Recall)

print(Acc, F1, Prec, Recall)
# Out:
# 0.46449136276391556 0.3887023854317366 0.38121249323356565 0.3964924922007405

# %%
np.savez('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/Time&ClassificationEval.npz",
         accuracy = Acc,
         MacF1 = F1,
         MacPrecision = Prec,
         MacRecall = Recall,
         TrainTime = np.float(total_training_time),
         PredTime = np.float(total_prediction_time)
        )

# %% [markdown]
# # Performance: IXIC

# %%
VarName = 'IXIC'

test_filename = "LW5_IW30/" + ts_direct + "/" + Test + "_" + VarName + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"

data_test = np.load('/content/drive/My Drive/Colab Notebooks/CNN/' + test_filename)

# %%
images_test = data_test['images']
image_labels_test = data_test['image_labels']
test_prices = data_test['price_at_image']

# %%
t0 = time.time()
image_labels_pred = model1.predict(images_test)
image_labels_pred = np.where(image_labels_pred > 0.5, 1, 0)
t1 = time.time()

total_prediction_time = t1-t0

# %%
y_true = np.argmax(image_labels_test,1) 
y_pred = np.argmax(image_labels_pred,1)

# %% [markdown]
# ## Confusion Matrix

# %%
cm =  pd.DataFrame(confusion_matrix(y_true, y_pred), 
                                 index = label_names_array, 
                                 columns = label_names_array)

plt.figure(figsize=[8,6])
sn.heatmap(cm, annot=True,cmap='Blues', fmt='g')

# %% [markdown]
# ## Classification Metrics

# %%
target_names = label_names_array
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         Sell       0.16      0.33      0.22        75
#          Buy       0.18      0.32      0.23        75
#         Hold       0.78      0.49      0.60       371
#
#     accuracy                           0.44       521
#    macro avg       0.37      0.38      0.35       521
# weighted avg       0.61      0.44      0.49       521

# %% [markdown]
# ## Financial Evaluation, Save predicton data in given format

# %%
#custom library
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/CNN/evaluation')
import financial_evaluation

# %%
# Create Signals from numbers here 
Signals = y_pred

prediction = pd.DataFrame(test_prices, columns = [VarName])
prediction['Signals'] = Signals
prediction['Signals'].loc[prediction['Signals'] == 0] = "Sell"
prediction['Signals'].loc[prediction['Signals'] == 1] = "Buy"
prediction['Signals'].loc[prediction['Signals'] == 2] = "Hold"
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#save results
prediction.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/PredForFinEval.csv")

# %%
fin_res = financial_evaluation.financial_evaluation(VarName, test_prices, prediction['Signals'], safety = True)
print(VarName + ": Annualized return is {}, cumulative return is {} and number of trades are {}.".format(fin_res['annualized_return'], fin_res['cumulative_return'], fin_res['all_trades']))
# Out:
# IXIC: Annualized return is [0.06708745], cumulative return is [0.13896003] and number of trades are 68.

# %% [markdown]
# ## Save Model

# %%
model1.save('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/model.h5")

# %% [markdown]
# ## Save true and pred

# %%
TruePred = pd.DataFrame(y_true, columns = [VarName])
TruePred['Prediction'] = y_pred
TruePred.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/True&Pred.csv")

# %% [markdown]
# ## Save Classification Metrics &  Save Times

# %%
Acc = np.float(accuracy_score(y_true=y_true, y_pred=y_pred))
#F1 = np.float(f1_score(y_true = y_true, y_pred = y_pred, average = 'macro'))
Prec = np.float(precision_score(y_true=y_true, y_pred=y_pred, average = 'macro'))
Recall = np.float(recall_score(y_true=y_true, y_pred=y_pred, average = 'macro'))

F1 = 2 * (Prec * Recall) / (Prec + Recall)

print(Acc, F1, Prec, Recall)
# Out:
# 0.44337811900191937 0.3777094061708632 0.37418600659264295 0.3812997903563941

# %%
np.savez('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/Time&ClassificationEval.npz",
         accuracy = Acc,
         MacF1 = F1,
         MacPrecision = Prec,
         MacRecall = Recall,
         TrainTime = np.float(total_training_time),
         PredTime = np.float(total_prediction_time)
        )

# %% [markdown]
# # Performance: N225

# %%
VarName = 'N225'

test_filename = "LW5_IW30/" + ts_direct + "/" + Test + "_" + VarName + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"

data_test = np.load('/content/drive/My Drive/Colab Notebooks/CNN/' + test_filename)

# %%
images_test = data_test['images']
image_labels_test = data_test['image_labels']
test_prices = data_test['price_at_image']

# %%
t0 = time.time()
image_labels_pred = model1.predict(images_test)
image_labels_pred = np.where(image_labels_pred > 0.5, 1, 0)
t1 = time.time()

total_prediction_time = t1-t0

# %%
y_true = np.argmax(image_labels_test,1) 
y_pred = np.argmax(image_labels_pred,1)

# %% [markdown]
# ## Confusion Matrix

# %%
cm =  pd.DataFrame(confusion_matrix(y_true, y_pred), 
                                 index = label_names_array, 
                                 columns = label_names_array)

plt.figure(figsize=[8,6])
sn.heatmap(cm, annot=True,cmap='Blues', fmt='g')

# %% [markdown]
# ## Classification Metrics

# %%
target_names = label_names_array
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         Sell       0.17      0.32      0.22        76
#          Buy       0.22      0.45      0.29        78
#         Hold       0.79      0.47      0.59       367
#
#     accuracy                           0.45       521
#    macro avg       0.39      0.41      0.37       521
# weighted avg       0.62      0.45      0.49       521

# %% [markdown]
# ## Financial Evaluation, Save predicton data in given format

# %%
#custom library
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/CNN/evaluation')
import financial_evaluation

# %%
# Create Signals from numbers here 
Signals = y_pred

prediction = pd.DataFrame(test_prices, columns = [VarName])
prediction['Signals'] = Signals
prediction['Signals'].loc[prediction['Signals'] == 0] = "Sell"
prediction['Signals'].loc[prediction['Signals'] == 1] = "Buy"
prediction['Signals'].loc[prediction['Signals'] == 2] = "Hold"
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#save results
prediction.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/PredForFinEval.csv")

# %%
fin_res = financial_evaluation.financial_evaluation(VarName, test_prices, prediction['Signals'], safety = True)
print(VarName + ": Annualized return is {}, cumulative return is {} and number of trades are {}.".format(fin_res['annualized_return'], fin_res['cumulative_return'], fin_res['all_trades']))
# Out:
# N225: Annualized return is [0.00754924], cumulative return is [0.01518484] and number of trades are 76.

# %% [markdown]
# ## Save Model

# %%
model1.save('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/model.h5")

# %% [markdown]
# ## Save true and pred

# %%
TruePred = pd.DataFrame(y_true, columns = [VarName])
TruePred['Prediction'] = y_pred
TruePred.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/True&Pred.csv")

# %% [markdown]
# ## Save Classification Metrics &  Save Times

# %%
Acc = np.float(accuracy_score(y_true=y_true, y_pred=y_pred))
#F1 = np.float(f1_score(y_true = y_true, y_pred = y_pred, average = 'macro'))
Prec = np.float(precision_score(y_true=y_true, y_pred=y_pred, average = 'macro'))
Recall = np.float(recall_score(y_true=y_true, y_pred=y_pred, average = 'macro'))

F1 = 2 * (Prec * Recall) / (Prec + Recall)

print(Acc, F1, Prec, Recall)
# Out:
# 0.4472168905950096 0.4032379843075027 0.3940415394168261 0.41287395460635096

# %%
np.savez('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/Time&ClassificationEval.npz",
         accuracy = Acc,
         MacF1 = F1,
         MacPrecision = Prec,
         MacRecall = Recall,
         TrainTime = np.float(total_training_time),
         PredTime = np.float(total_prediction_time)
        )

# %% [markdown]
# # Performance: SPY

# %%
VarName = 'SPY'

test_filename = "LW5_IW30/" + ts_direct + "/" + Test + "_" + VarName + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"

data_test = np.load('/content/drive/My Drive/Colab Notebooks/CNN/' + test_filename)

# %%
images_test = data_test['images']
image_labels_test = data_test['image_labels']
test_prices = data_test['price_at_image']

# %%
t0 = time.time()
image_labels_pred = model1.predict(images_test)
image_labels_pred = np.where(image_labels_pred > 0.5, 1, 0)
t1 = time.time()

total_prediction_time = t1-t0

# %%
y_true = np.argmax(image_labels_test,1) 
y_pred = np.argmax(image_labels_pred,1)

# %% [markdown]
# ## Confusion Matrix

# %%
cm =  pd.DataFrame(confusion_matrix(y_true, y_pred), 
                                 index = label_names_array, 
                                 columns = label_names_array)

plt.figure(figsize=[8,6])
sn.heatmap(cm, annot=True,cmap='Blues', fmt='g')

# %% [markdown]
# ## Classification Metrics

# %%
target_names = label_names_array
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         Sell       0.19      0.39      0.25        77
#          Buy       0.19      0.38      0.26        73
#         Hold       0.84      0.48      0.61       371
#
#     accuracy                           0.45       521
#    macro avg       0.40      0.42      0.37       521
# weighted avg       0.65      0.45      0.51       521

# %% [markdown]
# ## Time spent

# %%
total_training_time = sum(time_callback.times)
print("Time spent on entire model training: {:4f} seconds".format(total_training_time))
# Out:
# Time spent on entire model training: 1918.390671 seconds

# %% [markdown]
# ## Financial Evaluation, Save predicton data in given format

# %%
#custom library
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/CNN/evaluation')
import financial_evaluation

# %%
# Create Signals from numbers here 
Signals = y_pred

prediction = pd.DataFrame(test_prices, columns = [VarName])
prediction['Signals'] = Signals
prediction['Signals'].loc[prediction['Signals'] == 0] = "Sell"
prediction['Signals'].loc[prediction['Signals'] == 1] = "Buy"
prediction['Signals'].loc[prediction['Signals'] == 2] = "Hold"
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#save results
prediction.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/PredForFinEval.csv")

# %%
fin_res = financial_evaluation.financial_evaluation(VarName, test_prices, prediction['Signals'], safety = True)
print(VarName + ": Annualized return is {}, cumulative return is {} and number of trades are {}.".format(fin_res['annualized_return'], fin_res['cumulative_return'], fin_res['all_trades']))
# Out:
# SPY: Annualized return is [0.29263476], cumulative return is [0.67255504] and number of trades are 86.

# %% [markdown]
# ## Save Model

# %%
model1.save('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/model.h5")

# %% [markdown]
# ## Save true and pred

# %%
TruePred = pd.DataFrame(y_true, columns = [VarName])
TruePred['Prediction'] = y_pred
TruePred.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/True&Pred.csv")

# %% [markdown]
# ## Save Classification Metrics &  Save Times

# %%
Acc = np.float(accuracy_score(y_true=y_true, y_pred=y_pred))
#F1 = np.float(f1_score(y_true = y_true, y_pred = y_pred, average = 'macro'))
Prec = np.float(precision_score(y_true=y_true, y_pred=y_pred, average = 'macro'))
Recall = np.float(recall_score(y_true=y_true, y_pred=y_pred, average = 'macro'))

F1 = 2 * (Prec * Recall) / (Prec + Recall)

print(Acc, F1, Prec, Recall)
# Out:
# 0.45489443378119004 0.4115888739335778 0.4048549412584525 0.41855060593752763

# %%
np.savez('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/Time&ClassificationEval.npz",
         accuracy = Acc,
         MacF1 = F1,
         MacPrecision = Prec,
         MacRecall = Recall,
         TrainTime = np.float(total_training_time),
         PredTime = np.float(total_prediction_time)
        )
