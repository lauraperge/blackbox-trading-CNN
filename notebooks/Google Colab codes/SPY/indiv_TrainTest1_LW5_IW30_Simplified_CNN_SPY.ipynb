# %%
# !pip install numpy==1.16.1
# !pip install tensorflow-gpu==2.0.0-beta1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
from sklearn.model_selection import TimeSeriesSplit
from sklearn.utils import class_weight
from sklearn.metrics import f1_score, confusion_matrix, classification_report, accuracy_score, precision_score, recall_score
import time

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, AveragePooling2D, BatchNormalization, LeakyReLU
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam, Nadam, SGD, RMSprop
from tensorflow.keras.callbacks import EarlyStopping

LR = LeakyReLU(alpha = .3)
LR.__name__ = 'leakyrelu'

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Requirement already satisfied: numpy==1.16.1 in /usr/local/lib/python3.6/dist-packages (1.16.1)
# Requirement already satisfied: tensorflow-gpu==2.0.0-beta1 in /usr/local/lib/python3.6/dist-packages (2.0.0b1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.11.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.0.8)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.7.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.15.0)
# Requirement already satisfied: tb-nightly<1.14.0a20190604,>=1.14.0a20190603 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.14.0a20190603)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (3.7.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.2.2)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.8.0)
# Requirement already satisfied: tf-estimator-nightly<1.14.0.dev2019060502,>=1.14.0.dev2019060501 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.14.0.dev2019060501)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.12.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.1.7)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.33.4)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.16.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==2.0.0-beta1) (2.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (0.15.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (3.1.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (41.0.1)
# Found GPU at: /device:GPU:0

# %%
# fix random seed for reproducibility
seed = 2
np.random.seed(seed)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Pre-Settings

# %%
Test = "test1"
Version = "_indiv_" #="univ"
VarName = "SPY"

if Test == "test1":
  tr_direct = "data_train_to2005"
  ts_direct = "data_test_2005Decto_2007Dec"
elif Test == "test2":
  tr_direct = "data_train_to2008"
  ts_direct = "data_test_2009Jan_to_2011Jan"
else:
  tr_direct = "data_train_to2017May"
  ts_direct = "data_test_2017May_to_2019last"

# %% [markdown]
# # Load data

# %%
if Version == "_indiv_":
  train_filename = "LW5_IW30/" + tr_direct + "/" + Version[1:] + "train" + Test[-1] + "_" + VarName + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"
else:
  train_filename = "LW5_IW30/" + tr_direct + "/" + Version[1:] + "train" + Test[-1] + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"
  
test_filename = "LW5_IW30/" + ts_direct + "/" + Test + "_" + VarName + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"

# %% [markdown]
# ### Image window sizes

# %%
Image_window_size = np.int(train_filename[train_filename.find('_IWS') + 4 : train_filename.find("_Trf")])
Image_window_size
# Out:
# 30

# %% [markdown]
# ### Transformation types

# %%
Image_trf = eval(train_filename[train_filename.find('_Trf')+4:train_filename.find('.npz')])
Image_trf
# Out:
# ['RP', 'GASF', 'MTF']

# %%
num_color_channels = len(Image_trf)
num_color_channels
# Out:
# 3

# %% [markdown]
# #### In case file is missing run the data-check-and-prep with preferred settings and use the new file's name (cannot upload too big files to Git)

# %%
data_train = np.load('/content/drive/My Drive/Colab Notebooks/CNN/' + train_filename)
data_test = np.load('/content/drive/My Drive/Colab Notebooks/CNN/' + test_filename)

# %%
images_train = data_train['images']
images_test = data_test['images']
image_labels_train = data_train['image_labels']
image_labels_test = data_test['image_labels']
train_prices = data_train['price_at_image']
test_prices = data_test['price_at_image']

label_names = data_train['label_names'] # same everywhere

# %% [markdown]
# # Check data

# %%
image_labels_train.shape
# Out:
# (3339, 3)

# %% [markdown]
# Get label names array for later visualization

# %%
label_names = label_names.item()
label_names
# Out:
# {0: 'Sell', 1: 'Buy', 2: 'Hold'}

# %%
label_names_array = np.chararray(3, itemsize = 4).decode("utf-8")

for key, value in label_names.items():
  label_names_array[key] = value
label_names_array
# Out:
# array(['Sell', 'Buy', 'Hold'], dtype='<U4')

# %% [markdown]
# ## e.g.:

# %%
for trfidx, trf in enumerate(Image_trf):
    print('Transformation type: ' + trf)
    for idx, image in enumerate(images_train[:2,:,:, trfidx]):
        plt.imshow(image, cmap = "Greys")
        plt.title(label_names[np.int(np.argwhere(image_labels_train[idx]))])
        plt.show()
# Out:
# Transformation type: RP
# Transformation type: GASF
# Transformation type: MTF

# %%
print("Train images shape : {}; Train labels shape : {}".format(images_train.shape, image_labels_train.shape))
# Out:
# Train images shape : (3339, 30, 30, 3); Train labels shape : (3339, 3)

# %%
print("Test images shape : {}; Test labels shape : {}".format(images_test.shape, image_labels_test.shape))
# Out:
# Test images shape : (519, 30, 30, 3); Test labels shape : (519, 3)

# %% [markdown]
# # Baseline predictions
# Choosing the biggest class to be the class of all

# %%
basepred = np.zeros(image_labels_test.shape)
basepred[:, np.argmax(np.sum(image_labels_test, 0))] = 1.0

base_acc = sum(np.equal(np.argmax(basepred, 1), np.argmax(image_labels_test, 1)))/np.sum(image_labels_test)
base_f1 = f1_score(y_true = image_labels_test, y_pred = basepred, average = 'macro')
# warning F1 due to only label 2 being predicted in baseline

print("Accuracy: {:.5f}".format(base_acc))
print("Categorical Accuracy: {:.5f}".format(accuracy_score(np.argmax(basepred, 1), np.argmax(image_labels_test, 1))))

print("F1 score: {:.5f}".format(base_f1))

print(classification_report(np.argmax(basepred, 1), np.argmax(image_labels_test, 1)))
# Out:
# Accuracy: 0.73410
# Categorical Accuracy: 0.73410
# F1 score: 0.28222
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         0
#            2       1.00      0.73      0.85       519
#
#     accuracy                           0.73       519
#    macro avg       0.33      0.24      0.28       519
# weighted avg       1.00      0.73      0.85       519
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %% [markdown]
# # The Deep CNN

# %% [markdown]
# ### Custom Keras Eval metrics: F1 Score
# https://medium.com/@thongonary/how-to-compute-f1-score-for-each-epoch-in-keras-a1acd17715a2

# %%
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import fbeta_score

# Some default constants

START = 0.5
END = 0.95
STEP = 0.05
N_STEPS = int((END - START) / STEP) + 2
DEFAULT_THRESHOLDS = np.linspace(START, END, N_STEPS)
DEFAULT_BETA = 1
DEFAULT_LOGS = {}
FBETA_METRIC_NAME = "val_fbeta"

class FBetaMetricCallback(Callback):

    def __init__(self, beta=DEFAULT_BETA, thresholds=DEFAULT_THRESHOLDS):
        self.beta = beta
        self.thresholds = thresholds
        # Will be initialized when the training starts
        self.val_fbeta = None

    def on_train_begin(self, logs=DEFAULT_LOGS):
        """ This is where the validation Fbeta
        validation scores will be saved during training: one value per
        epoch.
        """
        self.val_fbeta = []

    def _score_per_threshold(self, predictions, targets, threshold):
        """ Compute the Fbeta score per threshold.
        """
        # Notice that here I am using the sklearn fbeta_score function.
        # You can read more about it here:
        # http://scikit-learn.org/stable/modules/generated/sklearn.metrics.fbeta_score.html
        thresholded_predictions = (predictions > threshold).astype(int)
        return fbeta_score(targets, thresholded_predictions, beta=self.beta)

    def on_epoch_end(self, epoch, logs=DEFAULT_LOGS):
        val_predictions = self.model.predict(self.validation_data[0])
        val_targets = self.validation_data[1]
        _val_fbeta = np.mean([self._score_per_threshold(val_predictions,
                                                        val_targets, threshold)
                              for threshold in self.thresholds])
        self.val_fbeta.append(_val_fbeta)
        print("Current F{} metric is: {}".format(str(self.beta), str(_val_fbeta)))
        return

    def on_train_end(self, logs=DEFAULT_LOGS):
        """ Assign the validation Fbeta computed metric to the History object.
        """
        self.model.history.history[FBETA_METRIC_NAME] = self.val_fbeta
        
f1_score = FBetaMetricCallback(beta=1)

# %% [markdown]
# ### Custom Time Logging

# %%
import tensorflow.keras.callbacks as keras_cb

class TimeHistory(keras_cb.Callback):
  def on_train_begin(self, logs={}):
    self.times = []

  def on_epoch_begin(self, epoch, logs={}):
    self.epoch_time_start = time.time()

  def on_epoch_end(self, epoch, logs={}):
    self.times.append(time.time() - self.epoch_time_start)

time_callback = TimeHistory()

# %% [markdown]
# ### Network Parameters

# %%
# image shape (d x d)
n_input = images_train.shape[1]
inputShape = (n_input, n_input, num_color_channels)

# number of classes
n_classes =  image_labels_train.shape[1]

# dropout
to_drop = 0.3 # prob. to DROP

# %% [markdown]
# ## Building the model

# %%
def createModel(input_shape, dropout = .2):
    model = Sequential()
    # Input
    model.add(Conv2D(32, 
                     (3, 3), 
                     padding='same', 
                     activation=LR, 
                     input_shape=input_shape
                    ))
    model.add(BatchNormalization())
    # model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))
    
    # 1Convolution,relu then pooling
    model.add(Conv2D(64, (3, 3), 
                     padding='same', 
                     activation=LR,
                     kernel_regularizer=regularizers.l2(0.01)
                    ))
    model.add(BatchNormalization())
    model.add(AveragePooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))
    
    # Flatten & Dense layers 
    model.add(Flatten())
    
    model.add(Dense(128, activation=LR, kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(Dropout(.5))
    model.add(Dense(n_classes, activation='softmax'))
  
    return model

# %%
model1 = createModel(dropout = to_drop, input_shape = inputShape)
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 30, 30, 32)        128
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 64)        256
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 15, 15, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 15, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 14400)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1843328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 1,864,003
# Trainable params: 1,863,555
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# ## Hyperparameter settings

# %%
training_iters = 450
batch_size = 150

# %% [markdown]
# ### Accounting for imbalance

# %%
label_names
# Out:
# {0: 'Sell', 1: 'Buy', 2: 'Hold'}

# %%
np.sum(image_labels_train, axis = 0)/np.sum(image_labels_train)
# Out:
# array([0.14195867, 0.14555256, 0.71248877])

# %%
y_ints = [y.argmax() for y in image_labels_train]
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_ints),
                                                 y_ints)
class_weight_dict = dict(enumerate(class_weights))
class_weight_dict
# Out:
# {0: 2.348101265822785, 1: 2.2901234567901234, 2: 0.467843631778058}

# %% [markdown]
# ## Compiling

# %%
model1.compile(optimizer=SGD(nesterov=True),#Adam(lr=0.0001, amsgrad = True), #Nadam(lr=0.0005), #
               loss='kullback_leibler_divergence', 
               metrics=['categorical_accuracy'])

# %% [markdown]
# ## Training

# %%
es2 = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
history = model1.fit(images_train, 
                     image_labels_train, 
                     batch_size=batch_size, 
                     epochs=training_iters, verbose=1,
                     validation_data=(images_test, image_labels_test),
                     class_weight=class_weight_dict,
                     callbacks=[time_callback, es2]
                    )
  
model1.evaluate(images_test, image_labels_test)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0706 15:07:25.238730 140612042360704 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 3339 samples, validate on 519 samples
# Epoch 1/450
# 3339/3339 [==============================] - 7s 2ms/sample - loss: 4.9048 - categorical_accuracy: 0.3411 - val_loss: 4.1265 - val_categorical_accuracy: 0.1349
# Epoch 2/450
# 3339/3339 [==============================] - 1s 352us/sample - loss: 4.5623 - categorical_accuracy: 0.3549 - val_loss: 4.1276 - val_categorical_accuracy: 0.1407
# Epoch 3/450
# 3339/3339 [==============================] - 1s 330us/sample - loss: 4.3669 - categorical_accuracy: 0.3726 - val_loss: 4.1113 - val_categorical_accuracy: 0.1387
# Epoch 4/450
# 3339/3339 [==============================] - 1s 317us/sample - loss: 4.2807 - categorical_accuracy: 0.3783 - val_loss: 4.1995 - val_categorical_accuracy: 0.1387
# Epoch 5/450
# 3339/3339 [==============================] - 1s 327us/sample - loss: 4.1080 - categorical_accuracy: 0.4037 - val_loss: 4.2020 - val_categorical_accuracy: 0.1387
# Epoch 6/450
# 3339/3339 [==============================] - 1s 321us/sample - loss: 4.0513 - categorical_accuracy: 0.4181 - val_loss: 4.2546 - val_categorical_accuracy: 0.1387
# Epoch 7/450
# 3339/3339 [==============================] - 1s 304us/sample - loss: 3.9876 - categorical_accuracy: 0.4232 - val_loss: 4.1662 - val_categorical_accuracy: 0.1387
# Epoch 8/450
# 3339/3339 [==============================] - 1s 317us/sample - loss: 3.9315 - categorical_accuracy: 0.4115 - val_loss: 4.1778 - val_categorical_accuracy: 0.1387
# Epoch 9/450
# 3339/3339 [==============================] - 1s 327us/sample - loss: 3.8519 - categorical_accuracy: 0.4370 - val_loss: 4.1101 - val_categorical_accuracy: 0.1387
# Epoch 10/450
# 3339/3339 [==============================] - 1s 329us/sample - loss: 3.7929 - categorical_accuracy: 0.4465 - val_loss: 4.0773 - val_categorical_accuracy: 0.1387
# Epoch 11/450
# 3339/3339 [==============================] - 1s 312us/sample - loss: 3.7569 - categorical_accuracy: 0.4561 - val_loss: 4.0414 - val_categorical_accuracy: 0.1387
# Epoch 12/450
# 3339/3339 [==============================] - 1s 316us/sample - loss: 3.6831 - categorical_accuracy: 0.4768 - val_loss: 3.9864 - val_categorical_accuracy: 0.1407
# Epoch 13/450
# 3339/3339 [==============================] - 1s 331us/sample - loss: 3.6393 - categorical_accuracy: 0.4714 - val_loss: 3.9198 - val_categorical_accuracy: 0.1426
# Epoch 14/450
# 3339/3339 [==============================] - 1s 324us/sample - loss: 3.5740 - categorical_accuracy: 0.4897 - val_loss: 3.9130 - val_categorical_accuracy: 0.1464
# Epoch 15/450
# 3339/3339 [==============================] - 1s 308us/sample - loss: 3.5371 - categorical_accuracy: 0.4927 - val_loss: 3.8130 - val_categorical_accuracy: 0.1965
# Epoch 16/450
# 3339/3339 [==============================] - 1s 308us/sample - loss: 3.4779 - categorical_accuracy: 0.5157 - val_loss: 3.7900 - val_categorical_accuracy: 0.2177
# Epoch 17/450
# 3339/3339 [==============================] - 1s 333us/sample - loss: 3.4673 - categorical_accuracy: 0.5085 - val_loss: 3.7612 - val_categorical_accuracy: 0.2254
# Epoch 18/450
# 3339/3339 [==============================] - 1s 330us/sample - loss: 3.4136 - categorical_accuracy: 0.5145 - val_loss: 3.7150 - val_categorical_accuracy: 0.2370
# Epoch 19/450
# 3339/3339 [==============================] - 1s 325us/sample - loss: 3.3993 - categorical_accuracy: 0.5184 - val_loss: 3.7044 - val_categorical_accuracy: 0.2543
# Epoch 20/450
# 3339/3339 [==============================] - 1s 307us/sample - loss: 3.3319 - categorical_accuracy: 0.5310 - val_loss: 3.6727 - val_categorical_accuracy: 0.2755
# Epoch 21/450
# 3339/3339 [==============================] - 1s 325us/sample - loss: 3.2926 - categorical_accuracy: 0.5415 - val_loss: 3.6391 - val_categorical_accuracy: 0.2909
# Epoch 22/450
# 3339/3339 [==============================] - 1s 313us/sample - loss: 3.2884 - categorical_accuracy: 0.5319 - val_loss: 3.5542 - val_categorical_accuracy: 0.3834
# Epoch 23/450
# 3339/3339 [==============================] - 1s 332us/sample - loss: 3.2330 - categorical_accuracy: 0.5439 - val_loss: 3.5232 - val_categorical_accuracy: 0.3950
# Epoch 24/450
# 3339/3339 [==============================] - 1s 315us/sample - loss: 3.2017 - categorical_accuracy: 0.5508 - val_loss: 3.5329 - val_categorical_accuracy: 0.3642
# Epoch 25/450
# 3339/3339 [==============================] - 1s 323us/sample - loss: 3.1658 - categorical_accuracy: 0.5645 - val_loss: 3.5232 - val_categorical_accuracy: 0.3642
# Epoch 26/450
# 3339/3339 [==============================] - 1s 333us/sample - loss: 3.1167 - categorical_accuracy: 0.5723 - val_loss: 3.4831 - val_categorical_accuracy: 0.3776
# Epoch 27/450
# 3339/3339 [==============================] - 1s 325us/sample - loss: 3.0981 - categorical_accuracy: 0.5630 - val_loss: 3.4612 - val_categorical_accuracy: 0.3661
# Epoch 28/450
# 3339/3339 [==============================] - 1s 323us/sample - loss: 3.0785 - categorical_accuracy: 0.5747 - val_loss: 3.4152 - val_categorical_accuracy: 0.3834
# Epoch 29/450
# 3339/3339 [==============================] - 1s 327us/sample - loss: 3.0499 - categorical_accuracy: 0.5759 - val_loss: 3.4143 - val_categorical_accuracy: 0.3911
# Epoch 30/450
# 3339/3339 [==============================] - 1s 313us/sample - loss: 3.0074 - categorical_accuracy: 0.5900 - val_loss: 3.3827 - val_categorical_accuracy: 0.4123
# Epoch 31/450
# 3339/3339 [==============================] - 1s 327us/sample - loss: 2.9794 - categorical_accuracy: 0.6017 - val_loss: 3.4078 - val_categorical_accuracy: 0.3776
# Epoch 32/450
# 3339/3339 [==============================] - 1s 328us/sample - loss: 2.9469 - categorical_accuracy: 0.5891 - val_loss: 3.3770 - val_categorical_accuracy: 0.3892
# Epoch 33/450
# 3339/3339 [==============================] - 1s 315us/sample - loss: 2.9055 - categorical_accuracy: 0.6056 - val_loss: 3.3338 - val_categorical_accuracy: 0.4277
# Epoch 34/450
# 3339/3339 [==============================] - 1s 329us/sample - loss: 2.8719 - categorical_accuracy: 0.6208 - val_loss: 3.3109 - val_categorical_accuracy: 0.4085
# Epoch 35/450
# 3339/3339 [==============================] - 1s 310us/sample - loss: 2.8654 - categorical_accuracy: 0.6143 - val_loss: 3.3134 - val_categorical_accuracy: 0.4143
# Epoch 36/450
# 3339/3339 [==============================] - 1s 329us/sample - loss: 2.8527 - categorical_accuracy: 0.6173 - val_loss: 3.2891 - val_categorical_accuracy: 0.4277
# Epoch 37/450
# 3339/3339 [==============================] - 1s 322us/sample - loss: 2.8048 - categorical_accuracy: 0.6370 - val_loss: 3.3087 - val_categorical_accuracy: 0.4008
# Epoch 38/450
# 3339/3339 [==============================] - 1s 324us/sample - loss: 2.7570 - categorical_accuracy: 0.6364 - val_loss: 3.2105 - val_categorical_accuracy: 0.4547
# Epoch 39/450
# 3339/3339 [==============================] - 1s 317us/sample - loss: 2.7515 - categorical_accuracy: 0.6373 - val_loss: 3.2519 - val_categorical_accuracy: 0.4066
# Epoch 40/450
# 3339/3339 [==============================] - 1s 311us/sample - loss: 2.7054 - categorical_accuracy: 0.6547 - val_loss: 3.1898 - val_categorical_accuracy: 0.4528
# Epoch 41/450
# 3339/3339 [==============================] - 1s 313us/sample - loss: 2.6828 - categorical_accuracy: 0.6526 - val_loss: 3.2034 - val_categorical_accuracy: 0.4200
# Epoch 42/450
# 3339/3339 [==============================] - 1s 321us/sample - loss: 2.6439 - categorical_accuracy: 0.6622 - val_loss: 3.2399 - val_categorical_accuracy: 0.4066
# Epoch 43/450
# 3339/3339 [==============================] - 1s 329us/sample - loss: 2.6393 - categorical_accuracy: 0.6532 - val_loss: 3.2157 - val_categorical_accuracy: 0.4123
# Epoch 44/450
# 3339/3339 [==============================] - 1s 319us/sample - loss: 2.6099 - categorical_accuracy: 0.6697 - val_loss: 3.1962 - val_categorical_accuracy: 0.3988
# Epoch 45/450
# 3339/3339 [==============================] - 1s 323us/sample - loss: 2.5679 - categorical_accuracy: 0.6742 - val_loss: 3.1266 - val_categorical_accuracy: 0.4605
# Epoch 46/450
# 3339/3339 [==============================] - 1s 315us/sample - loss: 2.5680 - categorical_accuracy: 0.6733 - val_loss: 3.1850 - val_categorical_accuracy: 0.4104
# Epoch 47/450
# 3339/3339 [==============================] - 1s 313us/sample - loss: 2.5356 - categorical_accuracy: 0.6751 - val_loss: 3.1233 - val_categorical_accuracy: 0.4432
# Epoch 48/450
# 3339/3339 [==============================] - 1s 348us/sample - loss: 2.4891 - categorical_accuracy: 0.6888 - val_loss: 3.1126 - val_categorical_accuracy: 0.4335
# Epoch 49/450
# 3339/3339 [==============================] - 1s 336us/sample - loss: 2.4796 - categorical_accuracy: 0.7002 - val_loss: 3.1121 - val_categorical_accuracy: 0.4432
# Epoch 50/450
# 3339/3339 [==============================] - 1s 322us/sample - loss: 2.4806 - categorical_accuracy: 0.6930 - val_loss: 3.0636 - val_categorical_accuracy: 0.4509
# Epoch 51/450
# 3339/3339 [==============================] - 1s 342us/sample - loss: 2.4400 - categorical_accuracy: 0.6948 - val_loss: 3.0558 - val_categorical_accuracy: 0.4547
# Epoch 52/450
# 3339/3339 [==============================] - 1s 326us/sample - loss: 2.4061 - categorical_accuracy: 0.6996 - val_loss: 3.0444 - val_categorical_accuracy: 0.4451
# Epoch 53/450
# 3339/3339 [==============================] - 1s 315us/sample - loss: 2.4159 - categorical_accuracy: 0.6951 - val_loss: 2.9915 - val_categorical_accuracy: 0.4644
# Epoch 54/450
# 3339/3339 [==============================] - 1s 312us/sample - loss: 2.3727 - categorical_accuracy: 0.7137 - val_loss: 2.9430 - val_categorical_accuracy: 0.5087
# Epoch 55/450
# 3339/3339 [==============================] - 1s 315us/sample - loss: 2.3366 - categorical_accuracy: 0.7185 - val_loss: 3.0054 - val_categorical_accuracy: 0.4586
# Epoch 56/450
# 3339/3339 [==============================] - 1s 313us/sample - loss: 2.3223 - categorical_accuracy: 0.7161 - val_loss: 2.9507 - val_categorical_accuracy: 0.4875
# Epoch 57/450
# 3339/3339 [==============================] - 1s 313us/sample - loss: 2.2757 - categorical_accuracy: 0.7320 - val_loss: 2.8969 - val_categorical_accuracy: 0.5048
# Epoch 58/450
# 3339/3339 [==============================] - 1s 305us/sample - loss: 2.2631 - categorical_accuracy: 0.7361 - val_loss: 2.8920 - val_categorical_accuracy: 0.4933
# Epoch 59/450
# 3339/3339 [==============================] - 1s 336us/sample - loss: 2.2594 - categorical_accuracy: 0.7403 - val_loss: 3.0262 - val_categorical_accuracy: 0.4316
# Epoch 60/450
# 3339/3339 [==============================] - 1s 325us/sample - loss: 2.2316 - categorical_accuracy: 0.7293 - val_loss: 3.0047 - val_categorical_accuracy: 0.4393
# Epoch 61/450
# 3339/3339 [==============================] - 1s 328us/sample - loss: 2.2081 - categorical_accuracy: 0.7427 - val_loss: 2.9300 - val_categorical_accuracy: 0.4701
# Epoch 62/450
# 3339/3339 [==============================] - 1s 317us/sample - loss: 2.1747 - categorical_accuracy: 0.7565 - val_loss: 2.9477 - val_categorical_accuracy: 0.4509
# Epoch 63/450
# 3339/3339 [==============================] - 1s 336us/sample - loss: 2.1480 - categorical_accuracy: 0.7520 - val_loss: 2.8980 - val_categorical_accuracy: 0.4875
# Epoch 64/450
# 3339/3339 [==============================] - 1s 336us/sample - loss: 2.1377 - categorical_accuracy: 0.7493 - val_loss: 2.9177 - val_categorical_accuracy: 0.4644
# Epoch 65/450
# 3339/3339 [==============================] - 1s 328us/sample - loss: 2.1155 - categorical_accuracy: 0.7574 - val_loss: 2.8821 - val_categorical_accuracy: 0.4778
# Epoch 66/450
# 3339/3339 [==============================] - 1s 315us/sample - loss: 2.1047 - categorical_accuracy: 0.7523 - val_loss: 2.9064 - val_categorical_accuracy: 0.4682
# Epoch 67/450
# 3339/3339 [==============================] - 1s 326us/sample - loss: 2.0781 - categorical_accuracy: 0.7655 - val_loss: 2.8285 - val_categorical_accuracy: 0.5087
# Epoch 68/450
# 3339/3339 [==============================] - 1s 317us/sample - loss: 2.0675 - categorical_accuracy: 0.7556 - val_loss: 2.8662 - val_categorical_accuracy: 0.4933
# Epoch 69/450
# 3339/3339 [==============================] - 1s 320us/sample - loss: 2.0405 - categorical_accuracy: 0.7586 - val_loss: 2.8571 - val_categorical_accuracy: 0.4721
# Epoch 70/450
# 3339/3339 [==============================] - 1s 303us/sample - loss: 2.0235 - categorical_accuracy: 0.7739 - val_loss: 2.7966 - val_categorical_accuracy: 0.4990
# Epoch 71/450
# 3339/3339 [==============================] - 1s 324us/sample - loss: 1.9882 - categorical_accuracy: 0.7772 - val_loss: 2.7955 - val_categorical_accuracy: 0.4817
# Epoch 72/450
# 3339/3339 [==============================] - 1s 321us/sample - loss: 2.0023 - categorical_accuracy: 0.7766 - val_loss: 2.7512 - val_categorical_accuracy: 0.5260
# Epoch 73/450
# 3339/3339 [==============================] - 1s 322us/sample - loss: 1.9685 - categorical_accuracy: 0.7781 - val_loss: 2.8040 - val_categorical_accuracy: 0.4971
# Epoch 74/450
# 3339/3339 [==============================] - 1s 315us/sample - loss: 1.9541 - categorical_accuracy: 0.7808 - val_loss: 2.7602 - val_categorical_accuracy: 0.4971
# Epoch 75/450
# 3339/3339 [==============================] - 1s 316us/sample - loss: 1.9428 - categorical_accuracy: 0.7892 - val_loss: 2.7617 - val_categorical_accuracy: 0.4990
# Epoch 76/450
# 3339/3339 [==============================] - 1s 338us/sample - loss: 1.8948 - categorical_accuracy: 0.7940 - val_loss: 2.8309 - val_categorical_accuracy: 0.4644
# Epoch 77/450
# 3339/3339 [==============================] - 1s 318us/sample - loss: 1.9017 - categorical_accuracy: 0.7931 - val_loss: 2.7050 - val_categorical_accuracy: 0.5125
# Epoch 78/450
# 3339/3339 [==============================] - 1s 320us/sample - loss: 1.8807 - categorical_accuracy: 0.7981 - val_loss: 2.6742 - val_categorical_accuracy: 0.5125
# Epoch 79/450
# 3339/3339 [==============================] - 1s 311us/sample - loss: 1.8545 - categorical_accuracy: 0.7984 - val_loss: 2.7359 - val_categorical_accuracy: 0.4933
# Epoch 80/450
# 3339/3339 [==============================] - 1s 306us/sample - loss: 1.8447 - categorical_accuracy: 0.7948 - val_loss: 2.7345 - val_categorical_accuracy: 0.4855
# Epoch 81/450
# 3339/3339 [==============================] - 1s 317us/sample - loss: 1.8429 - categorical_accuracy: 0.7937 - val_loss: 2.6669 - val_categorical_accuracy: 0.5202
# Epoch 82/450
# 3339/3339 [==============================] - 1s 314us/sample - loss: 1.8297 - categorical_accuracy: 0.7937 - val_loss: 2.7225 - val_categorical_accuracy: 0.4836
# Epoch 83/450
# 3339/3339 [==============================] - 1s 327us/sample - loss: 1.7815 - categorical_accuracy: 0.8131 - val_loss: 2.6011 - val_categorical_accuracy: 0.5434
# Epoch 84/450
# 3339/3339 [==============================] - 1s 311us/sample - loss: 1.7740 - categorical_accuracy: 0.8062 - val_loss: 2.5980 - val_categorical_accuracy: 0.5607
# Epoch 85/450
# 3339/3339 [==============================] - 1s 309us/sample - loss: 1.7666 - categorical_accuracy: 0.8080 - val_loss: 2.6505 - val_categorical_accuracy: 0.5318
# Epoch 86/450
# 3339/3339 [==============================] - 1s 333us/sample - loss: 1.7389 - categorical_accuracy: 0.8155 - val_loss: 2.5945 - val_categorical_accuracy: 0.5588
# Epoch 87/450
# 3339/3339 [==============================] - 1s 342us/sample - loss: 1.7249 - categorical_accuracy: 0.8185 - val_loss: 2.5863 - val_categorical_accuracy: 0.5491
# Epoch 88/450
# 3339/3339 [==============================] - 1s 308us/sample - loss: 1.7166 - categorical_accuracy: 0.8194 - val_loss: 2.6425 - val_categorical_accuracy: 0.5183
# Epoch 89/450
# 3339/3339 [==============================] - 1s 338us/sample - loss: 1.6951 - categorical_accuracy: 0.8191 - val_loss: 2.6138 - val_categorical_accuracy: 0.5356
# Epoch 90/450
# 3339/3339 [==============================] - 1s 355us/sample - loss: 1.6914 - categorical_accuracy: 0.8167 - val_loss: 2.6111 - val_categorical_accuracy: 0.5318
# Epoch 91/450
# 3339/3339 [==============================] - 1s 306us/sample - loss: 1.6664 - categorical_accuracy: 0.8356 - val_loss: 2.4803 - val_categorical_accuracy: 0.5934
# Epoch 92/450
# 3339/3339 [==============================] - 1s 310us/sample - loss: 1.6516 - categorical_accuracy: 0.8302 - val_loss: 2.6196 - val_categorical_accuracy: 0.5241
# Epoch 93/450
# 3339/3339 [==============================] - 1s 316us/sample - loss: 1.6383 - categorical_accuracy: 0.8272 - val_loss: 2.6470 - val_categorical_accuracy: 0.5106
# Epoch 94/450
# 3339/3339 [==============================] - 1s 305us/sample - loss: 1.6141 - categorical_accuracy: 0.8302 - val_loss: 2.6116 - val_categorical_accuracy: 0.5202
# Epoch 95/450
# 3339/3339 [==============================] - 1s 309us/sample - loss: 1.6097 - categorical_accuracy: 0.8398 - val_loss: 2.5721 - val_categorical_accuracy: 0.5260
# Epoch 96/450
# 3339/3339 [==============================] - 1s 329us/sample - loss: 1.5790 - categorical_accuracy: 0.8392 - val_loss: 2.5393 - val_categorical_accuracy: 0.5337
# Epoch 97/450
# 3339/3339 [==============================] - 1s 321us/sample - loss: 1.5828 - categorical_accuracy: 0.8443 - val_loss: 2.4509 - val_categorical_accuracy: 0.5896
# Epoch 98/450
# 3339/3339 [==============================] - 1s 306us/sample - loss: 1.5578 - categorical_accuracy: 0.8521 - val_loss: 2.5010 - val_categorical_accuracy: 0.5626
# Epoch 99/450
# 3339/3339 [==============================] - 1s 316us/sample - loss: 1.5261 - categorical_accuracy: 0.8583 - val_loss: 2.5305 - val_categorical_accuracy: 0.5453
# Epoch 100/450
# 3339/3339 [==============================] - 1s 325us/sample - loss: 1.5286 - categorical_accuracy: 0.8437 - val_loss: 2.5522 - val_categorical_accuracy: 0.5299
# Epoch 101/450
# 3339/3339 [==============================] - 1s 312us/sample - loss: 1.5169 - categorical_accuracy: 0.8518 - val_loss: 2.5941 - val_categorical_accuracy: 0.5202
# Epoch 102/450
# 3339/3339 [==============================] - 1s 312us/sample - loss: 1.4898 - categorical_accuracy: 0.8598 - val_loss: 2.5333 - val_categorical_accuracy: 0.5318
# Epoch 103/450
# 3339/3339 [==============================] - 1s 327us/sample - loss: 1.5035 - categorical_accuracy: 0.8521 - val_loss: 2.4923 - val_categorical_accuracy: 0.5684
# Epoch 104/450
# 3339/3339 [==============================] - 1s 316us/sample - loss: 1.4728 - categorical_accuracy: 0.8583 - val_loss: 2.5226 - val_categorical_accuracy: 0.5530
# Epoch 105/450
# 3339/3339 [==============================] - 1s 316us/sample - loss: 1.4695 - categorical_accuracy: 0.8503 - val_loss: 2.5486 - val_categorical_accuracy: 0.5222
# Epoch 106/450
# 3339/3339 [==============================] - 1s 319us/sample - loss: 1.4513 - categorical_accuracy: 0.8661 - val_loss: 2.4596 - val_categorical_accuracy: 0.5742
# Epoch 107/450
# 3339/3339 [==============================] - 1s 327us/sample - loss: 1.4481 - categorical_accuracy: 0.8524 - val_loss: 2.4391 - val_categorical_accuracy: 0.5626
# Epoch 108/450
# 3339/3339 [==============================] - 1s 304us/sample - loss: 1.4252 - categorical_accuracy: 0.8604 - val_loss: 2.4139 - val_categorical_accuracy: 0.5568
# Epoch 109/450
# 3339/3339 [==============================] - 1s 336us/sample - loss: 1.3984 - categorical_accuracy: 0.8676 - val_loss: 2.4784 - val_categorical_accuracy: 0.5376
# Epoch 110/450
# 3339/3339 [==============================] - 1s 329us/sample - loss: 1.4005 - categorical_accuracy: 0.8625 - val_loss: 2.4818 - val_categorical_accuracy: 0.5241
# Epoch 111/450
# 3339/3339 [==============================] - 1s 327us/sample - loss: 1.3890 - categorical_accuracy: 0.8682 - val_loss: 2.4526 - val_categorical_accuracy: 0.5511
# Epoch 112/450
# 3339/3339 [==============================] - 1s 314us/sample - loss: 1.3707 - categorical_accuracy: 0.8751 - val_loss: 2.4636 - val_categorical_accuracy: 0.5222
# Epoch 113/450
# 3339/3339 [==============================] - 1s 335us/sample - loss: 1.3540 - categorical_accuracy: 0.8691 - val_loss: 2.4413 - val_categorical_accuracy: 0.5453
# Epoch 114/450
# 3339/3339 [==============================] - 1s 322us/sample - loss: 1.3488 - categorical_accuracy: 0.8760 - val_loss: 2.4223 - val_categorical_accuracy: 0.5511
# Epoch 115/450
# 3339/3339 [==============================] - 1s 304us/sample - loss: 1.3390 - categorical_accuracy: 0.8802 - val_loss: 2.4501 - val_categorical_accuracy: 0.5588
# Epoch 116/450
# 3339/3339 [==============================] - 1s 313us/sample - loss: 1.3376 - categorical_accuracy: 0.8739 - val_loss: 2.5463 - val_categorical_accuracy: 0.5029
# Epoch 117/450
# 3339/3339 [==============================] - 1s 303us/sample - loss: 1.3179 - categorical_accuracy: 0.8754 - val_loss: 2.4487 - val_categorical_accuracy: 0.5356
# Epoch 118/450
# 3339/3339 [==============================] - 1s 318us/sample - loss: 1.3119 - categorical_accuracy: 0.8793 - val_loss: 2.4318 - val_categorical_accuracy: 0.5337
# Epoch 119/450
# 3339/3339 [==============================] - 1s 324us/sample - loss: 1.3024 - categorical_accuracy: 0.8856 - val_loss: 2.4920 - val_categorical_accuracy: 0.5395
# Epoch 120/450
# 3339/3339 [==============================] - 1s 324us/sample - loss: 1.2649 - categorical_accuracy: 0.8931 - val_loss: 2.4636 - val_categorical_accuracy: 0.5395
# Epoch 121/450
# 3339/3339 [==============================] - 1s 309us/sample - loss: 1.2621 - categorical_accuracy: 0.8862 - val_loss: 2.4110 - val_categorical_accuracy: 0.5472
# Epoch 122/450
# 3339/3339 [==============================] - 1s 315us/sample - loss: 1.2599 - categorical_accuracy: 0.8913 - val_loss: 2.4017 - val_categorical_accuracy: 0.5568
# Epoch 123/450
# 3339/3339 [==============================] - 1s 319us/sample - loss: 1.2500 - categorical_accuracy: 0.8856 - val_loss: 2.4115 - val_categorical_accuracy: 0.5472
# Epoch 124/450
# 3339/3339 [==============================] - 1s 316us/sample - loss: 1.2378 - categorical_accuracy: 0.8955 - val_loss: 2.3512 - val_categorical_accuracy: 0.5800
# Epoch 125/450
# 3339/3339 [==============================] - 1s 318us/sample - loss: 1.2170 - categorical_accuracy: 0.8895 - val_loss: 2.3622 - val_categorical_accuracy: 0.5588
# Epoch 126/450
# 3339/3339 [==============================] - 1s 316us/sample - loss: 1.2127 - categorical_accuracy: 0.8889 - val_loss: 2.3210 - val_categorical_accuracy: 0.5684
# Epoch 127/450
# 3339/3339 [==============================] - 1s 324us/sample - loss: 1.2246 - categorical_accuracy: 0.8853 - val_loss: 2.3919 - val_categorical_accuracy: 0.5530
# Epoch 128/450
# 3339/3339 [==============================] - 1s 314us/sample - loss: 1.1872 - categorical_accuracy: 0.9045 - val_loss: 2.3641 - val_categorical_accuracy: 0.5530
# Epoch 129/450
# 3339/3339 [==============================] - 1s 315us/sample - loss: 1.1688 - categorical_accuracy: 0.9057 - val_loss: 2.3187 - val_categorical_accuracy: 0.5665
# Epoch 130/450
# 3339/3339 [==============================] - 1s 305us/sample - loss: 1.1728 - categorical_accuracy: 0.9003 - val_loss: 2.3123 - val_categorical_accuracy: 0.5703
# Epoch 131/450
# 3339/3339 [==============================] - 1s 332us/sample - loss: 1.1669 - categorical_accuracy: 0.8940 - val_loss: 2.3283 - val_categorical_accuracy: 0.5395
# Epoch 132/450
# 3339/3339 [==============================] - 1s 307us/sample - loss: 1.1469 - categorical_accuracy: 0.9072 - val_loss: 2.2787 - val_categorical_accuracy: 0.5780
# Epoch 133/450
# 3339/3339 [==============================] - 1s 324us/sample - loss: 1.1360 - categorical_accuracy: 0.9024 - val_loss: 2.3622 - val_categorical_accuracy: 0.5279
# Epoch 134/450
# 3339/3339 [==============================] - 1s 305us/sample - loss: 1.1314 - categorical_accuracy: 0.8997 - val_loss: 2.3399 - val_categorical_accuracy: 0.5491
# Epoch 135/450
# 3339/3339 [==============================] - 1s 319us/sample - loss: 1.1145 - categorical_accuracy: 0.9033 - val_loss: 2.2752 - val_categorical_accuracy: 0.5800
# Epoch 136/450
# 3339/3339 [==============================] - 1s 327us/sample - loss: 1.1158 - categorical_accuracy: 0.9015 - val_loss: 2.3219 - val_categorical_accuracy: 0.5723
# Epoch 137/450
# 3339/3339 [==============================] - 1s 314us/sample - loss: 1.1359 - categorical_accuracy: 0.8988 - val_loss: 2.3982 - val_categorical_accuracy: 0.5530
# Epoch 138/450
# 3339/3339 [==============================] - 1s 308us/sample - loss: 1.1062 - categorical_accuracy: 0.9012 - val_loss: 2.4096 - val_categorical_accuracy: 0.5491
# Epoch 139/450
# 3339/3339 [==============================] - 1s 311us/sample - loss: 1.0925 - categorical_accuracy: 0.9087 - val_loss: 2.3463 - val_categorical_accuracy: 0.5549
# Epoch 140/450
# 3339/3339 [==============================] - 1s 314us/sample - loss: 1.0823 - categorical_accuracy: 0.9152 - val_loss: 2.3672 - val_categorical_accuracy: 0.5703
# Epoch 141/450
# 3339/3339 [==============================] - 1s 313us/sample - loss: 1.0680 - categorical_accuracy: 0.9075 - val_loss: 2.3466 - val_categorical_accuracy: 0.5453
# Epoch 142/450
# 3339/3339 [==============================] - 1s 334us/sample - loss: 1.0559 - categorical_accuracy: 0.9173 - val_loss: 2.3418 - val_categorical_accuracy: 0.5491
# Epoch 143/450
# 3339/3339 [==============================] - 1s 322us/sample - loss: 1.0626 - categorical_accuracy: 0.9054 - val_loss: 2.2938 - val_categorical_accuracy: 0.5723
# Epoch 144/450
# 3339/3339 [==============================] - 1s 319us/sample - loss: 1.0487 - categorical_accuracy: 0.9117 - val_loss: 2.3617 - val_categorical_accuracy: 0.5318
# Epoch 145/450
# 3339/3339 [==============================] - 1s 317us/sample - loss: 1.0317 - categorical_accuracy: 0.9170 - val_loss: 2.3336 - val_categorical_accuracy: 0.5414
# Epoch 146/450
# 3339/3339 [==============================] - 1s 329us/sample - loss: 1.0386 - categorical_accuracy: 0.9131 - val_loss: 2.2838 - val_categorical_accuracy: 0.5742
# Epoch 147/450
# 3339/3339 [==============================] - 1s 302us/sample - loss: 1.0192 - categorical_accuracy: 0.9122 - val_loss: 2.3427 - val_categorical_accuracy: 0.5472
# Epoch 148/450
# 3339/3339 [==============================] - 1s 314us/sample - loss: 1.0217 - categorical_accuracy: 0.9060 - val_loss: 2.3095 - val_categorical_accuracy: 0.5645
# Epoch 149/450
# 3339/3339 [==============================] - 1s 337us/sample - loss: 1.0000 - categorical_accuracy: 0.9164 - val_loss: 2.3082 - val_categorical_accuracy: 0.5607
# Epoch 150/450
# 3339/3339 [==============================] - 1s 321us/sample - loss: 0.9917 - categorical_accuracy: 0.9194 - val_loss: 2.2587 - val_categorical_accuracy: 0.5915
# Epoch 151/450
# 3339/3339 [==============================] - 1s 307us/sample - loss: 0.9753 - categorical_accuracy: 0.9212 - val_loss: 2.2531 - val_categorical_accuracy: 0.5857
# Epoch 152/450
# 3339/3339 [==============================] - 1s 327us/sample - loss: 0.9919 - categorical_accuracy: 0.9146 - val_loss: 2.2529 - val_categorical_accuracy: 0.6069
# Epoch 153/450
# 3339/3339 [==============================] - 1s 334us/sample - loss: 0.9732 - categorical_accuracy: 0.9206 - val_loss: 2.2728 - val_categorical_accuracy: 0.5761
# Epoch 154/450
# 3339/3339 [==============================] - 1s 307us/sample - loss: 0.9549 - categorical_accuracy: 0.9230 - val_loss: 2.2884 - val_categorical_accuracy: 0.5723
# Epoch 155/450
# 3339/3339 [==============================] - 1s 309us/sample - loss: 0.9515 - categorical_accuracy: 0.9239 - val_loss: 2.2407 - val_categorical_accuracy: 0.5800
# Epoch 156/450
# 3339/3339 [==============================] - 1s 308us/sample - loss: 0.9419 - categorical_accuracy: 0.9194 - val_loss: 2.2628 - val_categorical_accuracy: 0.5800
# Epoch 157/450
# 3339/3339 [==============================] - 1s 315us/sample - loss: 0.9371 - categorical_accuracy: 0.9230 - val_loss: 2.2332 - val_categorical_accuracy: 0.5896
# Epoch 158/450
# 3339/3339 [==============================] - 1s 309us/sample - loss: 0.9361 - categorical_accuracy: 0.9230 - val_loss: 2.2339 - val_categorical_accuracy: 0.5703
# Epoch 159/450
# 3339/3339 [==============================] - 1s 329us/sample - loss: 0.9371 - categorical_accuracy: 0.9218 - val_loss: 2.1994 - val_categorical_accuracy: 0.5973
# Epoch 160/450
# 3339/3339 [==============================] - 1s 331us/sample - loss: 0.9264 - categorical_accuracy: 0.9215 - val_loss: 2.2746 - val_categorical_accuracy: 0.5607
# Epoch 161/450
# 3339/3339 [==============================] - 1s 310us/sample - loss: 0.9073 - categorical_accuracy: 0.9269 - val_loss: 2.2400 - val_categorical_accuracy: 0.5857
# Epoch 162/450
# 3339/3339 [==============================] - 1s 316us/sample - loss: 0.9000 - categorical_accuracy: 0.9284 - val_loss: 2.1737 - val_categorical_accuracy: 0.5915
# Epoch 163/450
# 3339/3339 [==============================] - 1s 341us/sample - loss: 0.8862 - categorical_accuracy: 0.9290 - val_loss: 2.1960 - val_categorical_accuracy: 0.5973
# Epoch 164/450
# 3339/3339 [==============================] - 1s 319us/sample - loss: 0.8782 - categorical_accuracy: 0.9347 - val_loss: 2.2271 - val_categorical_accuracy: 0.5742
# Epoch 165/450
# 3339/3339 [==============================] - 1s 324us/sample - loss: 0.8762 - categorical_accuracy: 0.9308 - val_loss: 2.2152 - val_categorical_accuracy: 0.5800
# Epoch 166/450
# 3339/3339 [==============================] - 1s 326us/sample - loss: 0.8664 - categorical_accuracy: 0.9350 - val_loss: 2.2491 - val_categorical_accuracy: 0.5549
# Epoch 167/450
# 3339/3339 [==============================] - 1s 300us/sample - loss: 0.8570 - categorical_accuracy: 0.9371 - val_loss: 2.2550 - val_categorical_accuracy: 0.5568
# Epoch 168/450
# 3339/3339 [==============================] - 1s 316us/sample - loss: 0.8578 - categorical_accuracy: 0.9266 - val_loss: 2.2585 - val_categorical_accuracy: 0.5568
# Epoch 169/450
# 3339/3339 [==============================] - 1s 321us/sample - loss: 0.8490 - categorical_accuracy: 0.9326 - val_loss: 2.2322 - val_categorical_accuracy: 0.5742
# Epoch 170/450
# 3339/3339 [==============================] - 1s 312us/sample - loss: 0.8486 - categorical_accuracy: 0.9311 - val_loss: 2.2916 - val_categorical_accuracy: 0.5260
# Epoch 171/450
# 3339/3339 [==============================] - 1s 307us/sample - loss: 0.8488 - categorical_accuracy: 0.9248 - val_loss: 2.2388 - val_categorical_accuracy: 0.5588
# Epoch 172/450
# 3339/3339 [==============================] - 1s 318us/sample - loss: 0.8303 - categorical_accuracy: 0.9356 - val_loss: 2.1885 - val_categorical_accuracy: 0.5954
# Epoch 173/450
# 3339/3339 [==============================] - 1s 320us/sample - loss: 0.8255 - categorical_accuracy: 0.9329 - val_loss: 2.1458 - val_categorical_accuracy: 0.6031
# Epoch 174/450
# 3339/3339 [==============================] - 1s 326us/sample - loss: 0.8166 - categorical_accuracy: 0.9353 - val_loss: 2.2114 - val_categorical_accuracy: 0.5723
# Epoch 175/450
# 3339/3339 [==============================] - 1s 315us/sample - loss: 0.8182 - categorical_accuracy: 0.9341 - val_loss: 2.1892 - val_categorical_accuracy: 0.5915
# Epoch 176/450
# 3339/3339 [==============================] - 1s 316us/sample - loss: 0.8151 - categorical_accuracy: 0.9317 - val_loss: 2.1917 - val_categorical_accuracy: 0.6012
# Epoch 177/450
# 3339/3339 [==============================] - 1s 306us/sample - loss: 0.7923 - categorical_accuracy: 0.9404 - val_loss: 2.1561 - val_categorical_accuracy: 0.6127
# Epoch 178/450
# 3339/3339 [==============================] - 1s 328us/sample - loss: 0.7900 - categorical_accuracy: 0.9398 - val_loss: 2.1735 - val_categorical_accuracy: 0.6108
# Epoch 179/450
# 3339/3339 [==============================] - 1s 322us/sample - loss: 0.7802 - categorical_accuracy: 0.9404 - val_loss: 2.1841 - val_categorical_accuracy: 0.5992
# Epoch 180/450
# 3339/3339 [==============================] - 1s 325us/sample - loss: 0.7924 - categorical_accuracy: 0.9335 - val_loss: 2.1492 - val_categorical_accuracy: 0.5915
# Epoch 181/450
# 3339/3339 [==============================] - 1s 325us/sample - loss: 0.7883 - categorical_accuracy: 0.9275 - val_loss: 2.2220 - val_categorical_accuracy: 0.5703
# Epoch 182/450
# 3339/3339 [==============================] - 1s 322us/sample - loss: 0.7572 - categorical_accuracy: 0.9428 - val_loss: 2.1022 - val_categorical_accuracy: 0.5992
# Epoch 183/450
# 3339/3339 [==============================] - 1s 309us/sample - loss: 0.7624 - categorical_accuracy: 0.9449 - val_loss: 2.1877 - val_categorical_accuracy: 0.5877
# Epoch 184/450
# 3339/3339 [==============================] - 1s 343us/sample - loss: 0.7566 - categorical_accuracy: 0.9416 - val_loss: 2.1396 - val_categorical_accuracy: 0.6108
# Epoch 185/450
# 3339/3339 [==============================] - 1s 310us/sample - loss: 0.7486 - categorical_accuracy: 0.9419 - val_loss: 2.1128 - val_categorical_accuracy: 0.5954
# Epoch 186/450
# 3339/3339 [==============================] - 1s 321us/sample - loss: 0.7566 - categorical_accuracy: 0.9416 - val_loss: 2.1505 - val_categorical_accuracy: 0.5915
# Epoch 187/450
# 3339/3339 [==============================] - 1s 302us/sample - loss: 0.7327 - categorical_accuracy: 0.9464 - val_loss: 2.1373 - val_categorical_accuracy: 0.5761
# Epoch 188/450
# 3339/3339 [==============================] - 1s 335us/sample - loss: 0.7330 - categorical_accuracy: 0.9413 - val_loss: 2.1312 - val_categorical_accuracy: 0.5857
# Epoch 189/450
# 3339/3339 [==============================] - 1s 312us/sample - loss: 0.7128 - categorical_accuracy: 0.9524 - val_loss: 2.1596 - val_categorical_accuracy: 0.5761
# Epoch 190/450
# 3339/3339 [==============================] - 1s 326us/sample - loss: 0.7146 - categorical_accuracy: 0.9488 - val_loss: 2.1347 - val_categorical_accuracy: 0.6031
# Epoch 191/450
# 3339/3339 [==============================] - 1s 326us/sample - loss: 0.7061 - categorical_accuracy: 0.9434 - val_loss: 2.1314 - val_categorical_accuracy: 0.5954
# Epoch 192/450
# 3339/3339 [==============================] - 1s 322us/sample - loss: 0.7238 - categorical_accuracy: 0.9395 - val_loss: 2.1661 - val_categorical_accuracy: 0.5800
# Epoch 193/450
# 3339/3339 [==============================] - 1s 322us/sample - loss: 0.7154 - categorical_accuracy: 0.9377 - val_loss: 2.1141 - val_categorical_accuracy: 0.5838
# Epoch 194/450
# 3339/3339 [==============================] - 1s 323us/sample - loss: 0.7040 - categorical_accuracy: 0.9401 - val_loss: 2.1160 - val_categorical_accuracy: 0.6012
# Epoch 195/450
# 3339/3339 [==============================] - 1s 312us/sample - loss: 0.6929 - categorical_accuracy: 0.9464 - val_loss: 2.1690 - val_categorical_accuracy: 0.5645
# Epoch 196/450
# 3339/3339 [==============================] - 1s 320us/sample - loss: 0.7011 - categorical_accuracy: 0.9437 - val_loss: 2.2566 - val_categorical_accuracy: 0.5626
# Epoch 197/450
# 3339/3339 [==============================] - 1s 358us/sample - loss: 0.6874 - categorical_accuracy: 0.9518 - val_loss: 2.2069 - val_categorical_accuracy: 0.5819
# Epoch 198/450
# 3339/3339 [==============================] - 1s 323us/sample - loss: 0.6977 - categorical_accuracy: 0.9395 - val_loss: 2.1698 - val_categorical_accuracy: 0.5742
# Epoch 199/450
# 3339/3339 [==============================] - 1s 323us/sample - loss: 0.6841 - categorical_accuracy: 0.9491 - val_loss: 2.1960 - val_categorical_accuracy: 0.5877
# Epoch 200/450
# 3339/3339 [==============================] - 1s 316us/sample - loss: 0.6767 - categorical_accuracy: 0.9458 - val_loss: 2.1741 - val_categorical_accuracy: 0.5723
# Epoch 201/450
# 3339/3339 [==============================] - 1s 310us/sample - loss: 0.6841 - categorical_accuracy: 0.9455 - val_loss: 2.2638 - val_categorical_accuracy: 0.5337
# Epoch 202/450
# 3339/3339 [==============================] - 1s 319us/sample - loss: 0.6736 - categorical_accuracy: 0.9458 - val_loss: 2.1758 - val_categorical_accuracy: 0.5588
# Epoch 203/450
# 3339/3339 [==============================] - 1s 326us/sample - loss: 0.6560 - categorical_accuracy: 0.9482 - val_loss: 2.1525 - val_categorical_accuracy: 0.5819
# Epoch 204/450
# 3339/3339 [==============================] - 1s 314us/sample - loss: 0.6570 - categorical_accuracy: 0.9470 - val_loss: 2.1477 - val_categorical_accuracy: 0.5800
# Epoch 205/450
# 3339/3339 [==============================] - 1s 330us/sample - loss: 0.6640 - categorical_accuracy: 0.9440 - val_loss: 2.1879 - val_categorical_accuracy: 0.5723
# Epoch 206/450
# 3339/3339 [==============================] - 1s 328us/sample - loss: 0.6451 - categorical_accuracy: 0.9491 - val_loss: 2.1241 - val_categorical_accuracy: 0.5934
# Epoch 207/450
# 3339/3339 [==============================] - 1s 323us/sample - loss: 0.6571 - categorical_accuracy: 0.9404 - val_loss: 2.1649 - val_categorical_accuracy: 0.5684
# Epoch 208/450
# 3339/3339 [==============================] - 1s 314us/sample - loss: 0.6440 - categorical_accuracy: 0.9488 - val_loss: 2.2135 - val_categorical_accuracy: 0.5453
# Epoch 209/450
# 3339/3339 [==============================] - 1s 320us/sample - loss: 0.6354 - categorical_accuracy: 0.9500 - val_loss: 2.1969 - val_categorical_accuracy: 0.5626
# Epoch 210/450
# 3339/3339 [==============================] - 1s 326us/sample - loss: 0.6422 - categorical_accuracy: 0.9506 - val_loss: 2.1644 - val_categorical_accuracy: 0.5491
# Epoch 211/450
# 3339/3339 [==============================] - 1s 326us/sample - loss: 0.6180 - categorical_accuracy: 0.9530 - val_loss: 2.1875 - val_categorical_accuracy: 0.5665
# Epoch 212/450
# 3339/3339 [==============================] - 1s 327us/sample - loss: 0.6192 - categorical_accuracy: 0.9488 - val_loss: 2.1566 - val_categorical_accuracy: 0.5684
# Epoch 00212: early stopping
# 519/519 [==============================] - 1s 1ms/sample - loss: 2.1566 - categorical_accuracy: 0.5684
# [2.15664713001435, 0.5684008]

# %% [markdown]
# ## Loss & Accuracy Curves

# %%
# Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
  
# Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['categorical_accuracy'],'r',linewidth=3.0)
plt.plot(history.history['val_categorical_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %% [markdown]
# # Performance

# %%
t0 = time.time()
image_labels_pred = model1.predict(images_test)
image_labels_pred = np.where(image_labels_pred > 0.5, 1, 0)
t1 = time.time()

total_prediction_time = t1-t0

# %%
y_true = np.argmax(image_labels_test,1) 
y_pred = np.argmax(image_labels_pred,1)

# %% [markdown]
# ## Confusion Matrix

# %%
cm =  pd.DataFrame(confusion_matrix(y_true, y_pred), 
                                 index = label_names_array, 
                                 columns = label_names_array)

plt.figure(figsize=[8,6])
sn.heatmap(cm, annot=True,cmap='Blues', fmt='g')

# %% [markdown]
# ## Classification Metrics

# %%
target_names = label_names_array
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         Sell       0.17      0.24      0.20        66
#          Buy       0.19      0.21      0.20        72
#         Hold       0.77      0.70      0.73       381
#
#     accuracy                           0.57       519
#    macro avg       0.38      0.38      0.38       519
# weighted avg       0.61      0.57      0.59       519

# %% [markdown]
# ## Time spent

# %%
total_training_time = sum(time_callback.times)
print("Time spent on entire model training: {:4f} seconds".format(total_training_time))
# Out:
# Time spent on entire model training: 233.185563 seconds

# %% [markdown]
# ## Financial Evaluation, Save predicton data in given format

# %%
#custom library
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/CNN/evaluation')
import financial_evaluation

# %%
# Create Signals from numbers here 
Signals = y_pred

prediction = pd.DataFrame(test_prices, columns = [VarName])
prediction['Signals'] = Signals
prediction['Signals'].loc[prediction['Signals'] == 0] = "Sell"
prediction['Signals'].loc[prediction['Signals'] == 1] = "Buy"
prediction['Signals'].loc[prediction['Signals'] == 2] = "Hold"
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#save results
prediction.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/PredForFinEval.csv")

# %%
fin_res = financial_evaluation.financial_evaluation(VarName, test_prices, prediction['Signals'])
print("Annualized return is {}, cumulative return is {} and number of trades are {}.".format(fin_res['annualized_return'], fin_res['cumulative_return'], fin_res['all_trades']))
# Out:
# Annualized return is [0.08040595], cumulative return is [0.16692986] and number of trades are 90.

# %% [markdown]
# ## Save Model

# %%
model1.save('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/model.h5")

# %% [markdown]
# ## Save true and pred

# %%
TruePred = pd.DataFrame(y_true, columns = [VarName])
TruePred['Prediction'] = y_pred
TruePred.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/True&Pred.csv")

# %% [markdown]
# ## Save Classification Metrics &  Save Times

# %%
Acc = np.float(accuracy_score(y_true=y_true, y_pred=y_pred))
#F1 = np.float(f1_score(y_true = y_true, y_pred = y_pred, average = 'macro'))
Prec = np.float(precision_score(y_true=y_true, y_pred=y_pred, average = 'macro'))
Recall = np.float(recall_score(y_true=y_true, y_pred=y_pred, average = 'macro'))

F1 = 2 * (Prec * Recall) / (Prec + Recall)

print(Acc, F1, Prec, Recall)
# Out:
# 0.5703275529865125 0.3785744223884167 0.37511471265561963 0.38209854450011926

# %%
np.savez('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/Time&ClassificationEval.npz",
         accuracy = Acc,
         MacF1 = F1,
         MacPrecision = Prec,
         MacRecall = Recall,
         TrainTime = np.float(total_training_time),
         PredTime = np.float(total_prediction_time)
        )
