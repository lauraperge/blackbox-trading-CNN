# %%
# !pip install numpy==1.16.1
# !pip install tensorflow-gpu==2.0.0-beta1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
from sklearn.model_selection import TimeSeriesSplit
from sklearn.utils import class_weight
from sklearn.metrics import f1_score, confusion_matrix, classification_report, accuracy_score, precision_score, recall_score
import time

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, AveragePooling2D, BatchNormalization, LeakyReLU
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam, Nadam, SGD, RMSprop
from tensorflow.keras.callbacks import EarlyStopping

LR = LeakyReLU(alpha = .3)
LR.__name__ = 'leakyrelu'

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Requirement already satisfied: numpy==1.16.1 in /usr/local/lib/python3.6/dist-packages (1.16.1)
# Requirement already satisfied: tensorflow-gpu==2.0.0-beta1 in /usr/local/lib/python3.6/dist-packages (2.0.0b1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.2.2)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.8.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.7.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.0.8)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.15.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.33.4)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.12.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.16.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (3.7.1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.11.2)
# Requirement already satisfied: tb-nightly<1.14.0a20190604,>=1.14.0a20190603 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.14.0a20190603)
# Requirement already satisfied: tf-estimator-nightly<1.14.0.dev2019060502,>=1.14.0.dev2019060501 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.14.0.dev2019060501)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.1.7)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==2.0.0-beta1) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==2.0.0-beta1) (41.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (0.15.5)
# Found GPU at: /device:GPU:0
# Requirement already satisfied: numpy==1.16.1 in /usr/local/lib/python3.6/dist-packages (1.16.1)
# Requirement already satisfied: tensorflow-gpu==2.0.0-beta1 in /usr/local/lib/python3.6/dist-packages (2.0.0b1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.12.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.16.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (3.7.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.7.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.33.4)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.8.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.11.2)
# Requirement already satisfied: tb-nightly<1.14.0a20190604,>=1.14.0a20190603 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.14.0a20190603)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.2.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.1.7)
# Requirement already satisfied: tf-estimator-nightly<1.14.0.dev2019060502,>=1.14.0.dev2019060501 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.14.0.dev2019060501)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.0.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==2.0.0-beta1) (41.0.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (0.15.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (3.1.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==2.0.0-beta1) (2.8.0)
# Found GPU at: /device:GPU:0

# %%
# fix random seed for reproducibility
seed = 2
np.random.seed(seed)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Pre-Settings

# %%
Test = "test2"
Version = "_indiv_" #="univ"
VarName = "SPY"


if Test == "test1":
  tr_direct = "data_train_to2005"
  ts_direct = "data_test_2005Decto_2007Dec"
elif Test == "test2":
  tr_direct = "data_train_to2007"
  ts_direct = "data_test_2008Jan_to_2010Jan"
else:
  tr_direct = "data_train_to2017May"
  ts_direct = "data_test_2017May_to_2019last"

# %% [markdown]
# # Load data

# %%
if Version == "_indiv_":
  train_filename = "LW5_IW30/" + tr_direct + "/" + Version[1:] + "train" + Test[-1] + "_" + VarName + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"
else:
  train_filename = "LW5_IW30/" + tr_direct + "/" + Version[1:] + "train" + Test[-1] + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"
  
test_filename = "LW5_IW30/" + ts_direct + "/" + Test + "_" + VarName + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"

# %% [markdown]
# ### Image window sizes

# %%
Image_window_size = np.int(train_filename[train_filename.find('_IWS') + 4 : train_filename.find("_Trf")])
Image_window_size
# Out:
# 30
# 30

# %% [markdown]
# ### Transformation types

# %%
Image_trf = eval(train_filename[train_filename.find('_Trf')+4:train_filename.find('.npz')])
Image_trf
# Out:
# ['RP', 'GASF', 'MTF']
# ['RP', 'GASF', 'MTF']

# %%
num_color_channels = len(Image_trf)
num_color_channels
# Out:
# 3
# 3

# %% [markdown]
# #### In case file is missing run the data-check-and-prep with preferred settings and use the new file's name (cannot upload too big files to Git)

# %%
data_train = np.load('/content/drive/My Drive/Colab Notebooks/CNN/' + train_filename)
data_test = np.load('/content/drive/My Drive/Colab Notebooks/CNN/' + test_filename)

# %%
images_train = data_train['images']
images_test = data_test['images']
image_labels_train = data_train['image_labels']
image_labels_test = data_test['image_labels']
train_prices = data_train['price_at_image']
test_prices = data_test['price_at_image']

label_names = data_train['label_names'] # same everywhere

# %% [markdown]
# # Check data

# %%
image_labels_train.shape
# Out:
# (3860, 3)
# (3860, 3)

# %% [markdown]
# Get label names array for later visualization

# %%
label_names = label_names.item()
label_names
# Out:
# {0: 'Sell', 1: 'Buy', 2: 'Hold'}
# {0: 'Sell', 1: 'Buy', 2: 'Hold'}

# %%
label_names_array = np.chararray(3, itemsize = 4).decode("utf-8")

for key, value in label_names.items():
  label_names_array[key] = value
label_names_array
# Out:
# array(['Sell', 'Buy', 'Hold'], dtype='<U4')
# array(['S', 'B', 'H'], dtype='<U1')

# %% [markdown]
# ## e.g.:

# %%
for trfidx, trf in enumerate(Image_trf):
    print('Transformation type: ' + trf)
    for idx, image in enumerate(images_train[:2,:,:, trfidx]):
        plt.imshow(image, cmap = "Greys")
        plt.title(label_names[np.int(np.argwhere(image_labels_train[idx]))])
        plt.show()
# Out:
# Transformation type: RP
# Transformation type: GASF
# Transformation type: MTF
# Transformation type: RP
# Transformation type: GASF
# Transformation type: MTF

# %%
print("Train images shape : {}; Train labels shape : {}".format(images_train.shape, image_labels_train.shape))
# Out:
# Train images shape : (3860, 30, 30, 3); Train labels shape : (3860, 3)
# Train images shape : (3860, 30, 30, 3); Train labels shape : (3860, 3)

# %%
print("Test images shape : {}; Test labels shape : {}".format(images_test.shape, image_labels_test.shape))
# Out:
# Test images shape : (521, 30, 30, 3); Test labels shape : (521, 3)
# Test images shape : (521, 30, 30, 3); Test labels shape : (521, 3)

# %% [markdown]
# # Baseline predictions
# Choosing the biggest class to be the class of all

# %%
basepred = np.zeros(image_labels_test.shape)
basepred[:, np.argmax(np.sum(image_labels_test, 0))] = 1.0

base_acc = sum(np.equal(np.argmax(basepred, 1), np.argmax(image_labels_test, 1)))/np.sum(image_labels_test)
base_f1 = f1_score(y_true = image_labels_test, y_pred = basepred, average = 'macro')
# warning F1 due to only label 2 being predicted in baseline

print("Accuracy: {:.5f}".format(base_acc))
print("Categorical Accuracy: {:.5f}".format(accuracy_score(np.argmax(basepred, 1), np.argmax(image_labels_test, 1))))

print("F1 score: {:.5f}".format(base_f1))

print(classification_report(np.argmax(basepred, 1), np.argmax(image_labels_test, 1)))
# Out:
# Accuracy: 0.71209
# Categorical Accuracy: 0.71209
# F1 score: 0.27728
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         0
#            2       1.00      0.71      0.83       521
#
#     accuracy                           0.71       521
#    macro avg       0.33      0.24      0.28       521
# weighted avg       1.00      0.71      0.83       521
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# Accuracy: 0.71209
# Categorical Accuracy: 0.71209
# F1 score: 0.27728
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         0
#            2       1.00      0.71      0.83       521
#
#     accuracy                           0.71       521
#    macro avg       0.33      0.24      0.28       521
# weighted avg       1.00      0.71      0.83       521
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %% [markdown]
# # The Deep CNN

# %% [markdown]
# ### Custom Keras Eval metrics: F1 Score
# https://medium.com/@thongonary/how-to-compute-f1-score-for-each-epoch-in-keras-a1acd17715a2

# %%
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import fbeta_score

# Some default constants

START = 0.5
END = 0.95
STEP = 0.05
N_STEPS = int((END - START) / STEP) + 2
DEFAULT_THRESHOLDS = np.linspace(START, END, N_STEPS)
DEFAULT_BETA = 1
DEFAULT_LOGS = {}
FBETA_METRIC_NAME = "val_fbeta"

class FBetaMetricCallback(Callback):

    def __init__(self, beta=DEFAULT_BETA, thresholds=DEFAULT_THRESHOLDS):
        self.beta = beta
        self.thresholds = thresholds
        # Will be initialized when the training starts
        self.val_fbeta = None

    def on_train_begin(self, logs=DEFAULT_LOGS):
        """ This is where the validation Fbeta
        validation scores will be saved during training: one value per
        epoch.
        """
        self.val_fbeta = []

    def _score_per_threshold(self, predictions, targets, threshold):
        """ Compute the Fbeta score per threshold.
        """
        # Notice that here I am using the sklearn fbeta_score function.
        # You can read more about it here:
        # http://scikit-learn.org/stable/modules/generated/sklearn.metrics.fbeta_score.html
        thresholded_predictions = (predictions > threshold).astype(int)
        return fbeta_score(targets, thresholded_predictions, beta=self.beta)

    def on_epoch_end(self, epoch, logs=DEFAULT_LOGS):
        val_predictions = self.model.predict(self.validation_data[0])
        val_targets = self.validation_data[1]
        _val_fbeta = np.mean([self._score_per_threshold(val_predictions,
                                                        val_targets, threshold)
                              for threshold in self.thresholds])
        self.val_fbeta.append(_val_fbeta)
        print("Current F{} metric is: {}".format(str(self.beta), str(_val_fbeta)))
        return

    def on_train_end(self, logs=DEFAULT_LOGS):
        """ Assign the validation Fbeta computed metric to the History object.
        """
        self.model.history.history[FBETA_METRIC_NAME] = self.val_fbeta
        
f1_score = FBetaMetricCallback(beta=1)

# %% [markdown]
# ### Custom Time Logging

# %%
import tensorflow.keras.callbacks as keras_cb

class TimeHistory(keras_cb.Callback):
  def on_train_begin(self, logs={}):
    self.times = []

  def on_epoch_begin(self, epoch, logs={}):
    self.epoch_time_start = time.time()

  def on_epoch_end(self, epoch, logs={}):
    self.times.append(time.time() - self.epoch_time_start)

time_callback = TimeHistory()

# %% [markdown]
# ### Network Parameters

# %%
# image shape (d x d)
n_input = images_train.shape[1]
inputShape = (n_input, n_input, num_color_channels)

# number of classes
n_classes =  image_labels_train.shape[1]

# dropout
to_drop = 0.3 # prob. to DROP

# %% [markdown]
# ## Building the model

# %%
def createModel(input_shape, dropout = .2):
    model = Sequential()
    # Input
    model.add(Conv2D(32, 
                     (3, 3), 
                     padding='same', 
                     activation=LR, 
                     input_shape=input_shape
                    ))
    model.add(BatchNormalization())
    # model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))
    
    # 1Convolution,relu then pooling
    model.add(Conv2D(64, (3, 3), 
                     padding='same', 
                     activation=LR,
                     kernel_regularizer=regularizers.l2(0.01)
                    ))
    model.add(BatchNormalization())
    model.add(AveragePooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))
    
    # Flatten & Dense layers 
    model.add(Flatten())
    
    model.add(Dense(128, activation=LR, kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(Dropout(.5))
    model.add(Dense(n_classes, activation='softmax'))
  
    return model

# %%
model1 = createModel(dropout = to_drop, input_shape = inputShape)
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 30, 30, 32)        128
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 64)        256
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 15, 15, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 15, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 14400)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1843328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 1,864,003
# Trainable params: 1,863,555
# Non-trainable params: 448
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 30, 30, 64)        18496
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 30, 64)        256
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 15, 15, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 15, 15, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 14400)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               1843328
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 1,864,003
# Trainable params: 1,863,555
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# ## Hyperparameter settings

# %%
training_iters = 450
batch_size = 150

# %% [markdown]
# ### Accounting for imbalance

# %%
label_names
# Out:
# {0: 'Sell', 1: 'Buy', 2: 'Hold'}
# {0: 'Sell', 1: 'Buy', 2: 'Hold'}

# %%
np.sum(image_labels_train, axis = 0)/np.sum(image_labels_train)
# Out:
# array([0.13989637, 0.14455959, 0.71554404])
# array([0.13989637, 0.14455959, 0.71554404])

# %%
y_ints = [y.argmax() for y in image_labels_train]
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_ints),
                                                 y_ints)
class_weight_dict = dict(enumerate(class_weights))
class_weight_dict
# Out:
# {0: 2.382716049382716, 1: 2.3058542413381122, 2: 0.46584600531016174}
# {0: 2.382716049382716, 1: 2.3058542413381122, 2: 0.46584600531016174}

# %% [markdown]
# ## Compiling

# %%
model1.compile(optimizer=SGD(nesterov=True),#Adam(lr=0.0001, amsgrad = True), #Nadam(lr=0.0005), #
               loss='kullback_leibler_divergence', 
               metrics=['categorical_accuracy'])

# %% [markdown]
# ## Training

# %%
es2 = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
history = model1.fit(images_train, 
                     image_labels_train, 
                     batch_size=batch_size, 
                     epochs=training_iters, verbose=1,
                     validation_data=(images_test, image_labels_test),
                     class_weight=class_weight_dict,
                     callbacks=[time_callback, es2]
                    )
  
model1.evaluate(images_test, image_labels_test)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0814 14:37:47.421234 140593201911680 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 3860 samples, validate on 521 samples
# Epoch 1/450
# 3860/3860 [==============================] - 4s 1ms/sample - loss: 4.9242 - categorical_accuracy: 0.3272 - val_loss: 4.0649 - val_categorical_accuracy: 0.1420
# Epoch 2/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 4.5656 - categorical_accuracy: 0.3474 - val_loss: 4.0855 - val_categorical_accuracy: 0.1420
# Epoch 3/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 4.3536 - categorical_accuracy: 0.3645 - val_loss: 4.0081 - val_categorical_accuracy: 0.2476
# Epoch 4/450
# 3860/3860 [==============================] - 1s 298us/sample - loss: 4.2553 - categorical_accuracy: 0.3806 - val_loss: 4.0368 - val_categorical_accuracy: 0.1459
# Epoch 5/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 4.1198 - categorical_accuracy: 0.3873 - val_loss: 3.9747 - val_categorical_accuracy: 0.1881
# Epoch 6/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 4.0080 - categorical_accuracy: 0.4101 - val_loss: 3.9482 - val_categorical_accuracy: 0.1804
# Epoch 7/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 3.9660 - categorical_accuracy: 0.4225 - val_loss: 3.9267 - val_categorical_accuracy: 0.1727
# Epoch 8/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 3.9040 - categorical_accuracy: 0.4176 - val_loss: 3.8865 - val_categorical_accuracy: 0.2111
# Epoch 9/450
# 3860/3860 [==============================] - 1s 299us/sample - loss: 3.8150 - categorical_accuracy: 0.4288 - val_loss: 3.8517 - val_categorical_accuracy: 0.2284
# Epoch 10/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 3.7541 - categorical_accuracy: 0.4417 - val_loss: 3.8525 - val_categorical_accuracy: 0.1804
# Epoch 11/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 3.6996 - categorical_accuracy: 0.4459 - val_loss: 3.8159 - val_categorical_accuracy: 0.1996
# Epoch 12/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 3.6617 - categorical_accuracy: 0.4552 - val_loss: 3.7961 - val_categorical_accuracy: 0.2111
# Epoch 13/450
# 3860/3860 [==============================] - 1s 300us/sample - loss: 3.6073 - categorical_accuracy: 0.4585 - val_loss: 3.7744 - val_categorical_accuracy: 0.2226
# Epoch 14/450
# 3860/3860 [==============================] - 1s 297us/sample - loss: 3.5455 - categorical_accuracy: 0.4780 - val_loss: 3.7527 - val_categorical_accuracy: 0.2265
# Epoch 15/450
# 3860/3860 [==============================] - 1s 297us/sample - loss: 3.5089 - categorical_accuracy: 0.4824 - val_loss: 3.7033 - val_categorical_accuracy: 0.2764
# Epoch 16/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 3.4491 - categorical_accuracy: 0.4990 - val_loss: 3.6927 - val_categorical_accuracy: 0.2591
# Epoch 17/450
# 3860/3860 [==============================] - 1s 300us/sample - loss: 3.4148 - categorical_accuracy: 0.4935 - val_loss: 3.6645 - val_categorical_accuracy: 0.2553
# Epoch 18/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 3.3704 - categorical_accuracy: 0.5075 - val_loss: 3.6493 - val_categorical_accuracy: 0.2687
# Epoch 19/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 3.3353 - categorical_accuracy: 0.5109 - val_loss: 3.6250 - val_categorical_accuracy: 0.2841
# Epoch 20/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 3.3012 - categorical_accuracy: 0.5127 - val_loss: 3.5618 - val_categorical_accuracy: 0.3397
# Epoch 21/450
# 3860/3860 [==============================] - 1s 299us/sample - loss: 3.2558 - categorical_accuracy: 0.5249 - val_loss: 3.5404 - val_categorical_accuracy: 0.3321
# Epoch 22/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 3.2149 - categorical_accuracy: 0.5316 - val_loss: 3.4769 - val_categorical_accuracy: 0.3858
# Epoch 23/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 3.1930 - categorical_accuracy: 0.5316 - val_loss: 3.5023 - val_categorical_accuracy: 0.3455
# Epoch 24/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 3.1504 - categorical_accuracy: 0.5451 - val_loss: 3.4680 - val_categorical_accuracy: 0.3724
# Epoch 25/450
# 3860/3860 [==============================] - 1s 300us/sample - loss: 3.1234 - categorical_accuracy: 0.5500 - val_loss: 3.4191 - val_categorical_accuracy: 0.3992
# Epoch 26/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 3.0778 - categorical_accuracy: 0.5539 - val_loss: 3.4658 - val_categorical_accuracy: 0.3493
# Epoch 27/450
# 3860/3860 [==============================] - 1s 299us/sample - loss: 3.0428 - categorical_accuracy: 0.5648 - val_loss: 3.4320 - val_categorical_accuracy: 0.3724
# Epoch 28/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 3.0236 - categorical_accuracy: 0.5614 - val_loss: 3.4496 - val_categorical_accuracy: 0.3397
# Epoch 29/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 2.9955 - categorical_accuracy: 0.5583 - val_loss: 3.3848 - val_categorical_accuracy: 0.3762
# Epoch 30/450
# 3860/3860 [==============================] - 1s 298us/sample - loss: 2.9432 - categorical_accuracy: 0.5697 - val_loss: 3.3700 - val_categorical_accuracy: 0.3781
# Epoch 31/450
# 3860/3860 [==============================] - 1s 299us/sample - loss: 2.9225 - categorical_accuracy: 0.5845 - val_loss: 3.3834 - val_categorical_accuracy: 0.3321
# Epoch 32/450
# 3860/3860 [==============================] - 1s 298us/sample - loss: 2.8860 - categorical_accuracy: 0.5915 - val_loss: 3.3841 - val_categorical_accuracy: 0.3321
# Epoch 33/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 2.8490 - categorical_accuracy: 0.5915 - val_loss: 3.3631 - val_categorical_accuracy: 0.3493
# Epoch 34/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 2.8256 - categorical_accuracy: 0.5964 - val_loss: 3.3040 - val_categorical_accuracy: 0.3685
# Epoch 35/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 2.8102 - categorical_accuracy: 0.5979 - val_loss: 3.2613 - val_categorical_accuracy: 0.3839
# Epoch 36/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 2.7636 - categorical_accuracy: 0.6088 - val_loss: 3.3203 - val_categorical_accuracy: 0.3455
# Epoch 37/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 2.7330 - categorical_accuracy: 0.6212 - val_loss: 3.1984 - val_categorical_accuracy: 0.4127
# Epoch 38/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 2.7001 - categorical_accuracy: 0.6153 - val_loss: 3.1819 - val_categorical_accuracy: 0.4184
# Epoch 39/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 2.6913 - categorical_accuracy: 0.6174 - val_loss: 3.1502 - val_categorical_accuracy: 0.4165
# Epoch 40/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 2.6250 - categorical_accuracy: 0.6295 - val_loss: 3.1822 - val_categorical_accuracy: 0.3973
# Epoch 41/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 2.6216 - categorical_accuracy: 0.6355 - val_loss: 3.1413 - val_categorical_accuracy: 0.4242
# Epoch 42/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 2.6012 - categorical_accuracy: 0.6233 - val_loss: 3.1652 - val_categorical_accuracy: 0.4031
# Epoch 43/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 2.5646 - categorical_accuracy: 0.6453 - val_loss: 3.1661 - val_categorical_accuracy: 0.3762
# Epoch 44/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 2.5278 - categorical_accuracy: 0.6539 - val_loss: 3.2102 - val_categorical_accuracy: 0.3608
# Epoch 45/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 2.4894 - categorical_accuracy: 0.6585 - val_loss: 3.1047 - val_categorical_accuracy: 0.3935
# Epoch 46/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 2.4755 - categorical_accuracy: 0.6503 - val_loss: 3.1262 - val_categorical_accuracy: 0.3704
# Epoch 47/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 2.4561 - categorical_accuracy: 0.6617 - val_loss: 3.1075 - val_categorical_accuracy: 0.3973
# Epoch 48/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 2.4298 - categorical_accuracy: 0.6674 - val_loss: 3.0366 - val_categorical_accuracy: 0.4261
# Epoch 49/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 2.4016 - categorical_accuracy: 0.6728 - val_loss: 3.0298 - val_categorical_accuracy: 0.4069
# Epoch 50/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 2.3742 - categorical_accuracy: 0.6762 - val_loss: 3.0636 - val_categorical_accuracy: 0.3973
# Epoch 51/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 2.3711 - categorical_accuracy: 0.6707 - val_loss: 3.0450 - val_categorical_accuracy: 0.4031
# Epoch 52/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 2.3132 - categorical_accuracy: 0.6876 - val_loss: 3.0118 - val_categorical_accuracy: 0.3954
# Epoch 53/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 2.2930 - categorical_accuracy: 0.6894 - val_loss: 3.0589 - val_categorical_accuracy: 0.3628
# Epoch 54/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 2.2590 - categorical_accuracy: 0.7080 - val_loss: 2.9841 - val_categorical_accuracy: 0.4107
# Epoch 55/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 2.2622 - categorical_accuracy: 0.6917 - val_loss: 2.9269 - val_categorical_accuracy: 0.4357
# Epoch 56/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 2.2352 - categorical_accuracy: 0.6995 - val_loss: 2.9620 - val_categorical_accuracy: 0.4223
# Epoch 57/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 2.1951 - categorical_accuracy: 0.7187 - val_loss: 2.9163 - val_categorical_accuracy: 0.4280
# Epoch 58/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 2.1944 - categorical_accuracy: 0.6977 - val_loss: 2.8897 - val_categorical_accuracy: 0.4453
# Epoch 59/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 2.1693 - categorical_accuracy: 0.7098 - val_loss: 2.8981 - val_categorical_accuracy: 0.4319
# Epoch 60/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 2.1479 - categorical_accuracy: 0.7142 - val_loss: 2.9087 - val_categorical_accuracy: 0.4088
# Epoch 61/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 2.1174 - categorical_accuracy: 0.7215 - val_loss: 2.8662 - val_categorical_accuracy: 0.4242
# Epoch 62/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 2.0784 - categorical_accuracy: 0.7269 - val_loss: 2.8601 - val_categorical_accuracy: 0.4280
# Epoch 63/450
# 3860/3860 [==============================] - 1s 308us/sample - loss: 2.0691 - categorical_accuracy: 0.7298 - val_loss: 2.8318 - val_categorical_accuracy: 0.4299
# Epoch 64/450
# 3860/3860 [==============================] - 1s 308us/sample - loss: 2.0387 - categorical_accuracy: 0.7415 - val_loss: 2.8118 - val_categorical_accuracy: 0.4223
# Epoch 65/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 2.0019 - categorical_accuracy: 0.7430 - val_loss: 2.7576 - val_categorical_accuracy: 0.4472
# Epoch 66/450
# 3860/3860 [==============================] - 1s 308us/sample - loss: 1.9861 - categorical_accuracy: 0.7453 - val_loss: 2.7405 - val_categorical_accuracy: 0.4722
# Epoch 67/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 1.9610 - categorical_accuracy: 0.7484 - val_loss: 2.7444 - val_categorical_accuracy: 0.4587
# Epoch 68/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 1.9716 - categorical_accuracy: 0.7417 - val_loss: 2.7537 - val_categorical_accuracy: 0.4491
# Epoch 69/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 1.9392 - categorical_accuracy: 0.7490 - val_loss: 2.6873 - val_categorical_accuracy: 0.4818
# Epoch 70/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 1.9029 - categorical_accuracy: 0.7627 - val_loss: 2.7013 - val_categorical_accuracy: 0.4741
# Epoch 71/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 1.9012 - categorical_accuracy: 0.7560 - val_loss: 2.6916 - val_categorical_accuracy: 0.4741
# Epoch 72/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 1.8764 - categorical_accuracy: 0.7635 - val_loss: 2.6229 - val_categorical_accuracy: 0.5240
# Epoch 73/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 1.8577 - categorical_accuracy: 0.7666 - val_loss: 2.6436 - val_categorical_accuracy: 0.4875
# Epoch 74/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 1.8185 - categorical_accuracy: 0.7845 - val_loss: 2.7107 - val_categorical_accuracy: 0.4434
# Epoch 75/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 1.8117 - categorical_accuracy: 0.7798 - val_loss: 2.7860 - val_categorical_accuracy: 0.4069
# Epoch 76/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 1.8030 - categorical_accuracy: 0.7736 - val_loss: 2.6704 - val_categorical_accuracy: 0.4491
# Epoch 77/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 1.7679 - categorical_accuracy: 0.7850 - val_loss: 2.6367 - val_categorical_accuracy: 0.4683
# Epoch 78/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 1.7579 - categorical_accuracy: 0.7876 - val_loss: 2.6598 - val_categorical_accuracy: 0.4530
# Epoch 79/450
# 3860/3860 [==============================] - 1s 299us/sample - loss: 1.7420 - categorical_accuracy: 0.7889 - val_loss: 2.6697 - val_categorical_accuracy: 0.4357
# Epoch 80/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 1.7260 - categorical_accuracy: 0.7881 - val_loss: 2.7034 - val_categorical_accuracy: 0.4223
# Epoch 81/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 1.7106 - categorical_accuracy: 0.7826 - val_loss: 2.7204 - val_categorical_accuracy: 0.4223
# Epoch 82/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 1.6906 - categorical_accuracy: 0.8005 - val_loss: 2.5275 - val_categorical_accuracy: 0.5163
# Epoch 83/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 1.6664 - categorical_accuracy: 0.8057 - val_loss: 2.6436 - val_categorical_accuracy: 0.4472
# Epoch 84/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 1.6493 - categorical_accuracy: 0.8085 - val_loss: 2.6216 - val_categorical_accuracy: 0.4530
# Epoch 85/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 1.6399 - categorical_accuracy: 0.8117 - val_loss: 2.5955 - val_categorical_accuracy: 0.4568
# Epoch 86/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 1.6396 - categorical_accuracy: 0.7995 - val_loss: 2.5143 - val_categorical_accuracy: 0.5010
# Epoch 87/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 1.6160 - categorical_accuracy: 0.8065 - val_loss: 2.5289 - val_categorical_accuracy: 0.4971
# Epoch 88/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 1.5754 - categorical_accuracy: 0.8199 - val_loss: 2.4977 - val_categorical_accuracy: 0.4971
# Epoch 89/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 1.5654 - categorical_accuracy: 0.8282 - val_loss: 2.4487 - val_categorical_accuracy: 0.5509
# Epoch 90/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 1.5413 - categorical_accuracy: 0.8293 - val_loss: 2.4406 - val_categorical_accuracy: 0.5259
# Epoch 91/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 1.5337 - categorical_accuracy: 0.8238 - val_loss: 2.5214 - val_categorical_accuracy: 0.4607
# Epoch 92/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 1.5335 - categorical_accuracy: 0.8319 - val_loss: 2.4863 - val_categorical_accuracy: 0.4875
# Epoch 93/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 1.5083 - categorical_accuracy: 0.8303 - val_loss: 2.6413 - val_categorical_accuracy: 0.4242
# Epoch 94/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 1.4893 - categorical_accuracy: 0.8311 - val_loss: 2.4695 - val_categorical_accuracy: 0.5067
# Epoch 95/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 1.4784 - categorical_accuracy: 0.8233 - val_loss: 2.4905 - val_categorical_accuracy: 0.4914
# Epoch 96/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 1.4754 - categorical_accuracy: 0.8347 - val_loss: 2.4905 - val_categorical_accuracy: 0.4914
# Epoch 97/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 1.4464 - categorical_accuracy: 0.8448 - val_loss: 2.4519 - val_categorical_accuracy: 0.5086
# Epoch 98/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 1.4477 - categorical_accuracy: 0.8355 - val_loss: 2.4354 - val_categorical_accuracy: 0.5067
# Epoch 99/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 1.4225 - categorical_accuracy: 0.8435 - val_loss: 2.4372 - val_categorical_accuracy: 0.4990
# Epoch 100/450
# 3860/3860 [==============================] - 1s 300us/sample - loss: 1.4067 - categorical_accuracy: 0.8412 - val_loss: 2.4424 - val_categorical_accuracy: 0.4875
# Epoch 101/450
# 3860/3860 [==============================] - 1s 300us/sample - loss: 1.3793 - categorical_accuracy: 0.8466 - val_loss: 2.3413 - val_categorical_accuracy: 0.5374
# Epoch 102/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 1.3822 - categorical_accuracy: 0.8456 - val_loss: 2.4159 - val_categorical_accuracy: 0.4779
# Epoch 103/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 1.3659 - categorical_accuracy: 0.8500 - val_loss: 2.3798 - val_categorical_accuracy: 0.5086
# Epoch 104/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 1.3516 - categorical_accuracy: 0.8544 - val_loss: 2.3430 - val_categorical_accuracy: 0.5413
# Epoch 105/450
# 3860/3860 [==============================] - 1s 299us/sample - loss: 1.3142 - categorical_accuracy: 0.8661 - val_loss: 2.3479 - val_categorical_accuracy: 0.5106
# Epoch 106/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 1.3200 - categorical_accuracy: 0.8544 - val_loss: 2.3985 - val_categorical_accuracy: 0.4779
# Epoch 107/450
# 3860/3860 [==============================] - 1s 299us/sample - loss: 1.3132 - categorical_accuracy: 0.8635 - val_loss: 2.3577 - val_categorical_accuracy: 0.4990
# Epoch 108/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 1.3003 - categorical_accuracy: 0.8588 - val_loss: 2.3115 - val_categorical_accuracy: 0.5259
# Epoch 109/450
# 3860/3860 [==============================] - 1s 299us/sample - loss: 1.2712 - categorical_accuracy: 0.8655 - val_loss: 2.3713 - val_categorical_accuracy: 0.4779
# Epoch 110/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 1.2807 - categorical_accuracy: 0.8601 - val_loss: 2.3776 - val_categorical_accuracy: 0.4894
# Epoch 111/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 1.2637 - categorical_accuracy: 0.8606 - val_loss: 2.3582 - val_categorical_accuracy: 0.5106
# Epoch 112/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 1.2502 - categorical_accuracy: 0.8630 - val_loss: 2.3042 - val_categorical_accuracy: 0.5278
# Epoch 113/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 1.2416 - categorical_accuracy: 0.8596 - val_loss: 2.2520 - val_categorical_accuracy: 0.5662
# Epoch 114/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 1.2427 - categorical_accuracy: 0.8611 - val_loss: 2.3262 - val_categorical_accuracy: 0.5163
# Epoch 115/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 1.2084 - categorical_accuracy: 0.8754 - val_loss: 2.2942 - val_categorical_accuracy: 0.5259
# Epoch 116/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 1.1990 - categorical_accuracy: 0.8692 - val_loss: 2.2640 - val_categorical_accuracy: 0.5681
# Epoch 117/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 1.1909 - categorical_accuracy: 0.8785 - val_loss: 2.2837 - val_categorical_accuracy: 0.5125
# Epoch 118/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 1.1748 - categorical_accuracy: 0.8738 - val_loss: 2.3075 - val_categorical_accuracy: 0.4914
# Epoch 119/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 1.1768 - categorical_accuracy: 0.8793 - val_loss: 2.2707 - val_categorical_accuracy: 0.5393
# Epoch 120/450
# 3860/3860 [==============================] - 1s 300us/sample - loss: 1.1596 - categorical_accuracy: 0.8808 - val_loss: 2.2871 - val_categorical_accuracy: 0.5182
# Epoch 121/450
# 3860/3860 [==============================] - 1s 299us/sample - loss: 1.1465 - categorical_accuracy: 0.8845 - val_loss: 2.3650 - val_categorical_accuracy: 0.4818
# Epoch 122/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 1.1408 - categorical_accuracy: 0.8808 - val_loss: 2.3294 - val_categorical_accuracy: 0.4856
# Epoch 123/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 1.1398 - categorical_accuracy: 0.8712 - val_loss: 2.3335 - val_categorical_accuracy: 0.5067
# Epoch 124/450
# 3860/3860 [==============================] - 1s 299us/sample - loss: 1.1196 - categorical_accuracy: 0.8790 - val_loss: 2.2966 - val_categorical_accuracy: 0.5067
# Epoch 125/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 1.0993 - categorical_accuracy: 0.8899 - val_loss: 2.3412 - val_categorical_accuracy: 0.4760
# Epoch 126/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 1.0739 - categorical_accuracy: 0.8953 - val_loss: 2.2276 - val_categorical_accuracy: 0.5681
# Epoch 127/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 1.0723 - categorical_accuracy: 0.8946 - val_loss: 2.2493 - val_categorical_accuracy: 0.5489
# Epoch 128/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 1.0677 - categorical_accuracy: 0.9013 - val_loss: 2.2245 - val_categorical_accuracy: 0.5566
# Epoch 129/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 1.0673 - categorical_accuracy: 0.8881 - val_loss: 2.2479 - val_categorical_accuracy: 0.5317
# Epoch 130/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 1.0513 - categorical_accuracy: 0.8969 - val_loss: 2.2695 - val_categorical_accuracy: 0.5163
# Epoch 131/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 1.0248 - categorical_accuracy: 0.9021 - val_loss: 2.2699 - val_categorical_accuracy: 0.5106
# Epoch 132/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 1.0320 - categorical_accuracy: 0.9028 - val_loss: 2.2859 - val_categorical_accuracy: 0.4933
# Epoch 133/450
# 3860/3860 [==============================] - 1s 300us/sample - loss: 1.0209 - categorical_accuracy: 0.8930 - val_loss: 2.1821 - val_categorical_accuracy: 0.5509
# Epoch 134/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 1.0103 - categorical_accuracy: 0.9003 - val_loss: 2.1754 - val_categorical_accuracy: 0.5470
# Epoch 135/450
# 3860/3860 [==============================] - 1s 299us/sample - loss: 1.0104 - categorical_accuracy: 0.8974 - val_loss: 2.1980 - val_categorical_accuracy: 0.5355
# Epoch 136/450
# 3860/3860 [==============================] - 1s 309us/sample - loss: 0.9771 - categorical_accuracy: 0.9044 - val_loss: 2.1734 - val_categorical_accuracy: 0.5585
# Epoch 137/450
# 3860/3860 [==============================] - 1s 300us/sample - loss: 0.9985 - categorical_accuracy: 0.8909 - val_loss: 2.1799 - val_categorical_accuracy: 0.5413
# Epoch 138/450
# 3860/3860 [==============================] - 1s 298us/sample - loss: 0.9876 - categorical_accuracy: 0.9003 - val_loss: 2.1890 - val_categorical_accuracy: 0.5374
# Epoch 139/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.9787 - categorical_accuracy: 0.9003 - val_loss: 2.1924 - val_categorical_accuracy: 0.5298
# Epoch 140/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 0.9498 - categorical_accuracy: 0.9008 - val_loss: 2.2036 - val_categorical_accuracy: 0.5221
# Epoch 141/450
# 3860/3860 [==============================] - 1s 299us/sample - loss: 0.9332 - categorical_accuracy: 0.9179 - val_loss: 2.1841 - val_categorical_accuracy: 0.5470
# Epoch 142/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 0.9364 - categorical_accuracy: 0.9093 - val_loss: 2.1578 - val_categorical_accuracy: 0.5432
# Epoch 143/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.9158 - categorical_accuracy: 0.9145 - val_loss: 2.1257 - val_categorical_accuracy: 0.5681
# Epoch 144/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.9224 - categorical_accuracy: 0.9140 - val_loss: 2.1463 - val_categorical_accuracy: 0.5298
# Epoch 145/450
# 3860/3860 [==============================] - 1s 297us/sample - loss: 0.9272 - categorical_accuracy: 0.9057 - val_loss: 2.1575 - val_categorical_accuracy: 0.5298
# Epoch 146/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.9090 - categorical_accuracy: 0.9078 - val_loss: 2.1338 - val_categorical_accuracy: 0.5355
# Epoch 147/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 0.8981 - categorical_accuracy: 0.9137 - val_loss: 2.1160 - val_categorical_accuracy: 0.5489
# Epoch 148/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 0.8690 - categorical_accuracy: 0.9275 - val_loss: 2.1536 - val_categorical_accuracy: 0.5144
# Epoch 149/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.8955 - categorical_accuracy: 0.9091 - val_loss: 2.1047 - val_categorical_accuracy: 0.5451
# Epoch 150/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 0.8766 - categorical_accuracy: 0.9088 - val_loss: 2.1510 - val_categorical_accuracy: 0.5163
# Epoch 151/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.8657 - categorical_accuracy: 0.9189 - val_loss: 2.0892 - val_categorical_accuracy: 0.5701
# Epoch 152/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 0.8705 - categorical_accuracy: 0.9161 - val_loss: 2.1135 - val_categorical_accuracy: 0.5432
# Epoch 153/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.8577 - categorical_accuracy: 0.9135 - val_loss: 2.1061 - val_categorical_accuracy: 0.5509
# Epoch 154/450
# 3860/3860 [==============================] - 1s 300us/sample - loss: 0.8465 - categorical_accuracy: 0.9153 - val_loss: 2.1200 - val_categorical_accuracy: 0.5470
# Epoch 155/450
# 3860/3860 [==============================] - 1s 300us/sample - loss: 0.8316 - categorical_accuracy: 0.9223 - val_loss: 2.1733 - val_categorical_accuracy: 0.5221
# Epoch 156/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.8524 - categorical_accuracy: 0.9137 - val_loss: 2.1089 - val_categorical_accuracy: 0.5643
# Epoch 157/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.8083 - categorical_accuracy: 0.9277 - val_loss: 2.1136 - val_categorical_accuracy: 0.5662
# Epoch 158/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 0.8063 - categorical_accuracy: 0.9246 - val_loss: 2.0656 - val_categorical_accuracy: 0.5739
# Epoch 159/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.7852 - categorical_accuracy: 0.9350 - val_loss: 2.0655 - val_categorical_accuracy: 0.5662
# Epoch 160/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 0.7864 - categorical_accuracy: 0.9321 - val_loss: 2.0565 - val_categorical_accuracy: 0.5854
# Epoch 161/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.7930 - categorical_accuracy: 0.9259 - val_loss: 2.0999 - val_categorical_accuracy: 0.5681
# Epoch 162/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 0.7886 - categorical_accuracy: 0.9231 - val_loss: 2.1809 - val_categorical_accuracy: 0.5067
# Epoch 163/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.7933 - categorical_accuracy: 0.9205 - val_loss: 2.1090 - val_categorical_accuracy: 0.5489
# Epoch 164/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 0.7897 - categorical_accuracy: 0.9205 - val_loss: 2.1297 - val_categorical_accuracy: 0.5489
# Epoch 165/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.7850 - categorical_accuracy: 0.9181 - val_loss: 2.1309 - val_categorical_accuracy: 0.5470
# Epoch 166/450
# 3860/3860 [==============================] - 1s 312us/sample - loss: 0.7709 - categorical_accuracy: 0.9254 - val_loss: 2.1758 - val_categorical_accuracy: 0.5374
# Epoch 167/450
# 3860/3860 [==============================] - 1s 309us/sample - loss: 0.7714 - categorical_accuracy: 0.9207 - val_loss: 2.1130 - val_categorical_accuracy: 0.5912
# Epoch 168/450
# 3860/3860 [==============================] - 1s 309us/sample - loss: 0.7639 - categorical_accuracy: 0.9212 - val_loss: 2.1021 - val_categorical_accuracy: 0.5758
# Epoch 169/450
# 3860/3860 [==============================] - 1s 314us/sample - loss: 0.7410 - categorical_accuracy: 0.9345 - val_loss: 2.0712 - val_categorical_accuracy: 0.5605
# Epoch 170/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.7472 - categorical_accuracy: 0.9267 - val_loss: 2.0783 - val_categorical_accuracy: 0.5470
# Epoch 171/450
# 3860/3860 [==============================] - 1s 308us/sample - loss: 0.7259 - categorical_accuracy: 0.9378 - val_loss: 2.0674 - val_categorical_accuracy: 0.5758
# Epoch 172/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.7299 - categorical_accuracy: 0.9277 - val_loss: 2.0784 - val_categorical_accuracy: 0.5547
# Epoch 173/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 0.7172 - categorical_accuracy: 0.9329 - val_loss: 2.1077 - val_categorical_accuracy: 0.5605
# Epoch 174/450
# 3860/3860 [==============================] - 1s 310us/sample - loss: 0.7220 - categorical_accuracy: 0.9321 - val_loss: 2.0845 - val_categorical_accuracy: 0.5509
# Epoch 175/450
# 3860/3860 [==============================] - 1s 308us/sample - loss: 0.7075 - categorical_accuracy: 0.9251 - val_loss: 2.0827 - val_categorical_accuracy: 0.5298
# Epoch 176/450
# 3860/3860 [==============================] - 1s 310us/sample - loss: 0.7076 - categorical_accuracy: 0.9347 - val_loss: 2.0605 - val_categorical_accuracy: 0.5893
# Epoch 177/450
# 3860/3860 [==============================] - 1s 308us/sample - loss: 0.6968 - categorical_accuracy: 0.9409 - val_loss: 2.0933 - val_categorical_accuracy: 0.5509
# Epoch 178/450
# 3860/3860 [==============================] - 1s 309us/sample - loss: 0.6959 - categorical_accuracy: 0.9321 - val_loss: 2.1024 - val_categorical_accuracy: 0.5182
# Epoch 179/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.6814 - categorical_accuracy: 0.9326 - val_loss: 2.0982 - val_categorical_accuracy: 0.5163
# Epoch 180/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.6815 - categorical_accuracy: 0.9342 - val_loss: 2.1397 - val_categorical_accuracy: 0.5259
# Epoch 181/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 0.6973 - categorical_accuracy: 0.9363 - val_loss: 2.1191 - val_categorical_accuracy: 0.5489
# Epoch 182/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.6760 - categorical_accuracy: 0.9355 - val_loss: 2.0904 - val_categorical_accuracy: 0.5701
# Epoch 183/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.6403 - categorical_accuracy: 0.9472 - val_loss: 2.1038 - val_categorical_accuracy: 0.5681
# Epoch 184/450
# 3860/3860 [==============================] - 1s 317us/sample - loss: 0.6706 - categorical_accuracy: 0.9329 - val_loss: 2.1241 - val_categorical_accuracy: 0.5739
# Epoch 185/450
# 3860/3860 [==============================] - 1s 310us/sample - loss: 0.6680 - categorical_accuracy: 0.9332 - val_loss: 2.1416 - val_categorical_accuracy: 0.5854
# Epoch 186/450
# 3860/3860 [==============================] - 1s 309us/sample - loss: 0.6382 - categorical_accuracy: 0.9399 - val_loss: 2.1559 - val_categorical_accuracy: 0.5413
# Epoch 187/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.6622 - categorical_accuracy: 0.9313 - val_loss: 2.1509 - val_categorical_accuracy: 0.5298
# Epoch 188/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.6437 - categorical_accuracy: 0.9415 - val_loss: 2.0912 - val_categorical_accuracy: 0.5605
# Epoch 189/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.6446 - categorical_accuracy: 0.9347 - val_loss: 2.0556 - val_categorical_accuracy: 0.5528
# Epoch 190/450
# 3860/3860 [==============================] - 1s 312us/sample - loss: 0.6266 - categorical_accuracy: 0.9409 - val_loss: 2.0722 - val_categorical_accuracy: 0.5816
# Epoch 191/450
# 3860/3860 [==============================] - 1s 309us/sample - loss: 0.6269 - categorical_accuracy: 0.9358 - val_loss: 2.0765 - val_categorical_accuracy: 0.5528
# Epoch 192/450
# 3860/3860 [==============================] - 1s 310us/sample - loss: 0.6296 - categorical_accuracy: 0.9358 - val_loss: 2.0823 - val_categorical_accuracy: 0.5509
# Epoch 193/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.6134 - categorical_accuracy: 0.9435 - val_loss: 2.0847 - val_categorical_accuracy: 0.5547
# Epoch 194/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 0.6082 - categorical_accuracy: 0.9415 - val_loss: 2.1046 - val_categorical_accuracy: 0.5470
# Epoch 195/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.6030 - categorical_accuracy: 0.9469 - val_loss: 2.1181 - val_categorical_accuracy: 0.5393
# Epoch 196/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.6104 - categorical_accuracy: 0.9402 - val_loss: 2.1083 - val_categorical_accuracy: 0.5605
# Epoch 197/450
# 3860/3860 [==============================] - 1s 308us/sample - loss: 0.6065 - categorical_accuracy: 0.9376 - val_loss: 2.1329 - val_categorical_accuracy: 0.5739
# Epoch 198/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.5971 - categorical_accuracy: 0.9381 - val_loss: 2.1161 - val_categorical_accuracy: 0.5413
# Epoch 199/450
# 3860/3860 [==============================] - 1s 312us/sample - loss: 0.5913 - categorical_accuracy: 0.9461 - val_loss: 2.1028 - val_categorical_accuracy: 0.5758
# Epoch 200/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 0.5859 - categorical_accuracy: 0.9479 - val_loss: 2.0947 - val_categorical_accuracy: 0.5662
# Epoch 201/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.5807 - categorical_accuracy: 0.9487 - val_loss: 2.1566 - val_categorical_accuracy: 0.5451
# Epoch 202/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.5745 - categorical_accuracy: 0.9472 - val_loss: 2.1214 - val_categorical_accuracy: 0.5355
# Epoch 203/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.5726 - categorical_accuracy: 0.9402 - val_loss: 2.0813 - val_categorical_accuracy: 0.5643
# Epoch 204/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 0.5674 - categorical_accuracy: 0.9448 - val_loss: 2.1003 - val_categorical_accuracy: 0.5566
# Epoch 205/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.5552 - categorical_accuracy: 0.9516 - val_loss: 2.0715 - val_categorical_accuracy: 0.5489
# Epoch 206/450
# 3860/3860 [==============================] - 1s 308us/sample - loss: 0.5457 - categorical_accuracy: 0.9448 - val_loss: 2.0281 - val_categorical_accuracy: 0.5470
# Epoch 207/450
# 3860/3860 [==============================] - 1s 313us/sample - loss: 0.5576 - categorical_accuracy: 0.9492 - val_loss: 2.0735 - val_categorical_accuracy: 0.5643
# Epoch 208/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.5549 - categorical_accuracy: 0.9438 - val_loss: 2.0397 - val_categorical_accuracy: 0.5585
# Epoch 209/450
# 3860/3860 [==============================] - 1s 308us/sample - loss: 0.5518 - categorical_accuracy: 0.9482 - val_loss: 2.1083 - val_categorical_accuracy: 0.5413
# Epoch 210/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.5353 - categorical_accuracy: 0.9443 - val_loss: 2.0688 - val_categorical_accuracy: 0.5758
# Epoch 211/450
# 3860/3860 [==============================] - 1s 308us/sample - loss: 0.5320 - categorical_accuracy: 0.9451 - val_loss: 2.0660 - val_categorical_accuracy: 0.5432
# Epoch 212/450
# 3860/3860 [==============================] - 1s 308us/sample - loss: 0.5294 - categorical_accuracy: 0.9482 - val_loss: 2.0673 - val_categorical_accuracy: 0.5413
# Epoch 213/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.5143 - categorical_accuracy: 0.9557 - val_loss: 2.0592 - val_categorical_accuracy: 0.5605
# Epoch 214/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.5127 - categorical_accuracy: 0.9541 - val_loss: 2.0383 - val_categorical_accuracy: 0.5988
# Epoch 215/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.5183 - categorical_accuracy: 0.9490 - val_loss: 2.0359 - val_categorical_accuracy: 0.5585
# Epoch 216/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.5288 - categorical_accuracy: 0.9513 - val_loss: 2.0764 - val_categorical_accuracy: 0.5528
# Epoch 217/450
# 3860/3860 [==============================] - 1s 310us/sample - loss: 0.5298 - categorical_accuracy: 0.9508 - val_loss: 2.0642 - val_categorical_accuracy: 0.5528
# Epoch 218/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 0.5142 - categorical_accuracy: 0.9448 - val_loss: 2.0526 - val_categorical_accuracy: 0.5547
# Epoch 219/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 0.5183 - categorical_accuracy: 0.9477 - val_loss: 2.0766 - val_categorical_accuracy: 0.5489
# Epoch 220/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 0.5207 - categorical_accuracy: 0.9404 - val_loss: 2.1289 - val_categorical_accuracy: 0.5374
# Epoch 221/450
# 3860/3860 [==============================] - 1s 311us/sample - loss: 0.5143 - categorical_accuracy: 0.9422 - val_loss: 2.0835 - val_categorical_accuracy: 0.5566
# Epoch 222/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 0.5020 - categorical_accuracy: 0.9492 - val_loss: 2.1069 - val_categorical_accuracy: 0.5470
# Epoch 223/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.4972 - categorical_accuracy: 0.9490 - val_loss: 2.0977 - val_categorical_accuracy: 0.5393
# Epoch 224/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.5013 - categorical_accuracy: 0.9513 - val_loss: 2.0863 - val_categorical_accuracy: 0.5509
# Epoch 225/450
# 3860/3860 [==============================] - 1s 309us/sample - loss: 0.4943 - categorical_accuracy: 0.9490 - val_loss: 2.0820 - val_categorical_accuracy: 0.5278
# Epoch 226/450
# 3860/3860 [==============================] - 1s 308us/sample - loss: 0.4897 - categorical_accuracy: 0.9536 - val_loss: 2.0615 - val_categorical_accuracy: 0.5509
# Epoch 227/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.4844 - categorical_accuracy: 0.9490 - val_loss: 2.0244 - val_categorical_accuracy: 0.5758
# Epoch 228/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 0.4767 - categorical_accuracy: 0.9560 - val_loss: 1.9989 - val_categorical_accuracy: 0.5777
# Epoch 229/450
# 3860/3860 [==============================] - 1s 310us/sample - loss: 0.4704 - categorical_accuracy: 0.9573 - val_loss: 1.9964 - val_categorical_accuracy: 0.5681
# Epoch 230/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.4965 - categorical_accuracy: 0.9459 - val_loss: 2.0475 - val_categorical_accuracy: 0.5451
# Epoch 231/450
# 3860/3860 [==============================] - 1s 308us/sample - loss: 0.4754 - categorical_accuracy: 0.9495 - val_loss: 2.0293 - val_categorical_accuracy: 0.5777
# Epoch 232/450
# 3860/3860 [==============================] - 1s 308us/sample - loss: 0.4736 - categorical_accuracy: 0.9510 - val_loss: 2.0829 - val_categorical_accuracy: 0.5605
# Epoch 233/450
# 3860/3860 [==============================] - 1s 310us/sample - loss: 0.4805 - categorical_accuracy: 0.9503 - val_loss: 2.0560 - val_categorical_accuracy: 0.5643
# Epoch 234/450
# 3860/3860 [==============================] - 1s 308us/sample - loss: 0.4762 - categorical_accuracy: 0.9528 - val_loss: 2.0442 - val_categorical_accuracy: 0.5355
# Epoch 235/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.4649 - categorical_accuracy: 0.9541 - val_loss: 1.9997 - val_categorical_accuracy: 0.5701
# Epoch 236/450
# 3860/3860 [==============================] - 1s 309us/sample - loss: 0.4678 - categorical_accuracy: 0.9503 - val_loss: 2.0419 - val_categorical_accuracy: 0.5643
# Epoch 237/450
# 3860/3860 [==============================] - 1s 309us/sample - loss: 0.4771 - categorical_accuracy: 0.9469 - val_loss: 2.0119 - val_categorical_accuracy: 0.5835
# Epoch 238/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.4589 - categorical_accuracy: 0.9547 - val_loss: 2.0026 - val_categorical_accuracy: 0.5739
# Epoch 239/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.4515 - categorical_accuracy: 0.9510 - val_loss: 1.9698 - val_categorical_accuracy: 0.5873
# Epoch 240/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.4499 - categorical_accuracy: 0.9583 - val_loss: 1.9160 - val_categorical_accuracy: 0.5873
# Epoch 241/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.4440 - categorical_accuracy: 0.9534 - val_loss: 2.0132 - val_categorical_accuracy: 0.6084
# Epoch 242/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 0.4454 - categorical_accuracy: 0.9549 - val_loss: 1.9777 - val_categorical_accuracy: 0.5873
# Epoch 243/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.4343 - categorical_accuracy: 0.9560 - val_loss: 2.0083 - val_categorical_accuracy: 0.5643
# Epoch 244/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.4502 - categorical_accuracy: 0.9536 - val_loss: 1.9643 - val_categorical_accuracy: 0.5854
# Epoch 245/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.4408 - categorical_accuracy: 0.9557 - val_loss: 2.0114 - val_categorical_accuracy: 0.5720
# Epoch 246/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.4387 - categorical_accuracy: 0.9560 - val_loss: 2.0206 - val_categorical_accuracy: 0.5701
# Epoch 247/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 0.4431 - categorical_accuracy: 0.9513 - val_loss: 2.0464 - val_categorical_accuracy: 0.5701
# Epoch 248/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.4297 - categorical_accuracy: 0.9536 - val_loss: 2.0419 - val_categorical_accuracy: 0.5547
# Epoch 249/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.4365 - categorical_accuracy: 0.9539 - val_loss: 2.0142 - val_categorical_accuracy: 0.5643
# Epoch 250/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.4266 - categorical_accuracy: 0.9552 - val_loss: 2.0735 - val_categorical_accuracy: 0.5451
# Epoch 251/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.4177 - categorical_accuracy: 0.9601 - val_loss: 1.9906 - val_categorical_accuracy: 0.5893
# Epoch 252/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 0.4147 - categorical_accuracy: 0.9575 - val_loss: 2.0007 - val_categorical_accuracy: 0.5758
# Epoch 253/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.4005 - categorical_accuracy: 0.9645 - val_loss: 1.9328 - val_categorical_accuracy: 0.6123
# Epoch 254/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.4207 - categorical_accuracy: 0.9604 - val_loss: 1.9350 - val_categorical_accuracy: 0.6008
# Epoch 255/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.4105 - categorical_accuracy: 0.9619 - val_loss: 1.9992 - val_categorical_accuracy: 0.5624
# Epoch 256/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.4202 - categorical_accuracy: 0.9516 - val_loss: 2.0348 - val_categorical_accuracy: 0.5681
# Epoch 257/450
# 3860/3860 [==============================] - 1s 300us/sample - loss: 0.4074 - categorical_accuracy: 0.9585 - val_loss: 2.0500 - val_categorical_accuracy: 0.5605
# Epoch 258/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.3943 - categorical_accuracy: 0.9619 - val_loss: 2.0451 - val_categorical_accuracy: 0.5528
# Epoch 259/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.4122 - categorical_accuracy: 0.9585 - val_loss: 2.0757 - val_categorical_accuracy: 0.5701
# Epoch 260/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.3921 - categorical_accuracy: 0.9622 - val_loss: 2.0464 - val_categorical_accuracy: 0.5681
# Epoch 261/450
# 3860/3860 [==============================] - 1s 309us/sample - loss: 0.3963 - categorical_accuracy: 0.9632 - val_loss: 2.0625 - val_categorical_accuracy: 0.5470
# Epoch 262/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 0.3972 - categorical_accuracy: 0.9614 - val_loss: 2.0522 - val_categorical_accuracy: 0.5643
# Epoch 263/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.3924 - categorical_accuracy: 0.9614 - val_loss: 2.0574 - val_categorical_accuracy: 0.5585
# Epoch 264/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.3746 - categorical_accuracy: 0.9692 - val_loss: 1.9979 - val_categorical_accuracy: 0.5893
# Epoch 265/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 0.4020 - categorical_accuracy: 0.9531 - val_loss: 2.0094 - val_categorical_accuracy: 0.5566
# Epoch 266/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.4055 - categorical_accuracy: 0.9547 - val_loss: 2.0026 - val_categorical_accuracy: 0.5950
# Epoch 267/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 0.3936 - categorical_accuracy: 0.9552 - val_loss: 1.9647 - val_categorical_accuracy: 0.6027
# Epoch 268/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.3903 - categorical_accuracy: 0.9526 - val_loss: 2.0145 - val_categorical_accuracy: 0.5854
# Epoch 269/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.3956 - categorical_accuracy: 0.9567 - val_loss: 2.0725 - val_categorical_accuracy: 0.5681
# Epoch 270/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.3799 - categorical_accuracy: 0.9606 - val_loss: 2.0517 - val_categorical_accuracy: 0.5931
# Epoch 00270: early stopping
# 521/521 [==============================] - 0s 688us/sample - loss: 2.0517 - categorical_accuracy: 0.5931
# [2.0516695298983816, 0.59309024]
# Train on 3860 samples, validate on 521 samples
# Epoch 1/450
# 3860/3860 [==============================] - 3s 694us/sample - loss: 4.8541 - categorical_accuracy: 0.3321 - val_loss: 3.9968 - val_categorical_accuracy: 0.6564
# ...
# Epoch 121/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 1.1436 - categorical_accuracy: 0.8842 - val_loss: 2.2267 - val_categorical_accuracy: 0.5355
# Epoch 122/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 1.1359 - categorical_accuracy: 0.8811 - val_loss: 2.2584 - val_categorical_accuracy: 0.5240
# Epoch 123/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 1.1272 - categorical_accuracy: 0.8795 - val_loss: 2.2101 - val_categorical_accuracy: 0.5393
# Epoch 124/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 1.1139 - categorical_accuracy: 0.8927 - val_loss: 2.2290 - val_categorical_accuracy: 0.5432
# Epoch 125/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 1.1160 - categorical_accuracy: 0.8863 - val_loss: 2.2098 - val_categorical_accuracy: 0.5470
# Epoch 126/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 1.0810 - categorical_accuracy: 0.8938 - val_loss: 2.2042 - val_categorical_accuracy: 0.5509
# Epoch 127/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 1.0816 - categorical_accuracy: 0.8920 - val_loss: 2.2177 - val_categorical_accuracy: 0.5528
# Epoch 128/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 1.0603 - categorical_accuracy: 0.8938 - val_loss: 2.1802 - val_categorical_accuracy: 0.5547
# Epoch 129/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 1.0524 - categorical_accuracy: 0.8984 - val_loss: 2.1762 - val_categorical_accuracy: 0.5489
# Epoch 130/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 1.0604 - categorical_accuracy: 0.8943 - val_loss: 2.2155 - val_categorical_accuracy: 0.5298
# Epoch 131/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 1.0331 - categorical_accuracy: 0.8982 - val_loss: 2.1424 - val_categorical_accuracy: 0.5451
# Epoch 132/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 1.0389 - categorical_accuracy: 0.8959 - val_loss: 2.2120 - val_categorical_accuracy: 0.5125
# Epoch 133/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 1.0067 - categorical_accuracy: 0.9013 - val_loss: 2.1855 - val_categorical_accuracy: 0.5336
# Epoch 134/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 1.0084 - categorical_accuracy: 0.9044 - val_loss: 2.1941 - val_categorical_accuracy: 0.5163
# Epoch 135/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 1.0071 - categorical_accuracy: 0.9039 - val_loss: 2.1381 - val_categorical_accuracy: 0.5470
# Epoch 136/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 0.9861 - categorical_accuracy: 0.9062 - val_loss: 2.1111 - val_categorical_accuracy: 0.5470
# Epoch 137/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 0.9815 - categorical_accuracy: 0.9054 - val_loss: 2.1784 - val_categorical_accuracy: 0.5374
# Epoch 138/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.9837 - categorical_accuracy: 0.9005 - val_loss: 2.1801 - val_categorical_accuracy: 0.5317
# Epoch 139/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 0.9720 - categorical_accuracy: 0.9096 - val_loss: 2.1749 - val_categorical_accuracy: 0.5432
# Epoch 140/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.9408 - categorical_accuracy: 0.9130 - val_loss: 2.1220 - val_categorical_accuracy: 0.5585
# Epoch 141/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.9391 - categorical_accuracy: 0.9132 - val_loss: 2.2166 - val_categorical_accuracy: 0.4933
# Epoch 142/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 0.9296 - categorical_accuracy: 0.9132 - val_loss: 2.1709 - val_categorical_accuracy: 0.5163
# Epoch 143/450
# 3860/3860 [==============================] - 1s 309us/sample - loss: 0.9187 - categorical_accuracy: 0.9212 - val_loss: 2.1322 - val_categorical_accuracy: 0.5547
# Epoch 144/450
# 3860/3860 [==============================] - 1s 310us/sample - loss: 0.9070 - categorical_accuracy: 0.9163 - val_loss: 2.1057 - val_categorical_accuracy: 0.5643
# Epoch 145/450
# 3860/3860 [==============================] - 1s 310us/sample - loss: 0.9205 - categorical_accuracy: 0.9062 - val_loss: 2.1002 - val_categorical_accuracy: 0.5777
# Epoch 146/450
# 3860/3860 [==============================] - 1s 309us/sample - loss: 0.9086 - categorical_accuracy: 0.9106 - val_loss: 2.1001 - val_categorical_accuracy: 0.5701
# Epoch 147/450
# 3860/3860 [==============================] - 1s 309us/sample - loss: 0.8995 - categorical_accuracy: 0.9153 - val_loss: 2.1229 - val_categorical_accuracy: 0.5528
# Epoch 148/450
# 3860/3860 [==============================] - 1s 309us/sample - loss: 0.8967 - categorical_accuracy: 0.9124 - val_loss: 2.2173 - val_categorical_accuracy: 0.4856
# Epoch 149/450
# 3860/3860 [==============================] - 1s 309us/sample - loss: 0.8941 - categorical_accuracy: 0.9142 - val_loss: 2.1378 - val_categorical_accuracy: 0.5413
# Epoch 150/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 0.8716 - categorical_accuracy: 0.9119 - val_loss: 2.0956 - val_categorical_accuracy: 0.5816
# Epoch 151/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.8641 - categorical_accuracy: 0.9192 - val_loss: 2.1242 - val_categorical_accuracy: 0.5547
# Epoch 152/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.8793 - categorical_accuracy: 0.9124 - val_loss: 2.1275 - val_categorical_accuracy: 0.5547
# Epoch 153/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.8568 - categorical_accuracy: 0.9189 - val_loss: 2.0870 - val_categorical_accuracy: 0.5816
# Epoch 154/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.8419 - categorical_accuracy: 0.9184 - val_loss: 2.0763 - val_categorical_accuracy: 0.5739
# Epoch 155/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 0.8373 - categorical_accuracy: 0.9251 - val_loss: 2.1356 - val_categorical_accuracy: 0.5393
# Epoch 156/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.8351 - categorical_accuracy: 0.9194 - val_loss: 2.1385 - val_categorical_accuracy: 0.5489
# Epoch 157/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.8196 - categorical_accuracy: 0.9212 - val_loss: 2.1013 - val_categorical_accuracy: 0.5547
# Epoch 158/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.8176 - categorical_accuracy: 0.9264 - val_loss: 2.0852 - val_categorical_accuracy: 0.5701
# Epoch 159/450
# 3860/3860 [==============================] - 1s 309us/sample - loss: 0.8073 - categorical_accuracy: 0.9212 - val_loss: 2.0862 - val_categorical_accuracy: 0.5547
# Epoch 160/450
# 3860/3860 [==============================] - 1s 309us/sample - loss: 0.7978 - categorical_accuracy: 0.9285 - val_loss: 2.0847 - val_categorical_accuracy: 0.5816
# Epoch 161/450
# 3860/3860 [==============================] - 1s 312us/sample - loss: 0.8124 - categorical_accuracy: 0.9256 - val_loss: 2.1057 - val_categorical_accuracy: 0.5566
# Epoch 162/450
# 3860/3860 [==============================] - 1s 316us/sample - loss: 0.7863 - categorical_accuracy: 0.9231 - val_loss: 2.0849 - val_categorical_accuracy: 0.5624
# Epoch 163/450
# 3860/3860 [==============================] - 1s 313us/sample - loss: 0.7852 - categorical_accuracy: 0.9236 - val_loss: 2.1039 - val_categorical_accuracy: 0.5547
# Epoch 164/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.7694 - categorical_accuracy: 0.9321 - val_loss: 2.0844 - val_categorical_accuracy: 0.5739
# Epoch 165/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.7601 - categorical_accuracy: 0.9298 - val_loss: 2.0971 - val_categorical_accuracy: 0.5624
# Epoch 166/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.7654 - categorical_accuracy: 0.9236 - val_loss: 2.0844 - val_categorical_accuracy: 0.5681
# Epoch 167/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.7518 - categorical_accuracy: 0.9321 - val_loss: 2.1552 - val_categorical_accuracy: 0.5432
# Epoch 168/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.7532 - categorical_accuracy: 0.9298 - val_loss: 2.1047 - val_categorical_accuracy: 0.5662
# Epoch 169/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.7469 - categorical_accuracy: 0.9311 - val_loss: 2.0913 - val_categorical_accuracy: 0.5566
# Epoch 170/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.7391 - categorical_accuracy: 0.9368 - val_loss: 2.0758 - val_categorical_accuracy: 0.5777
# Epoch 171/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.7281 - categorical_accuracy: 0.9347 - val_loss: 2.0685 - val_categorical_accuracy: 0.5701
# Epoch 172/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.7332 - categorical_accuracy: 0.9293 - val_loss: 2.0549 - val_categorical_accuracy: 0.5816
# Epoch 173/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.7059 - categorical_accuracy: 0.9378 - val_loss: 2.0271 - val_categorical_accuracy: 0.5797
# Epoch 174/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.7206 - categorical_accuracy: 0.9282 - val_loss: 2.0501 - val_categorical_accuracy: 0.5547
# Epoch 175/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.7066 - categorical_accuracy: 0.9358 - val_loss: 2.0372 - val_categorical_accuracy: 0.5643
# Epoch 176/450
# 3860/3860 [==============================] - 1s 306us/sample - loss: 0.7048 - categorical_accuracy: 0.9324 - val_loss: 2.0503 - val_categorical_accuracy: 0.5643
# Epoch 177/450
# 3860/3860 [==============================] - 1s 308us/sample - loss: 0.6949 - categorical_accuracy: 0.9321 - val_loss: 2.0413 - val_categorical_accuracy: 0.5643
# Epoch 178/450
# 3860/3860 [==============================] - 1s 310us/sample - loss: 0.6792 - categorical_accuracy: 0.9420 - val_loss: 2.0263 - val_categorical_accuracy: 0.5720
# Epoch 179/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.6821 - categorical_accuracy: 0.9339 - val_loss: 1.9728 - val_categorical_accuracy: 0.6123
# Epoch 180/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.6805 - categorical_accuracy: 0.9347 - val_loss: 1.9605 - val_categorical_accuracy: 0.6084
# Epoch 181/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.6854 - categorical_accuracy: 0.9370 - val_loss: 2.0240 - val_categorical_accuracy: 0.5605
# Epoch 182/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 0.6624 - categorical_accuracy: 0.9415 - val_loss: 2.0584 - val_categorical_accuracy: 0.5662
# Epoch 183/450
# 3860/3860 [==============================] - 1s 296us/sample - loss: 0.6631 - categorical_accuracy: 0.9391 - val_loss: 2.0517 - val_categorical_accuracy: 0.5566
# Epoch 184/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.6639 - categorical_accuracy: 0.9324 - val_loss: 2.1089 - val_categorical_accuracy: 0.5125
# Epoch 185/450
# 3860/3860 [==============================] - 1s 299us/sample - loss: 0.6574 - categorical_accuracy: 0.9389 - val_loss: 2.0536 - val_categorical_accuracy: 0.5202
# Epoch 186/450
# 3860/3860 [==============================] - 1s 298us/sample - loss: 0.6641 - categorical_accuracy: 0.9319 - val_loss: 2.0658 - val_categorical_accuracy: 0.5451
# Epoch 187/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.6395 - categorical_accuracy: 0.9420 - val_loss: 2.0468 - val_categorical_accuracy: 0.5720
# Epoch 188/450
# 3860/3860 [==============================] - 1s 298us/sample - loss: 0.6609 - categorical_accuracy: 0.9337 - val_loss: 2.0076 - val_categorical_accuracy: 0.5854
# Epoch 189/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.6346 - categorical_accuracy: 0.9422 - val_loss: 2.0016 - val_categorical_accuracy: 0.5739
# Epoch 190/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.6282 - categorical_accuracy: 0.9368 - val_loss: 1.9982 - val_categorical_accuracy: 0.5720
# Epoch 191/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.6204 - categorical_accuracy: 0.9425 - val_loss: 1.9923 - val_categorical_accuracy: 0.5893
# Epoch 192/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.6327 - categorical_accuracy: 0.9334 - val_loss: 2.0201 - val_categorical_accuracy: 0.5605
# Epoch 193/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.6235 - categorical_accuracy: 0.9404 - val_loss: 2.0436 - val_categorical_accuracy: 0.5585
# Epoch 194/450
# 3860/3860 [==============================] - 1s 307us/sample - loss: 0.6273 - categorical_accuracy: 0.9352 - val_loss: 1.9937 - val_categorical_accuracy: 0.5988
# Epoch 195/450
# 3860/3860 [==============================] - 1s 310us/sample - loss: 0.6076 - categorical_accuracy: 0.9453 - val_loss: 1.9631 - val_categorical_accuracy: 0.5969
# Epoch 196/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 0.6018 - categorical_accuracy: 0.9479 - val_loss: 2.0103 - val_categorical_accuracy: 0.5662
# Epoch 197/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.6021 - categorical_accuracy: 0.9399 - val_loss: 1.9864 - val_categorical_accuracy: 0.5739
# Epoch 198/450
# 3860/3860 [==============================] - 1s 300us/sample - loss: 0.5977 - categorical_accuracy: 0.9422 - val_loss: 2.0275 - val_categorical_accuracy: 0.5528
# Epoch 199/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.6072 - categorical_accuracy: 0.9347 - val_loss: 2.0089 - val_categorical_accuracy: 0.5739
# Epoch 200/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.6035 - categorical_accuracy: 0.9417 - val_loss: 2.0555 - val_categorical_accuracy: 0.5144
# Epoch 201/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.5758 - categorical_accuracy: 0.9451 - val_loss: 2.0832 - val_categorical_accuracy: 0.5202
# Epoch 202/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 0.5808 - categorical_accuracy: 0.9422 - val_loss: 2.0423 - val_categorical_accuracy: 0.5931
# Epoch 203/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.5860 - categorical_accuracy: 0.9383 - val_loss: 1.9835 - val_categorical_accuracy: 0.5873
# Epoch 204/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 0.5720 - categorical_accuracy: 0.9420 - val_loss: 1.9989 - val_categorical_accuracy: 0.5624
# Epoch 205/450
# 3860/3860 [==============================] - 1s 303us/sample - loss: 0.5745 - categorical_accuracy: 0.9440 - val_loss: 1.9953 - val_categorical_accuracy: 0.6084
# Epoch 206/450
# 3860/3860 [==============================] - 1s 302us/sample - loss: 0.5684 - categorical_accuracy: 0.9453 - val_loss: 1.9731 - val_categorical_accuracy: 0.5701
# Epoch 207/450
# 3860/3860 [==============================] - 1s 305us/sample - loss: 0.5651 - categorical_accuracy: 0.9453 - val_loss: 1.9994 - val_categorical_accuracy: 0.5873
# Epoch 208/450
# 3860/3860 [==============================] - 1s 304us/sample - loss: 0.5586 - categorical_accuracy: 0.9508 - val_loss: 1.9966 - val_categorical_accuracy: 0.5854
# Epoch 209/450
# 3860/3860 [==============================] - 1s 301us/sample - loss: 0.5631 - categorical_accuracy: 0.9422 - val_loss: 1.9946 - val_categorical_accuracy: 0.5758
# Epoch 210/450
# 3860/3860 [==============================] - 1s 297us/sample - loss: 0.5622 - categorical_accuracy: 0.9391 - val_loss: 2.0315 - val_categorical_accuracy: 0.5643
# Epoch 00210: early stopping
# 521/521 [==============================] - 0s 689us/sample - loss: 2.0315 - categorical_accuracy: 0.5643
# [2.031519941084673, 0.5642994]

# %% [markdown]
# ## Loss & Accuracy Curves

# %%
# Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
  
# Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['categorical_accuracy'],'r',linewidth=3.0)
plt.plot(history.history['val_categorical_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')
# Text(0.5, 1.0, 'Accuracy Curves')

# %% [markdown]
# # Performance

# %%
t0 = time.time()
image_labels_pred = model1.predict(images_test)
image_labels_pred = np.where(image_labels_pred > 0.5, 1, 0)
t1 = time.time()

total_prediction_time = t1-t0

# %%
y_true = np.argmax(image_labels_test,1) 
y_pred = np.argmax(image_labels_pred,1)

# %% [markdown]
# ## Confusion Matrix

# %%
cm =  pd.DataFrame(confusion_matrix(y_true, y_pred), 
                                 index = label_names_array, 
                                 columns = label_names_array)

plt.figure(figsize=[8,6])
sn.heatmap(cm, annot=True,cmap='Blues', fmt='g')

# %% [markdown]
# ## Classification Metrics

# %%
target_names = label_names_array
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         Sell       0.21      0.22      0.21        77
#          Buy       0.18      0.12      0.15        73
#         Hold       0.71      0.75      0.73       371
#
#     accuracy                           0.58       521
#    macro avg       0.37      0.36      0.36       521
# weighted avg       0.56      0.58      0.57       521
#
#               precision    recall  f1-score   support
#
#            S       0.19      0.21      0.20        77
#            B       0.17      0.18      0.18        73
#            H       0.73      0.71      0.72       371
#
#     accuracy                           0.56       521
#    macro avg       0.36      0.37      0.36       521
# weighted avg       0.57      0.56      0.57       521

# %% [markdown]
# ## Time spent

# %%
total_training_time = sum(time_callback.times)
print("Time spent on entire model training: {:4f} seconds".format(total_training_time))
# Out:
# Time spent on entire model training: 320.004637 seconds
# Time spent on entire model training: 248.592901 seconds

# %% [markdown]
# ## Financial Evaluation, Save predicton data in given format

# %%
#custom library
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/CNN/evaluation')
import financial_evaluation

# %%
# Create Signals from numbers here 
Signals = y_pred

prediction = pd.DataFrame(test_prices, columns = [VarName])
prediction['Signals'] = Signals
prediction['Signals'].loc[prediction['Signals'] == 0] = "Sell"
prediction['Signals'].loc[prediction['Signals'] == 1] = "Buy"
prediction['Signals'].loc[prediction['Signals'] == 2] = "Hold"
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#save results
prediction.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/PredForFinEval.csv")

# %%
fin_res = financial_evaluation.financial_evaluation(VarName, test_prices, prediction['Signals'], safety = True)
print("Annualized return is {}, cumulative return is {} and number of trades are {}.".format(fin_res['annualized_return'], fin_res['cumulative_return'], fin_res['all_trades']))
# Out:
# Annualized return is [0.02785212], cumulative return is [0.05659161] and number of trades are 37.

# %%
((10000-5)/test_prices[0]*test_prices[-1]-5)/10000 -1
# Out:
# array([-0.19427083])

# %% [markdown]
# ## Save Model

# %%
model1.save('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/model.h5")

# %% [markdown]
# ## Save true and pred

# %%
TruePred = pd.DataFrame(y_true, columns = [VarName])
TruePred['Prediction'] = y_pred
TruePred.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/True&Pred.csv")

# %% [markdown]
# ## Save Classification Metrics &  Save Times

# %%
Acc = np.float(accuracy_score(y_true=y_true, y_pred=y_pred))
#F1 = np.float(f1_score(y_true = y_true, y_pred = y_pred, average = 'macro'))
Prec = np.float(precision_score(y_true=y_true, y_pred=y_pred, average = 'macro'))
Recall = np.float(recall_score(y_true=y_true, y_pred=y_pred, average = 'macro'))

F1 = 2 * (Prec * Recall) / (Prec + Recall)

print(Acc, F1, Prec, Recall)
# Out:
# 0.5623800383877159 0.365054271099718 0.36429018883638403 0.3658215653563288

# %%
np.savez('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/Time&ClassificationEval.npz",
         accuracy = Acc,
         MacF1 = F1,
         MacPrecision = Prec,
         MacRecall = Recall,
         TrainTime = np.float(total_training_time),
         PredTime = np.float(total_prediction_time)
        )
