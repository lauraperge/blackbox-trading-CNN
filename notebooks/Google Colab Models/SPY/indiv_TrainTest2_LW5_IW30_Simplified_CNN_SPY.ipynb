# %%
# !pip install numpy==1.16.1
# !pip install tensorflow-gpu==2.0.0-beta1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
from sklearn.model_selection import TimeSeriesSplit
from sklearn.utils import class_weight
from sklearn.metrics import f1_score, confusion_matrix, classification_report, accuracy_score, precision_score, recall_score
import time

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, AveragePooling2D, BatchNormalization, LeakyReLU
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam, Nadam, SGD, RMSprop
from tensorflow.keras.callbacks import EarlyStopping

LR = LeakyReLU(alpha = .3)
LR.__name__ = 'leakyrelu'

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Requirement already satisfied: numpy==1.16.1 in /usr/local/lib/python3.6/dist-packages (1.16.1)
# Requirement already satisfied: tensorflow-gpu==2.0.0-beta1 in /usr/local/lib/python3.6/dist-packages (2.0.0b1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.2.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.0.8)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.7.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.12.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.16.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.15.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.33.4)
# Requirement already satisfied: tf-estimator-nightly<1.14.0.dev2019060502,>=1.14.0.dev2019060501 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.14.0.dev2019060501)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.11.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.1.7)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.8.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (3.7.1)
# Requirement already satisfied: tb-nightly<1.14.0a20190604,>=1.14.0a20190603 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.14.0a20190603)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==2.0.0-beta1) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==2.0.0-beta1) (41.0.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (0.15.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (3.1.1)
# Found GPU at: /device:GPU:0

# %%
# fix random seed for reproducibility
seed = 2
np.random.seed(seed)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Pre-Settings

# %%
Test = "test2"
Version = "_indiv_" #="univ"
VarName = "SPY"

if Test == "test1":
  tr_direct = "data_train_to2005"
  ts_direct = "data_test_2005Decto_2007Dec"
elif Test == "test2":
  tr_direct = "data_train_to2008"
  ts_direct = "data_test_2009Jan_to_2011Jan"
else:
  tr_direct = "data_train_to2017May"
  ts_direct = "data_test_2017May_to_2019last"

# %% [markdown]
# # Load data

# %%
if Version == "_indiv_":
  train_filename = "LW5_IW30/" + tr_direct + "/" + Version[1:] + "train" + Test[-1] + "_" + VarName + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"
else:
  train_filename = "LW5_IW30/" + tr_direct + "/" + Version[1:] + "train" + Test[-1] + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"
  
test_filename = "LW5_IW30/" + ts_direct + "/" + Test + "_" + VarName + "_1B_ReturnTrue_LWS5_IWS30_Trf['RP', 'GASF', 'MTF'].npz"

# %% [markdown]
# ### Image window sizes

# %%
Image_window_size = np.int(train_filename[train_filename.find('_IWS') + 4 : train_filename.find("_Trf")])
Image_window_size
# Out:
# 30

# %% [markdown]
# ### Transformation types

# %%
Image_trf = eval(train_filename[train_filename.find('_Trf')+4:train_filename.find('.npz')])
Image_trf
# Out:
# ['RP', 'GASF', 'MTF']

# %%
num_color_channels = len(Image_trf)
num_color_channels
# Out:
# 3

# %% [markdown]
# #### In case file is missing run the data-check-and-prep with preferred settings and use the new file's name (cannot upload too big files to Git)

# %%
data_train = np.load('/content/drive/My Drive/Colab Notebooks/CNN/' + train_filename)
data_test = np.load('/content/drive/My Drive/Colab Notebooks/CNN/' + test_filename)

# %%
images_train = data_train['images']
images_test = data_test['images']
image_labels_train = data_train['image_labels']
image_labels_test = data_test['image_labels']
train_prices = data_train['price_at_image']
test_prices = data_test['price_at_image']

label_names = data_train['label_names'] # same everywhere

# %% [markdown]
# # Check data

# %%
image_labels_train.shape
# Out:
# (4122, 3)

# %% [markdown]
# Get label names array for later visualization

# %%
label_names = label_names.item()
label_names
# Out:
# {0: 'Sell', 1: 'Buy', 2: 'Hold'}

# %%
label_names_array = np.chararray(3, itemsize = 4).decode("utf-8")

for key, value in label_names.items():
  label_names_array[key] = value
label_names_array
# Out:
# array(['Sell', 'Buy', 'Hold'], dtype='<U4')

# %% [markdown]
# ## e.g.:

# %%
for trfidx, trf in enumerate(Image_trf):
    print('Transformation type: ' + trf)
    for idx, image in enumerate(images_train[:2,:,:, trfidx]):
        plt.imshow(image, cmap = "Greys")
        plt.title(label_names[np.int(np.argwhere(image_labels_train[idx]))])
        plt.show()
# Out:
# Transformation type: RP
# Transformation type: GASF
# Transformation type: MTF

# %%
print("Train images shape : {}; Train labels shape : {}".format(images_train.shape, image_labels_train.shape))
# Out:
# Train images shape : (4122, 30, 30, 3); Train labels shape : (4122, 3)

# %%
print("Test images shape : {}; Test labels shape : {}".format(images_test.shape, image_labels_test.shape))
# Out:
# Test images shape : (520, 30, 30, 3); Test labels shape : (520, 3)

# %% [markdown]
# # Baseline predictions
# Choosing the biggest class to be the class of all

# %%
basepred = np.zeros(image_labels_test.shape)
basepred[:, np.argmax(np.sum(image_labels_test, 0))] = 1.0

base_acc = sum(np.equal(np.argmax(basepred, 1), np.argmax(image_labels_test, 1)))/np.sum(image_labels_test)
base_f1 = f1_score(y_true = image_labels_test, y_pred = basepred, average = 'macro')
# warning F1 due to only label 2 being predicted in baseline

print("Accuracy: {:.5f}".format(base_acc))
print("Categorical Accuracy: {:.5f}".format(accuracy_score(np.argmax(basepred, 1), np.argmax(image_labels_test, 1))))

print("F1 score: {:.5f}".format(base_f1))

print(classification_report(np.argmax(basepred, 1), np.argmax(image_labels_test, 1)))
# Out:
# Accuracy: 0.71731
# Categorical Accuracy: 0.71731
# F1 score: 0.27846
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         0
#            2       1.00      0.72      0.84       520
#
#     accuracy                           0.72       520
#    macro avg       0.33      0.24      0.28       520
# weighted avg       1.00      0.72      0.84       520
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %% [markdown]
# # The Deep CNN

# %% [markdown]
# ### Custom Keras Eval metrics: F1 Score
# https://medium.com/@thongonary/how-to-compute-f1-score-for-each-epoch-in-keras-a1acd17715a2

# %%
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import fbeta_score

# Some default constants

START = 0.5
END = 0.95
STEP = 0.05
N_STEPS = int((END - START) / STEP) + 2
DEFAULT_THRESHOLDS = np.linspace(START, END, N_STEPS)
DEFAULT_BETA = 1
DEFAULT_LOGS = {}
FBETA_METRIC_NAME = "val_fbeta"

class FBetaMetricCallback(Callback):

    def __init__(self, beta=DEFAULT_BETA, thresholds=DEFAULT_THRESHOLDS):
        self.beta = beta
        self.thresholds = thresholds
        # Will be initialized when the training starts
        self.val_fbeta = None

    def on_train_begin(self, logs=DEFAULT_LOGS):
        """ This is where the validation Fbeta
        validation scores will be saved during training: one value per
        epoch.
        """
        self.val_fbeta = []

    def _score_per_threshold(self, predictions, targets, threshold):
        """ Compute the Fbeta score per threshold.
        """
        # Notice that here I am using the sklearn fbeta_score function.
        # You can read more about it here:
        # http://scikit-learn.org/stable/modules/generated/sklearn.metrics.fbeta_score.html
        thresholded_predictions = (predictions > threshold).astype(int)
        return fbeta_score(targets, thresholded_predictions, beta=self.beta)

    def on_epoch_end(self, epoch, logs=DEFAULT_LOGS):
        val_predictions = self.model.predict(self.validation_data[0])
        val_targets = self.validation_data[1]
        _val_fbeta = np.mean([self._score_per_threshold(val_predictions,
                                                        val_targets, threshold)
                              for threshold in self.thresholds])
        self.val_fbeta.append(_val_fbeta)
        print("Current F{} metric is: {}".format(str(self.beta), str(_val_fbeta)))
        return

    def on_train_end(self, logs=DEFAULT_LOGS):
        """ Assign the validation Fbeta computed metric to the History object.
        """
        self.model.history.history[FBETA_METRIC_NAME] = self.val_fbeta
        
f1_score = FBetaMetricCallback(beta=1)

# %% [markdown]
# ### Custom Time Logging

# %%
import tensorflow.keras.callbacks as keras_cb

class TimeHistory(keras_cb.Callback):
  def on_train_begin(self, logs={}):
    self.times = []

  def on_epoch_begin(self, epoch, logs={}):
    self.epoch_time_start = time.time()

  def on_epoch_end(self, epoch, logs={}):
    self.times.append(time.time() - self.epoch_time_start)

time_callback = TimeHistory()

# %% [markdown]
# ### Network Parameters

# %%
# image shape (d x d)
n_input = images_train.shape[1]
inputShape = (n_input, n_input, num_color_channels)

# number of classes
n_classes =  image_labels_train.shape[1]

# dropout
to_drop = 0.3 # prob. to DROP

# %% [markdown]
# ## Building the model

# %%
def createModel(input_shape, dropout = .2):
    model = Sequential()
    # Input
    model.add(Conv2D(32, 
                     (3, 3), 
                     padding='same', 
                     activation=LR, 
                     input_shape=input_shape
                    ))
    model.add(BatchNormalization())
    # model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))
    
    # 1Convolution,relu then pooling
    model.add(Conv2D(64, (3, 3), 
                     padding='same', 
                     activation=LR,
                     kernel_regularizer=regularizers.l2(0.01)
                    ))
    model.add(BatchNormalization())
    model.add(AveragePooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))
    
    # Flatten & Dense layers 
    model.add(Flatten())
    
    model.add(Dense(128, activation=LR, kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(Dropout(.5))
    model.add(Dense(n_classes, activation='softmax'))
  
    return model

# %%
model1 = createModel(dropout = to_drop, input_shape = inputShape)
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 30, 30, 32)        128
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 64)        256
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 15, 15, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 15, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 14400)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1843328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 1,864,003
# Trainable params: 1,863,555
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# ## Hyperparameter settings

# %%
training_iters = 450
batch_size = 150

# %% [markdown]
# ### Accounting for imbalance

# %%
label_names
# Out:
# {0: 'Sell', 1: 'Buy', 2: 'Hold'}

# %%
np.sum(image_labels_train, axis = 0)/np.sum(image_labels_train)
# Out:
# array([0.14046579, 0.14483261, 0.7147016 ])

# %%
y_ints = [y.argmax() for y in image_labels_train]
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_ints),
                                                 y_ints)
class_weight_dict = dict(enumerate(class_weights))
class_weight_dict
# Out:
# {0: 2.373056994818653, 1: 2.301507537688442, 2: 0.4663951120162933}

# %% [markdown]
# ## Compiling

# %%
model1.compile(optimizer=SGD(nesterov=True),#Adam(lr=0.0001, amsgrad = True), #Nadam(lr=0.0005), #
               loss='kullback_leibler_divergence', 
               metrics=['categorical_accuracy'])

# %% [markdown]
# ## Training

# %%
es2 = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
history = model1.fit(images_train, 
                     image_labels_train, 
                     batch_size=batch_size, 
                     epochs=training_iters, verbose=1,
                     validation_data=(images_test, image_labels_test),
                     class_weight=class_weight_dict,
                     callbacks=[time_callback, es2]
                    )
  
model1.evaluate(images_test, image_labels_test)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0706 15:13:05.376059 140371357980544 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 4122 samples, validate on 520 samples
# Epoch 1/450
# 4122/4122 [==============================] - 4s 1ms/sample - loss: 4.9552 - categorical_accuracy: 0.3328 - val_loss: 4.0326 - val_categorical_accuracy: 0.2192
# Epoch 2/450
# 4122/4122 [==============================] - 1s 200us/sample - loss: 4.5892 - categorical_accuracy: 0.3612 - val_loss: 4.0405 - val_categorical_accuracy: 0.1462
# Epoch 3/450
# 4122/4122 [==============================] - 1s 196us/sample - loss: 4.3715 - categorical_accuracy: 0.3809 - val_loss: 4.1213 - val_categorical_accuracy: 0.1423
# Epoch 4/450
# 4122/4122 [==============================] - 1s 200us/sample - loss: 4.2123 - categorical_accuracy: 0.4020 - val_loss: 4.0817 - val_categorical_accuracy: 0.1423
# Epoch 5/450
# 4122/4122 [==============================] - 1s 199us/sample - loss: 4.0640 - categorical_accuracy: 0.4173 - val_loss: 4.0690 - val_categorical_accuracy: 0.1423
# Epoch 6/450
# 4122/4122 [==============================] - 1s 210us/sample - loss: 4.0368 - categorical_accuracy: 0.4066 - val_loss: 4.1173 - val_categorical_accuracy: 0.1423
# Epoch 7/450
# 4122/4122 [==============================] - 1s 195us/sample - loss: 3.9047 - categorical_accuracy: 0.4306 - val_loss: 4.1065 - val_categorical_accuracy: 0.1442
# Epoch 8/450
# 4122/4122 [==============================] - 1s 196us/sample - loss: 3.8224 - categorical_accuracy: 0.4398 - val_loss: 4.0645 - val_categorical_accuracy: 0.1423
# Epoch 9/450
# 4122/4122 [==============================] - 1s 193us/sample - loss: 3.7588 - categorical_accuracy: 0.4391 - val_loss: 4.0600 - val_categorical_accuracy: 0.1423
# Epoch 10/450
# 4122/4122 [==============================] - 1s 197us/sample - loss: 3.7139 - categorical_accuracy: 0.4573 - val_loss: 4.0512 - val_categorical_accuracy: 0.1500
# Epoch 11/450
# 4122/4122 [==============================] - 1s 198us/sample - loss: 3.6509 - categorical_accuracy: 0.4677 - val_loss: 4.0031 - val_categorical_accuracy: 0.1654
# Epoch 12/450
# 4122/4122 [==============================] - 1s 197us/sample - loss: 3.5966 - categorical_accuracy: 0.4779 - val_loss: 3.9452 - val_categorical_accuracy: 0.1615
# Epoch 13/450
# 4122/4122 [==============================] - 1s 197us/sample - loss: 3.5494 - categorical_accuracy: 0.4796 - val_loss: 3.9091 - val_categorical_accuracy: 0.1558
# Epoch 14/450
# 4122/4122 [==============================] - 1s 195us/sample - loss: 3.4779 - categorical_accuracy: 0.5017 - val_loss: 3.8796 - val_categorical_accuracy: 0.1731
# Epoch 15/450
# 4122/4122 [==============================] - 1s 196us/sample - loss: 3.4342 - categorical_accuracy: 0.5080 - val_loss: 3.8444 - val_categorical_accuracy: 0.1731
# Epoch 16/450
# 4122/4122 [==============================] - 1s 208us/sample - loss: 3.3973 - categorical_accuracy: 0.5131 - val_loss: 3.7493 - val_categorical_accuracy: 0.2000
# Epoch 17/450
# 4122/4122 [==============================] - 1s 220us/sample - loss: 3.3413 - categorical_accuracy: 0.5226 - val_loss: 3.6760 - val_categorical_accuracy: 0.2442
# Epoch 18/450
# 4122/4122 [==============================] - 1s 211us/sample - loss: 3.3146 - categorical_accuracy: 0.5274 - val_loss: 3.6314 - val_categorical_accuracy: 0.2673
# Epoch 19/450
# 4122/4122 [==============================] - 1s 200us/sample - loss: 3.2765 - categorical_accuracy: 0.5226 - val_loss: 3.6164 - val_categorical_accuracy: 0.2904
# Epoch 20/450
# 4122/4122 [==============================] - 1s 196us/sample - loss: 3.2384 - categorical_accuracy: 0.5386 - val_loss: 3.6117 - val_categorical_accuracy: 0.2827
# Epoch 21/450
# 4122/4122 [==============================] - 1s 206us/sample - loss: 3.2031 - categorical_accuracy: 0.5386 - val_loss: 3.5858 - val_categorical_accuracy: 0.3000
# Epoch 22/450
# 4122/4122 [==============================] - 1s 213us/sample - loss: 3.1752 - categorical_accuracy: 0.5410 - val_loss: 3.5585 - val_categorical_accuracy: 0.2981
# Epoch 23/450
# 4122/4122 [==============================] - 1s 215us/sample - loss: 3.1355 - categorical_accuracy: 0.5478 - val_loss: 3.4812 - val_categorical_accuracy: 0.3308
# Epoch 24/450
# 4122/4122 [==============================] - 1s 219us/sample - loss: 3.0832 - categorical_accuracy: 0.5597 - val_loss: 3.5022 - val_categorical_accuracy: 0.3192
# Epoch 25/450
# 4122/4122 [==============================] - 1s 206us/sample - loss: 3.0708 - categorical_accuracy: 0.5614 - val_loss: 3.4622 - val_categorical_accuracy: 0.3192
# Epoch 26/450
# 4122/4122 [==============================] - 1s 206us/sample - loss: 3.0097 - categorical_accuracy: 0.5745 - val_loss: 3.4531 - val_categorical_accuracy: 0.3173
# Epoch 27/450
# 4122/4122 [==============================] - 1s 220us/sample - loss: 2.9726 - categorical_accuracy: 0.5786 - val_loss: 3.5141 - val_categorical_accuracy: 0.2885
# Epoch 28/450
# 4122/4122 [==============================] - 1s 213us/sample - loss: 2.9343 - categorical_accuracy: 0.5973 - val_loss: 3.3926 - val_categorical_accuracy: 0.3481
# Epoch 29/450
# 4122/4122 [==============================] - 1s 217us/sample - loss: 2.9010 - categorical_accuracy: 0.6019 - val_loss: 3.3671 - val_categorical_accuracy: 0.3519
# Epoch 30/450
# 4122/4122 [==============================] - 1s 215us/sample - loss: 2.8728 - categorical_accuracy: 0.5992 - val_loss: 3.2696 - val_categorical_accuracy: 0.4115
# Epoch 31/450
# 4122/4122 [==============================] - 1s 209us/sample - loss: 2.8576 - categorical_accuracy: 0.6012 - val_loss: 3.3014 - val_categorical_accuracy: 0.3673
# Epoch 32/450
# 4122/4122 [==============================] - 1s 209us/sample - loss: 2.8092 - categorical_accuracy: 0.6038 - val_loss: 3.2706 - val_categorical_accuracy: 0.3904
# Epoch 33/450
# 4122/4122 [==============================] - 1s 209us/sample - loss: 2.7698 - categorical_accuracy: 0.6121 - val_loss: 3.2447 - val_categorical_accuracy: 0.3827
# Epoch 34/450
# 4122/4122 [==============================] - 1s 216us/sample - loss: 2.7411 - categorical_accuracy: 0.6237 - val_loss: 3.2281 - val_categorical_accuracy: 0.3981
# Epoch 35/450
# 4122/4122 [==============================] - 1s 212us/sample - loss: 2.7148 - categorical_accuracy: 0.6245 - val_loss: 3.2311 - val_categorical_accuracy: 0.3788
# Epoch 36/450
# 4122/4122 [==============================] - 1s 222us/sample - loss: 2.6621 - categorical_accuracy: 0.6291 - val_loss: 3.2536 - val_categorical_accuracy: 0.3558
# Epoch 37/450
# 4122/4122 [==============================] - 1s 227us/sample - loss: 2.6406 - categorical_accuracy: 0.6412 - val_loss: 3.2199 - val_categorical_accuracy: 0.3808
# Epoch 38/450
# 4122/4122 [==============================] - 1s 204us/sample - loss: 2.6111 - categorical_accuracy: 0.6441 - val_loss: 3.0910 - val_categorical_accuracy: 0.4615
# Epoch 39/450
# 4122/4122 [==============================] - 1s 223us/sample - loss: 2.6006 - categorical_accuracy: 0.6351 - val_loss: 3.1359 - val_categorical_accuracy: 0.4000
# Epoch 40/450
# 4122/4122 [==============================] - 1s 219us/sample - loss: 2.5705 - categorical_accuracy: 0.6538 - val_loss: 3.1325 - val_categorical_accuracy: 0.4115
# Epoch 41/450
# 4122/4122 [==============================] - 1s 216us/sample - loss: 2.5245 - categorical_accuracy: 0.6507 - val_loss: 3.1601 - val_categorical_accuracy: 0.3712
# Epoch 42/450
# 4122/4122 [==============================] - 1s 222us/sample - loss: 2.5100 - categorical_accuracy: 0.6596 - val_loss: 3.1646 - val_categorical_accuracy: 0.3500
# Epoch 43/450
# 4122/4122 [==============================] - 1s 235us/sample - loss: 2.4755 - categorical_accuracy: 0.6657 - val_loss: 2.9935 - val_categorical_accuracy: 0.4500
# Epoch 44/450
# 4122/4122 [==============================] - 1s 238us/sample - loss: 2.4400 - categorical_accuracy: 0.6805 - val_loss: 2.9857 - val_categorical_accuracy: 0.4519
# Epoch 45/450
# 4122/4122 [==============================] - 1s 229us/sample - loss: 2.4042 - categorical_accuracy: 0.6773 - val_loss: 3.0401 - val_categorical_accuracy: 0.4231
# Epoch 46/450
# 4122/4122 [==============================] - 1s 225us/sample - loss: 2.4101 - categorical_accuracy: 0.6783 - val_loss: 3.0092 - val_categorical_accuracy: 0.4308
# Epoch 47/450
# 4122/4122 [==============================] - 1s 218us/sample - loss: 2.3556 - categorical_accuracy: 0.6958 - val_loss: 2.9518 - val_categorical_accuracy: 0.4712
# Epoch 48/450
# 4122/4122 [==============================] - 1s 211us/sample - loss: 2.3241 - categorical_accuracy: 0.6938 - val_loss: 2.9553 - val_categorical_accuracy: 0.4519
# Epoch 49/450
# 4122/4122 [==============================] - 1s 206us/sample - loss: 2.3123 - categorical_accuracy: 0.6926 - val_loss: 2.9072 - val_categorical_accuracy: 0.4712
# Epoch 50/450
# 4122/4122 [==============================] - 1s 219us/sample - loss: 2.2899 - categorical_accuracy: 0.6980 - val_loss: 2.8619 - val_categorical_accuracy: 0.4846
# Epoch 51/450
# 4122/4122 [==============================] - 1s 222us/sample - loss: 2.2353 - categorical_accuracy: 0.7094 - val_loss: 2.8780 - val_categorical_accuracy: 0.4615
# Epoch 52/450
# 4122/4122 [==============================] - 1s 222us/sample - loss: 2.2115 - categorical_accuracy: 0.7208 - val_loss: 2.8620 - val_categorical_accuracy: 0.4673
# Epoch 53/450
# 4122/4122 [==============================] - 1s 225us/sample - loss: 2.2140 - categorical_accuracy: 0.7111 - val_loss: 2.8413 - val_categorical_accuracy: 0.4769
# Epoch 54/450
# 4122/4122 [==============================] - 1s 265us/sample - loss: 2.1808 - categorical_accuracy: 0.7149 - val_loss: 2.8361 - val_categorical_accuracy: 0.4731
# Epoch 55/450
# 4122/4122 [==============================] - 1s 314us/sample - loss: 2.1517 - categorical_accuracy: 0.7111 - val_loss: 2.8843 - val_categorical_accuracy: 0.4231
# Epoch 56/450
# 4122/4122 [==============================] - 1s 219us/sample - loss: 2.1350 - categorical_accuracy: 0.7244 - val_loss: 2.8941 - val_categorical_accuracy: 0.4135
# Epoch 57/450
# 4122/4122 [==============================] - 1s 216us/sample - loss: 2.1013 - categorical_accuracy: 0.7244 - val_loss: 2.7795 - val_categorical_accuracy: 0.4846
# Epoch 58/450
# 4122/4122 [==============================] - 1s 290us/sample - loss: 2.0666 - categorical_accuracy: 0.7334 - val_loss: 2.7903 - val_categorical_accuracy: 0.4577
# Epoch 59/450
# 4122/4122 [==============================] - 1s 296us/sample - loss: 2.0584 - categorical_accuracy: 0.7341 - val_loss: 2.8613 - val_categorical_accuracy: 0.4135
# Epoch 60/450
# 4122/4122 [==============================] - 1s 309us/sample - loss: 2.0345 - categorical_accuracy: 0.7404 - val_loss: 2.8020 - val_categorical_accuracy: 0.4462
# Epoch 61/450
# 4122/4122 [==============================] - 1s 307us/sample - loss: 1.9964 - categorical_accuracy: 0.7496 - val_loss: 2.7863 - val_categorical_accuracy: 0.4577
# Epoch 62/450
# 4122/4122 [==============================] - 1s 312us/sample - loss: 1.9966 - categorical_accuracy: 0.7458 - val_loss: 2.6877 - val_categorical_accuracy: 0.5038
# Epoch 63/450
# 4122/4122 [==============================] - 1s 306us/sample - loss: 1.9697 - categorical_accuracy: 0.7470 - val_loss: 2.6623 - val_categorical_accuracy: 0.5038
# Epoch 64/450
# 4122/4122 [==============================] - 1s 294us/sample - loss: 1.9501 - categorical_accuracy: 0.7574 - val_loss: 2.7016 - val_categorical_accuracy: 0.4846
# Epoch 65/450
# 4122/4122 [==============================] - 1s 308us/sample - loss: 1.9268 - categorical_accuracy: 0.7586 - val_loss: 2.6856 - val_categorical_accuracy: 0.4750
# Epoch 66/450
# 4122/4122 [==============================] - 1s 311us/sample - loss: 1.9188 - categorical_accuracy: 0.7579 - val_loss: 2.6679 - val_categorical_accuracy: 0.5000
# Epoch 67/450
# 4122/4122 [==============================] - 1s 290us/sample - loss: 1.8899 - categorical_accuracy: 0.7589 - val_loss: 2.7310 - val_categorical_accuracy: 0.4635
# Epoch 68/450
# 4122/4122 [==============================] - 1s 286us/sample - loss: 1.8580 - categorical_accuracy: 0.7705 - val_loss: 2.6739 - val_categorical_accuracy: 0.4904
# Epoch 69/450
# 4122/4122 [==============================] - 1s 299us/sample - loss: 1.8439 - categorical_accuracy: 0.7737 - val_loss: 2.6253 - val_categorical_accuracy: 0.5173
# Epoch 70/450
# 4122/4122 [==============================] - 1s 298us/sample - loss: 1.8129 - categorical_accuracy: 0.7787 - val_loss: 2.6585 - val_categorical_accuracy: 0.4865
# Epoch 71/450
# 4122/4122 [==============================] - 1s 299us/sample - loss: 1.8136 - categorical_accuracy: 0.7768 - val_loss: 2.6096 - val_categorical_accuracy: 0.4962
# Epoch 72/450
# 4122/4122 [==============================] - 1s 310us/sample - loss: 1.7862 - categorical_accuracy: 0.7804 - val_loss: 2.6403 - val_categorical_accuracy: 0.4827
# Epoch 73/450
# 4122/4122 [==============================] - 1s 312us/sample - loss: 1.7464 - categorical_accuracy: 0.7950 - val_loss: 2.5933 - val_categorical_accuracy: 0.5077
# Epoch 74/450
# 4122/4122 [==============================] - 1s 311us/sample - loss: 1.7482 - categorical_accuracy: 0.7877 - val_loss: 2.6068 - val_categorical_accuracy: 0.5077
# Epoch 75/450
# 4122/4122 [==============================] - 1s 304us/sample - loss: 1.7178 - categorical_accuracy: 0.7889 - val_loss: 2.5136 - val_categorical_accuracy: 0.5192
# Epoch 76/450
# 4122/4122 [==============================] - 1s 308us/sample - loss: 1.7089 - categorical_accuracy: 0.7923 - val_loss: 2.5490 - val_categorical_accuracy: 0.5096
# Epoch 77/450
# 4122/4122 [==============================] - 1s 309us/sample - loss: 1.6859 - categorical_accuracy: 0.7996 - val_loss: 2.5269 - val_categorical_accuracy: 0.5019
# Epoch 78/450
# 4122/4122 [==============================] - 1s 294us/sample - loss: 1.6743 - categorical_accuracy: 0.7950 - val_loss: 2.5418 - val_categorical_accuracy: 0.4923
# Epoch 79/450
# 4122/4122 [==============================] - 1s 301us/sample - loss: 1.6476 - categorical_accuracy: 0.8013 - val_loss: 2.6491 - val_categorical_accuracy: 0.4577
# Epoch 80/450
# 4122/4122 [==============================] - 1s 295us/sample - loss: 1.6472 - categorical_accuracy: 0.7928 - val_loss: 2.4977 - val_categorical_accuracy: 0.5077
# Epoch 81/450
# 4122/4122 [==============================] - 1s 311us/sample - loss: 1.6343 - categorical_accuracy: 0.7986 - val_loss: 2.6480 - val_categorical_accuracy: 0.4519
# Epoch 82/450
# 4122/4122 [==============================] - 1s 301us/sample - loss: 1.5929 - categorical_accuracy: 0.8081 - val_loss: 2.4660 - val_categorical_accuracy: 0.5250
# Epoch 83/450
# 4122/4122 [==============================] - 1s 299us/sample - loss: 1.5742 - categorical_accuracy: 0.8217 - val_loss: 2.5316 - val_categorical_accuracy: 0.4962
# Epoch 84/450
# 4122/4122 [==============================] - 1s 306us/sample - loss: 1.5664 - categorical_accuracy: 0.8246 - val_loss: 2.4613 - val_categorical_accuracy: 0.5212
# Epoch 85/450
# 4122/4122 [==============================] - 1s 306us/sample - loss: 1.5484 - categorical_accuracy: 0.8229 - val_loss: 2.4908 - val_categorical_accuracy: 0.4923
# Epoch 86/450
# 4122/4122 [==============================] - 1s 293us/sample - loss: 1.5308 - categorical_accuracy: 0.8193 - val_loss: 2.4581 - val_categorical_accuracy: 0.5269
# Epoch 87/450
# 4122/4122 [==============================] - 1s 299us/sample - loss: 1.5164 - categorical_accuracy: 0.8210 - val_loss: 2.4623 - val_categorical_accuracy: 0.5096
# Epoch 88/450
# 4122/4122 [==============================] - 1s 307us/sample - loss: 1.4870 - categorical_accuracy: 0.8370 - val_loss: 2.4134 - val_categorical_accuracy: 0.5269
# Epoch 89/450
# 4122/4122 [==============================] - 1s 295us/sample - loss: 1.4993 - categorical_accuracy: 0.8280 - val_loss: 2.4393 - val_categorical_accuracy: 0.5019
# Epoch 90/450
# 4122/4122 [==============================] - 1s 308us/sample - loss: 1.4598 - categorical_accuracy: 0.8326 - val_loss: 2.3958 - val_categorical_accuracy: 0.5308
# Epoch 91/450
# 4122/4122 [==============================] - 1s 294us/sample - loss: 1.4585 - categorical_accuracy: 0.8241 - val_loss: 2.3382 - val_categorical_accuracy: 0.5692
# Epoch 92/450
# 4122/4122 [==============================] - 1s 301us/sample - loss: 1.4549 - categorical_accuracy: 0.8265 - val_loss: 2.4077 - val_categorical_accuracy: 0.5269
# Epoch 93/450
# 4122/4122 [==============================] - 1s 283us/sample - loss: 1.4243 - categorical_accuracy: 0.8421 - val_loss: 2.3820 - val_categorical_accuracy: 0.5365
# Epoch 94/450
# 4122/4122 [==============================] - 1s 303us/sample - loss: 1.4081 - categorical_accuracy: 0.8462 - val_loss: 2.4063 - val_categorical_accuracy: 0.5058
# Epoch 95/450
# 4122/4122 [==============================] - 1s 296us/sample - loss: 1.3865 - categorical_accuracy: 0.8404 - val_loss: 2.4335 - val_categorical_accuracy: 0.4865
# Epoch 96/450
# 4122/4122 [==============================] - 1s 311us/sample - loss: 1.3703 - categorical_accuracy: 0.8493 - val_loss: 2.3535 - val_categorical_accuracy: 0.5250
# Epoch 97/450
# 4122/4122 [==============================] - 1s 308us/sample - loss: 1.3595 - categorical_accuracy: 0.8513 - val_loss: 2.3154 - val_categorical_accuracy: 0.5365
# Epoch 98/450
# 4122/4122 [==============================] - 1s 297us/sample - loss: 1.3407 - categorical_accuracy: 0.8510 - val_loss: 2.3976 - val_categorical_accuracy: 0.5019
# Epoch 99/450
# 4122/4122 [==============================] - 1s 296us/sample - loss: 1.3296 - categorical_accuracy: 0.8532 - val_loss: 2.3326 - val_categorical_accuracy: 0.5192
# Epoch 100/450
# 4122/4122 [==============================] - 1s 313us/sample - loss: 1.3329 - categorical_accuracy: 0.8472 - val_loss: 2.3601 - val_categorical_accuracy: 0.5038
# Epoch 101/450
# 4122/4122 [==============================] - 1s 295us/sample - loss: 1.2989 - categorical_accuracy: 0.8603 - val_loss: 2.3078 - val_categorical_accuracy: 0.5231
# Epoch 102/450
# 4122/4122 [==============================] - 1s 303us/sample - loss: 1.3177 - categorical_accuracy: 0.8513 - val_loss: 2.2949 - val_categorical_accuracy: 0.5500
# Epoch 103/450
# 4122/4122 [==============================] - 1s 302us/sample - loss: 1.2853 - categorical_accuracy: 0.8571 - val_loss: 2.2936 - val_categorical_accuracy: 0.5192
# Epoch 104/450
# 4122/4122 [==============================] - 1s 305us/sample - loss: 1.2599 - categorical_accuracy: 0.8632 - val_loss: 2.2903 - val_categorical_accuracy: 0.5385
# Epoch 105/450
# 4122/4122 [==============================] - 1s 296us/sample - loss: 1.2630 - categorical_accuracy: 0.8603 - val_loss: 2.3189 - val_categorical_accuracy: 0.5212
# Epoch 106/450
# 4122/4122 [==============================] - 1s 297us/sample - loss: 1.2401 - categorical_accuracy: 0.8688 - val_loss: 2.2720 - val_categorical_accuracy: 0.5519
# Epoch 107/450
# 4122/4122 [==============================] - 1s 289us/sample - loss: 1.2277 - categorical_accuracy: 0.8770 - val_loss: 2.2307 - val_categorical_accuracy: 0.5731
# Epoch 108/450
# 4122/4122 [==============================] - 1s 293us/sample - loss: 1.2095 - categorical_accuracy: 0.8702 - val_loss: 2.3070 - val_categorical_accuracy: 0.5250
# Epoch 109/450
# 4122/4122 [==============================] - 1s 304us/sample - loss: 1.2159 - categorical_accuracy: 0.8671 - val_loss: 2.2610 - val_categorical_accuracy: 0.5500
# Epoch 110/450
# 4122/4122 [==============================] - 1s 311us/sample - loss: 1.2044 - categorical_accuracy: 0.8736 - val_loss: 2.2460 - val_categorical_accuracy: 0.5519
# Epoch 111/450
# 4122/4122 [==============================] - 1s 300us/sample - loss: 1.1747 - categorical_accuracy: 0.8772 - val_loss: 2.2096 - val_categorical_accuracy: 0.5673
# Epoch 112/450
# 4122/4122 [==============================] - 1s 301us/sample - loss: 1.1605 - categorical_accuracy: 0.8794 - val_loss: 2.3137 - val_categorical_accuracy: 0.5231
# Epoch 113/450
# 4122/4122 [==============================] - 1s 307us/sample - loss: 1.1414 - categorical_accuracy: 0.8821 - val_loss: 2.2954 - val_categorical_accuracy: 0.5385
# Epoch 114/450
# 4122/4122 [==============================] - 1s 314us/sample - loss: 1.1348 - categorical_accuracy: 0.8836 - val_loss: 2.2411 - val_categorical_accuracy: 0.5385
# Epoch 115/450
# 4122/4122 [==============================] - 1s 315us/sample - loss: 1.1202 - categorical_accuracy: 0.8869 - val_loss: 2.2592 - val_categorical_accuracy: 0.5423
# Epoch 116/450
# 4122/4122 [==============================] - 1s 296us/sample - loss: 1.1126 - categorical_accuracy: 0.8782 - val_loss: 2.2975 - val_categorical_accuracy: 0.5115
# Epoch 117/450
# 4122/4122 [==============================] - 1s 308us/sample - loss: 1.1022 - categorical_accuracy: 0.8802 - val_loss: 2.2418 - val_categorical_accuracy: 0.5250
# Epoch 118/450
# 4122/4122 [==============================] - 1s 290us/sample - loss: 1.0949 - categorical_accuracy: 0.8860 - val_loss: 2.2318 - val_categorical_accuracy: 0.5327
# Epoch 119/450
# 4122/4122 [==============================] - 1s 302us/sample - loss: 1.0905 - categorical_accuracy: 0.8872 - val_loss: 2.2674 - val_categorical_accuracy: 0.5231
# Epoch 120/450
# 4122/4122 [==============================] - 1s 296us/sample - loss: 1.0806 - categorical_accuracy: 0.8874 - val_loss: 2.2228 - val_categorical_accuracy: 0.5462
# Epoch 121/450
# 4122/4122 [==============================] - 1s 297us/sample - loss: 1.0716 - categorical_accuracy: 0.8845 - val_loss: 2.2539 - val_categorical_accuracy: 0.5308
# Epoch 122/450
# 4122/4122 [==============================] - 1s 293us/sample - loss: 1.0585 - categorical_accuracy: 0.8872 - val_loss: 2.2386 - val_categorical_accuracy: 0.5365
# Epoch 123/450
# 4122/4122 [==============================] - 1s 303us/sample - loss: 1.0674 - categorical_accuracy: 0.8867 - val_loss: 2.2003 - val_categorical_accuracy: 0.5481
# Epoch 124/450
# 4122/4122 [==============================] - 1s 302us/sample - loss: 1.0519 - categorical_accuracy: 0.8872 - val_loss: 2.1513 - val_categorical_accuracy: 0.5654
# Epoch 125/450
# 4122/4122 [==============================] - 1s 310us/sample - loss: 1.0289 - categorical_accuracy: 0.8942 - val_loss: 2.1975 - val_categorical_accuracy: 0.5462
# Epoch 126/450
# 4122/4122 [==============================] - 1s 304us/sample - loss: 1.0135 - categorical_accuracy: 0.8935 - val_loss: 2.2369 - val_categorical_accuracy: 0.5308
# Epoch 127/450
# 4122/4122 [==============================] - 1s 292us/sample - loss: 0.9955 - categorical_accuracy: 0.9008 - val_loss: 2.1276 - val_categorical_accuracy: 0.5731
# Epoch 128/450
# 4122/4122 [==============================] - 1s 304us/sample - loss: 0.9891 - categorical_accuracy: 0.9027 - val_loss: 2.1447 - val_categorical_accuracy: 0.5635
# Epoch 129/450
# 4122/4122 [==============================] - 1s 312us/sample - loss: 1.0003 - categorical_accuracy: 0.8959 - val_loss: 2.1357 - val_categorical_accuracy: 0.5788
# Epoch 130/450
# 4122/4122 [==============================] - 1s 316us/sample - loss: 0.9641 - categorical_accuracy: 0.9015 - val_loss: 2.0898 - val_categorical_accuracy: 0.5904
# Epoch 131/450
# 4122/4122 [==============================] - 1s 293us/sample - loss: 0.9642 - categorical_accuracy: 0.9022 - val_loss: 2.1123 - val_categorical_accuracy: 0.5846
# Epoch 132/450
# 4122/4122 [==============================] - 1s 289us/sample - loss: 0.9633 - categorical_accuracy: 0.9003 - val_loss: 2.1042 - val_categorical_accuracy: 0.5904
# Epoch 133/450
# 4122/4122 [==============================] - 1s 308us/sample - loss: 0.9500 - categorical_accuracy: 0.9030 - val_loss: 2.1929 - val_categorical_accuracy: 0.5462
# Epoch 134/450
# 4122/4122 [==============================] - 1s 303us/sample - loss: 0.9330 - categorical_accuracy: 0.9095 - val_loss: 2.1283 - val_categorical_accuracy: 0.5692
# Epoch 135/450
# 4122/4122 [==============================] - 1s 296us/sample - loss: 0.9273 - categorical_accuracy: 0.9085 - val_loss: 2.1151 - val_categorical_accuracy: 0.5750
# Epoch 136/450
# 4122/4122 [==============================] - 1s 294us/sample - loss: 0.9200 - categorical_accuracy: 0.9059 - val_loss: 2.0870 - val_categorical_accuracy: 0.5827
# Epoch 137/450
# 4122/4122 [==============================] - 1s 310us/sample - loss: 0.8996 - categorical_accuracy: 0.9161 - val_loss: 2.1132 - val_categorical_accuracy: 0.5769
# Epoch 138/450
# 4122/4122 [==============================] - 1s 312us/sample - loss: 0.8913 - categorical_accuracy: 0.9093 - val_loss: 2.0951 - val_categorical_accuracy: 0.5635
# Epoch 139/450
# 4122/4122 [==============================] - 1s 316us/sample - loss: 0.8884 - categorical_accuracy: 0.9088 - val_loss: 2.0904 - val_categorical_accuracy: 0.5596
# Epoch 140/450
# 4122/4122 [==============================] - 1s 293us/sample - loss: 0.8965 - categorical_accuracy: 0.9105 - val_loss: 2.1005 - val_categorical_accuracy: 0.5404
# Epoch 141/450
# 4122/4122 [==============================] - 1s 313us/sample - loss: 0.8729 - categorical_accuracy: 0.9129 - val_loss: 2.0496 - val_categorical_accuracy: 0.5769
# Epoch 142/450
# 4122/4122 [==============================] - 1s 292us/sample - loss: 0.8806 - categorical_accuracy: 0.9076 - val_loss: 2.0543 - val_categorical_accuracy: 0.5750
# Epoch 143/450
# 4122/4122 [==============================] - 1s 316us/sample - loss: 0.8667 - categorical_accuracy: 0.9134 - val_loss: 2.0895 - val_categorical_accuracy: 0.5481
# Epoch 144/450
# 4122/4122 [==============================] - 1s 290us/sample - loss: 0.8555 - categorical_accuracy: 0.9165 - val_loss: 2.0701 - val_categorical_accuracy: 0.5519
# Epoch 145/450
# 4122/4122 [==============================] - 1s 304us/sample - loss: 0.8452 - categorical_accuracy: 0.9185 - val_loss: 2.1084 - val_categorical_accuracy: 0.5538
# Epoch 146/450
# 4122/4122 [==============================] - 1s 313us/sample - loss: 0.8210 - categorical_accuracy: 0.9241 - val_loss: 2.0357 - val_categorical_accuracy: 0.5846
# Epoch 147/450
# 4122/4122 [==============================] - 1s 302us/sample - loss: 0.8235 - categorical_accuracy: 0.9212 - val_loss: 2.0743 - val_categorical_accuracy: 0.5596
# Epoch 148/450
# 4122/4122 [==============================] - 1s 299us/sample - loss: 0.8269 - categorical_accuracy: 0.9199 - val_loss: 2.0891 - val_categorical_accuracy: 0.5673
# Epoch 149/450
# 4122/4122 [==============================] - 1s 306us/sample - loss: 0.8076 - categorical_accuracy: 0.9272 - val_loss: 2.0921 - val_categorical_accuracy: 0.5538
# Epoch 150/450
# 4122/4122 [==============================] - 1s 312us/sample - loss: 0.8034 - categorical_accuracy: 0.9258 - val_loss: 2.0830 - val_categorical_accuracy: 0.5596
# Epoch 151/450
# 4122/4122 [==============================] - 1s 303us/sample - loss: 0.8063 - categorical_accuracy: 0.9170 - val_loss: 2.1212 - val_categorical_accuracy: 0.5500
# Epoch 152/450
# 4122/4122 [==============================] - 1s 314us/sample - loss: 0.7942 - categorical_accuracy: 0.9178 - val_loss: 2.1042 - val_categorical_accuracy: 0.5615
# Epoch 153/450
# 4122/4122 [==============================] - 1s 311us/sample - loss: 0.7937 - categorical_accuracy: 0.9185 - val_loss: 2.0811 - val_categorical_accuracy: 0.5577
# Epoch 154/450
# 4122/4122 [==============================] - 1s 301us/sample - loss: 0.7864 - categorical_accuracy: 0.9289 - val_loss: 2.0686 - val_categorical_accuracy: 0.5788
# Epoch 155/450
# 4122/4122 [==============================] - 1s 316us/sample - loss: 0.7686 - categorical_accuracy: 0.9267 - val_loss: 2.0123 - val_categorical_accuracy: 0.5673
# Epoch 156/450
# 4122/4122 [==============================] - 1s 302us/sample - loss: 0.7456 - categorical_accuracy: 0.9313 - val_loss: 2.0557 - val_categorical_accuracy: 0.5846
# Epoch 157/450
# 4122/4122 [==============================] - 1s 308us/sample - loss: 0.7680 - categorical_accuracy: 0.9216 - val_loss: 2.0534 - val_categorical_accuracy: 0.5692
# Epoch 158/450
# 4122/4122 [==============================] - 1s 321us/sample - loss: 0.7420 - categorical_accuracy: 0.9212 - val_loss: 2.0684 - val_categorical_accuracy: 0.5692
# Epoch 159/450
# 4122/4122 [==============================] - 1s 309us/sample - loss: 0.7415 - categorical_accuracy: 0.9248 - val_loss: 2.0340 - val_categorical_accuracy: 0.5712
# Epoch 160/450
# 4122/4122 [==============================] - 1s 311us/sample - loss: 0.7440 - categorical_accuracy: 0.9231 - val_loss: 2.1009 - val_categorical_accuracy: 0.5288
# Epoch 161/450
# 4122/4122 [==============================] - 1s 305us/sample - loss: 0.7463 - categorical_accuracy: 0.9221 - val_loss: 2.0593 - val_categorical_accuracy: 0.5558
# Epoch 162/450
# 4122/4122 [==============================] - 1s 300us/sample - loss: 0.7294 - categorical_accuracy: 0.9304 - val_loss: 2.0252 - val_categorical_accuracy: 0.5615
# Epoch 163/450
# 4122/4122 [==============================] - 1s 300us/sample - loss: 0.7156 - categorical_accuracy: 0.9328 - val_loss: 2.0293 - val_categorical_accuracy: 0.5692
# Epoch 164/450
# 4122/4122 [==============================] - 1s 305us/sample - loss: 0.7109 - categorical_accuracy: 0.9340 - val_loss: 2.0203 - val_categorical_accuracy: 0.5846
# Epoch 165/450
# 4122/4122 [==============================] - 1s 305us/sample - loss: 0.7116 - categorical_accuracy: 0.9301 - val_loss: 2.0062 - val_categorical_accuracy: 0.5615
# Epoch 166/450
# 4122/4122 [==============================] - 1s 315us/sample - loss: 0.6992 - categorical_accuracy: 0.9321 - val_loss: 2.0193 - val_categorical_accuracy: 0.5519
# Epoch 167/450
# 4122/4122 [==============================] - 1s 311us/sample - loss: 0.6833 - categorical_accuracy: 0.9381 - val_loss: 1.9885 - val_categorical_accuracy: 0.5846
# Epoch 168/450
# 4122/4122 [==============================] - 1s 297us/sample - loss: 0.6879 - categorical_accuracy: 0.9391 - val_loss: 1.9799 - val_categorical_accuracy: 0.5827
# Epoch 169/450
# 4122/4122 [==============================] - 1s 303us/sample - loss: 0.6775 - categorical_accuracy: 0.9408 - val_loss: 1.9736 - val_categorical_accuracy: 0.5750
# Epoch 170/450
# 4122/4122 [==============================] - 1s 305us/sample - loss: 0.6715 - categorical_accuracy: 0.9384 - val_loss: 2.0101 - val_categorical_accuracy: 0.5500
# Epoch 171/450
# 4122/4122 [==============================] - 1s 305us/sample - loss: 0.6728 - categorical_accuracy: 0.9355 - val_loss: 2.0003 - val_categorical_accuracy: 0.6019
# Epoch 172/450
# 4122/4122 [==============================] - 1s 299us/sample - loss: 0.6691 - categorical_accuracy: 0.9345 - val_loss: 1.9836 - val_categorical_accuracy: 0.6212
# Epoch 173/450
# 4122/4122 [==============================] - 1s 307us/sample - loss: 0.6587 - categorical_accuracy: 0.9374 - val_loss: 1.9613 - val_categorical_accuracy: 0.6135
# Epoch 174/450
# 4122/4122 [==============================] - 1s 302us/sample - loss: 0.6648 - categorical_accuracy: 0.9343 - val_loss: 2.0085 - val_categorical_accuracy: 0.5904
# Epoch 175/450
# 4122/4122 [==============================] - 1s 308us/sample - loss: 0.6572 - categorical_accuracy: 0.9338 - val_loss: 2.0148 - val_categorical_accuracy: 0.5981
# Epoch 176/450
# 4122/4122 [==============================] - 1s 306us/sample - loss: 0.6409 - categorical_accuracy: 0.9347 - val_loss: 2.0396 - val_categorical_accuracy: 0.5827
# Epoch 177/450
# 4122/4122 [==============================] - 1s 301us/sample - loss: 0.6337 - categorical_accuracy: 0.9408 - val_loss: 2.0450 - val_categorical_accuracy: 0.5942
# Epoch 178/450
# 4122/4122 [==============================] - 1s 306us/sample - loss: 0.6339 - categorical_accuracy: 0.9345 - val_loss: 2.0199 - val_categorical_accuracy: 0.5750
# Epoch 179/450
# 4122/4122 [==============================] - 1s 288us/sample - loss: 0.6310 - categorical_accuracy: 0.9367 - val_loss: 2.0058 - val_categorical_accuracy: 0.5750
# Epoch 180/450
# 4122/4122 [==============================] - 1s 286us/sample - loss: 0.6255 - categorical_accuracy: 0.9377 - val_loss: 2.0734 - val_categorical_accuracy: 0.5365
# Epoch 181/450
# 4122/4122 [==============================] - 1s 311us/sample - loss: 0.6102 - categorical_accuracy: 0.9401 - val_loss: 2.0080 - val_categorical_accuracy: 0.5865
# Epoch 182/450
# 4122/4122 [==============================] - 1s 299us/sample - loss: 0.6251 - categorical_accuracy: 0.9345 - val_loss: 1.9506 - val_categorical_accuracy: 0.5808
# Epoch 183/450
# 4122/4122 [==============================] - 1s 316us/sample - loss: 0.6101 - categorical_accuracy: 0.9379 - val_loss: 2.0158 - val_categorical_accuracy: 0.5692
# Epoch 184/450
# 4122/4122 [==============================] - 1s 311us/sample - loss: 0.6075 - categorical_accuracy: 0.9335 - val_loss: 2.0032 - val_categorical_accuracy: 0.5827
# Epoch 185/450
# 4122/4122 [==============================] - 1s 310us/sample - loss: 0.6145 - categorical_accuracy: 0.9347 - val_loss: 2.0179 - val_categorical_accuracy: 0.5750
# Epoch 186/450
# 4122/4122 [==============================] - 1s 281us/sample - loss: 0.5812 - categorical_accuracy: 0.9481 - val_loss: 2.0184 - val_categorical_accuracy: 0.5615
# Epoch 187/450
# 4122/4122 [==============================] - 1s 297us/sample - loss: 0.6031 - categorical_accuracy: 0.9391 - val_loss: 1.9842 - val_categorical_accuracy: 0.5712
# Epoch 188/450
# 4122/4122 [==============================] - 1s 304us/sample - loss: 0.5873 - categorical_accuracy: 0.9432 - val_loss: 2.0416 - val_categorical_accuracy: 0.5615
# Epoch 189/450
# 4122/4122 [==============================] - 1s 291us/sample - loss: 0.5902 - categorical_accuracy: 0.9420 - val_loss: 2.0086 - val_categorical_accuracy: 0.5654
# Epoch 190/450
# 4122/4122 [==============================] - 1s 311us/sample - loss: 0.5684 - categorical_accuracy: 0.9476 - val_loss: 2.0384 - val_categorical_accuracy: 0.5635
# Epoch 191/450
# 4122/4122 [==============================] - 1s 313us/sample - loss: 0.5666 - categorical_accuracy: 0.9483 - val_loss: 2.0005 - val_categorical_accuracy: 0.5615
# Epoch 192/450
# 4122/4122 [==============================] - 1s 304us/sample - loss: 0.5689 - categorical_accuracy: 0.9503 - val_loss: 2.0061 - val_categorical_accuracy: 0.5654
# Epoch 193/450
# 4122/4122 [==============================] - 1s 307us/sample - loss: 0.5786 - categorical_accuracy: 0.9384 - val_loss: 2.0000 - val_categorical_accuracy: 0.5769
# Epoch 194/450
# 4122/4122 [==============================] - 1s 307us/sample - loss: 0.5596 - categorical_accuracy: 0.9454 - val_loss: 2.0100 - val_categorical_accuracy: 0.5827
# Epoch 195/450
# 4122/4122 [==============================] - 1s 302us/sample - loss: 0.5692 - categorical_accuracy: 0.9464 - val_loss: 2.0533 - val_categorical_accuracy: 0.5654
# Epoch 196/450
# 4122/4122 [==============================] - 1s 298us/sample - loss: 0.5823 - categorical_accuracy: 0.9345 - val_loss: 2.0512 - val_categorical_accuracy: 0.5654
# Epoch 197/450
# 4122/4122 [==============================] - 1s 303us/sample - loss: 0.5626 - categorical_accuracy: 0.9372 - val_loss: 1.9787 - val_categorical_accuracy: 0.5962
# Epoch 198/450
# 4122/4122 [==============================] - 1s 314us/sample - loss: 0.5514 - categorical_accuracy: 0.9423 - val_loss: 1.9978 - val_categorical_accuracy: 0.5865
# Epoch 199/450
# 4122/4122 [==============================] - 1s 307us/sample - loss: 0.5526 - categorical_accuracy: 0.9435 - val_loss: 1.9450 - val_categorical_accuracy: 0.5615
# Epoch 200/450
# 4122/4122 [==============================] - 1s 298us/sample - loss: 0.5651 - categorical_accuracy: 0.9393 - val_loss: 2.1110 - val_categorical_accuracy: 0.5538
# Epoch 201/450
# 4122/4122 [==============================] - 1s 304us/sample - loss: 0.5561 - categorical_accuracy: 0.9340 - val_loss: 2.0530 - val_categorical_accuracy: 0.5635
# Epoch 202/450
# 4122/4122 [==============================] - 1s 297us/sample - loss: 0.5311 - categorical_accuracy: 0.9457 - val_loss: 1.9912 - val_categorical_accuracy: 0.5769
# Epoch 203/450
# 4122/4122 [==============================] - 1s 299us/sample - loss: 0.5259 - categorical_accuracy: 0.9454 - val_loss: 2.0145 - val_categorical_accuracy: 0.5673
# Epoch 204/450
# 4122/4122 [==============================] - 1s 292us/sample - loss: 0.5319 - categorical_accuracy: 0.9408 - val_loss: 1.9864 - val_categorical_accuracy: 0.5731
# Epoch 205/450
# 4122/4122 [==============================] - 1s 312us/sample - loss: 0.5205 - categorical_accuracy: 0.9466 - val_loss: 1.9936 - val_categorical_accuracy: 0.5885
# Epoch 206/450
# 4122/4122 [==============================] - 1s 301us/sample - loss: 0.5171 - categorical_accuracy: 0.9461 - val_loss: 1.9943 - val_categorical_accuracy: 0.5865
# Epoch 207/450
# 4122/4122 [==============================] - 1s 303us/sample - loss: 0.5132 - categorical_accuracy: 0.9486 - val_loss: 1.9905 - val_categorical_accuracy: 0.5769
# Epoch 208/450
# 4122/4122 [==============================] - 1s 304us/sample - loss: 0.5183 - categorical_accuracy: 0.9464 - val_loss: 2.0020 - val_categorical_accuracy: 0.5788
# Epoch 209/450
# 4122/4122 [==============================] - 1s 295us/sample - loss: 0.5136 - categorical_accuracy: 0.9420 - val_loss: 1.9931 - val_categorical_accuracy: 0.5692
# Epoch 210/450
# 4122/4122 [==============================] - 1s 297us/sample - loss: 0.5062 - categorical_accuracy: 0.9459 - val_loss: 1.9726 - val_categorical_accuracy: 0.5692
# Epoch 211/450
# 4122/4122 [==============================] - 1s 296us/sample - loss: 0.5039 - categorical_accuracy: 0.9461 - val_loss: 1.9329 - val_categorical_accuracy: 0.5846
# Epoch 212/450
# 4122/4122 [==============================] - 1s 291us/sample - loss: 0.5029 - categorical_accuracy: 0.9493 - val_loss: 2.0180 - val_categorical_accuracy: 0.5673
# Epoch 213/450
# 4122/4122 [==============================] - 1s 307us/sample - loss: 0.5042 - categorical_accuracy: 0.9432 - val_loss: 2.0455 - val_categorical_accuracy: 0.5808
# Epoch 214/450
# 4122/4122 [==============================] - 1s 299us/sample - loss: 0.4994 - categorical_accuracy: 0.9454 - val_loss: 1.9567 - val_categorical_accuracy: 0.5827
# Epoch 215/450
# 4122/4122 [==============================] - 1s 308us/sample - loss: 0.4894 - categorical_accuracy: 0.9493 - val_loss: 1.9868 - val_categorical_accuracy: 0.5731
# Epoch 216/450
# 4122/4122 [==============================] - 1s 308us/sample - loss: 0.4902 - categorical_accuracy: 0.9488 - val_loss: 1.9900 - val_categorical_accuracy: 0.5654
# Epoch 217/450
# 4122/4122 [==============================] - 1s 298us/sample - loss: 0.4974 - categorical_accuracy: 0.9481 - val_loss: 1.9762 - val_categorical_accuracy: 0.5731
# Epoch 218/450
# 4122/4122 [==============================] - 1s 301us/sample - loss: 0.4785 - categorical_accuracy: 0.9546 - val_loss: 2.0216 - val_categorical_accuracy: 0.5731
# Epoch 219/450
# 4122/4122 [==============================] - 1s 301us/sample - loss: 0.4864 - categorical_accuracy: 0.9483 - val_loss: 1.9889 - val_categorical_accuracy: 0.5885
# Epoch 220/450
# 4122/4122 [==============================] - 1s 303us/sample - loss: 0.4759 - categorical_accuracy: 0.9515 - val_loss: 1.9698 - val_categorical_accuracy: 0.5827
# Epoch 221/450
# 4122/4122 [==============================] - 1s 312us/sample - loss: 0.4665 - categorical_accuracy: 0.9527 - val_loss: 1.9051 - val_categorical_accuracy: 0.6000
# Epoch 222/450
# 4122/4122 [==============================] - 1s 301us/sample - loss: 0.4578 - categorical_accuracy: 0.9568 - val_loss: 1.9535 - val_categorical_accuracy: 0.5865
# Epoch 223/450
# 4122/4122 [==============================] - 1s 300us/sample - loss: 0.4562 - categorical_accuracy: 0.9578 - val_loss: 1.9899 - val_categorical_accuracy: 0.5885
# Epoch 224/450
# 4122/4122 [==============================] - 1s 314us/sample - loss: 0.4671 - categorical_accuracy: 0.9493 - val_loss: 2.0524 - val_categorical_accuracy: 0.5712
# Epoch 225/450
# 4122/4122 [==============================] - 1s 303us/sample - loss: 0.4780 - categorical_accuracy: 0.9469 - val_loss: 2.0673 - val_categorical_accuracy: 0.5635
# Epoch 226/450
# 4122/4122 [==============================] - 1s 306us/sample - loss: 0.4796 - categorical_accuracy: 0.9413 - val_loss: 2.0370 - val_categorical_accuracy: 0.5750
# Epoch 227/450
# 4122/4122 [==============================] - 1s 295us/sample - loss: 0.4634 - categorical_accuracy: 0.9469 - val_loss: 2.0296 - val_categorical_accuracy: 0.5885
# Epoch 228/450
# 4122/4122 [==============================] - 1s 291us/sample - loss: 0.4644 - categorical_accuracy: 0.9454 - val_loss: 2.0233 - val_categorical_accuracy: 0.5885
# Epoch 229/450
# 4122/4122 [==============================] - 1s 307us/sample - loss: 0.4533 - categorical_accuracy: 0.9469 - val_loss: 2.0213 - val_categorical_accuracy: 0.5981
# Epoch 230/450
# 4122/4122 [==============================] - 1s 298us/sample - loss: 0.4521 - categorical_accuracy: 0.9503 - val_loss: 2.0365 - val_categorical_accuracy: 0.5923
# Epoch 231/450
# 4122/4122 [==============================] - 1s 303us/sample - loss: 0.4495 - categorical_accuracy: 0.9510 - val_loss: 2.0777 - val_categorical_accuracy: 0.5731
# Epoch 232/450
# 4122/4122 [==============================] - 1s 317us/sample - loss: 0.4345 - categorical_accuracy: 0.9561 - val_loss: 2.0010 - val_categorical_accuracy: 0.5750
# Epoch 233/450
# 4122/4122 [==============================] - 1s 314us/sample - loss: 0.4411 - categorical_accuracy: 0.9471 - val_loss: 2.0004 - val_categorical_accuracy: 0.5885
# Epoch 234/450
# 4122/4122 [==============================] - 1s 305us/sample - loss: 0.4402 - categorical_accuracy: 0.9505 - val_loss: 1.9171 - val_categorical_accuracy: 0.6000
# Epoch 235/450
# 4122/4122 [==============================] - 1s 296us/sample - loss: 0.4308 - categorical_accuracy: 0.9573 - val_loss: 1.9082 - val_categorical_accuracy: 0.5981
# Epoch 236/450
# 4122/4122 [==============================] - 1s 309us/sample - loss: 0.4413 - categorical_accuracy: 0.9466 - val_loss: 1.9501 - val_categorical_accuracy: 0.6000
# Epoch 237/450
# 4122/4122 [==============================] - 1s 310us/sample - loss: 0.4334 - categorical_accuracy: 0.9517 - val_loss: 1.9326 - val_categorical_accuracy: 0.5904
# Epoch 238/450
# 4122/4122 [==============================] - 1s 287us/sample - loss: 0.4239 - categorical_accuracy: 0.9500 - val_loss: 1.9459 - val_categorical_accuracy: 0.5827
# Epoch 239/450
# 4122/4122 [==============================] - 1s 302us/sample - loss: 0.4232 - categorical_accuracy: 0.9561 - val_loss: 1.9931 - val_categorical_accuracy: 0.5750
# Epoch 240/450
# 4122/4122 [==============================] - 1s 290us/sample - loss: 0.4201 - categorical_accuracy: 0.9556 - val_loss: 1.9604 - val_categorical_accuracy: 0.5808
# Epoch 241/450
# 4122/4122 [==============================] - 1s 293us/sample - loss: 0.4209 - categorical_accuracy: 0.9571 - val_loss: 1.9570 - val_categorical_accuracy: 0.5769
# Epoch 242/450
# 4122/4122 [==============================] - 1s 297us/sample - loss: 0.4313 - categorical_accuracy: 0.9495 - val_loss: 1.9397 - val_categorical_accuracy: 0.5692
# Epoch 243/450
# 4122/4122 [==============================] - 1s 305us/sample - loss: 0.4231 - categorical_accuracy: 0.9488 - val_loss: 1.9902 - val_categorical_accuracy: 0.5596
# Epoch 244/450
# 4122/4122 [==============================] - 1s 308us/sample - loss: 0.4168 - categorical_accuracy: 0.9529 - val_loss: 1.9399 - val_categorical_accuracy: 0.5904
# Epoch 245/450
# 4122/4122 [==============================] - 1s 296us/sample - loss: 0.4208 - categorical_accuracy: 0.9551 - val_loss: 1.9924 - val_categorical_accuracy: 0.5904
# Epoch 246/450
# 4122/4122 [==============================] - 1s 308us/sample - loss: 0.4138 - categorical_accuracy: 0.9517 - val_loss: 1.9812 - val_categorical_accuracy: 0.5788
# Epoch 247/450
# 4122/4122 [==============================] - 1s 309us/sample - loss: 0.4200 - categorical_accuracy: 0.9495 - val_loss: 1.9991 - val_categorical_accuracy: 0.5731
# Epoch 248/450
# 4122/4122 [==============================] - 1s 308us/sample - loss: 0.4118 - categorical_accuracy: 0.9488 - val_loss: 1.9725 - val_categorical_accuracy: 0.5808
# Epoch 249/450
# 4122/4122 [==============================] - 1s 303us/sample - loss: 0.4019 - categorical_accuracy: 0.9563 - val_loss: 1.9611 - val_categorical_accuracy: 0.5788
# Epoch 250/450
# 4122/4122 [==============================] - 1s 317us/sample - loss: 0.4018 - categorical_accuracy: 0.9551 - val_loss: 1.9623 - val_categorical_accuracy: 0.5846
# Epoch 251/450
# 4122/4122 [==============================] - 1s 303us/sample - loss: 0.3921 - categorical_accuracy: 0.9563 - val_loss: 1.9552 - val_categorical_accuracy: 0.5865
# Epoch 00251: early stopping
# 520/520 [==============================] - 1s 1ms/sample - loss: 1.9552 - categorical_accuracy: 0.5865
# [1.9551911500784067, 0.58653843]

# %% [markdown]
# ## Loss & Accuracy Curves

# %%
# Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
  
# Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['categorical_accuracy'],'r',linewidth=3.0)
plt.plot(history.history['val_categorical_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %% [markdown]
# # Performance

# %%
t0 = time.time()
image_labels_pred = model1.predict(images_test)
image_labels_pred = np.where(image_labels_pred > 0.5, 1, 0)
t1 = time.time()

total_prediction_time = t1-t0

# %%
y_true = np.argmax(image_labels_test,1) 
y_pred = np.argmax(image_labels_pred,1)

# %% [markdown]
# ## Confusion Matrix

# %%
cm =  pd.DataFrame(confusion_matrix(y_true, y_pred), 
                                 index = label_names_array, 
                                 columns = label_names_array)

plt.figure(figsize=[8,6])
sn.heatmap(cm, annot=True,cmap='Blues', fmt='g')

# %% [markdown]
# ## Classification Metrics

# %%
target_names = label_names_array
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         Sell       0.15      0.16      0.16        74
#          Buy       0.26      0.25      0.25        73
#         Hold       0.73      0.73      0.73       373
#
#     accuracy                           0.58       520
#    macro avg       0.38      0.38      0.38       520
# weighted avg       0.58      0.58      0.58       520

# %% [markdown]
# ## Time spent

# %%
total_training_time = sum(time_callback.times)
print("Time spent on entire model training: {:4f} seconds".format(total_training_time))
# Out:
# Time spent on entire model training: 296.074059 seconds

# %% [markdown]
# ## Financial Evaluation, Save predicton data in given format

# %%
#custom library
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/CNN/evaluation')
import financial_evaluation

# %%
# Create Signals from numbers here 
Signals = y_pred

prediction = pd.DataFrame(test_prices, columns = [VarName])
prediction['Signals'] = Signals
prediction['Signals'].loc[prediction['Signals'] == 0] = "Sell"
prediction['Signals'].loc[prediction['Signals'] == 1] = "Buy"
prediction['Signals'].loc[prediction['Signals'] == 2] = "Hold"
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#save results
prediction.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/PredForFinEval.csv")

# %%
fin_res = financial_evaluation.financial_evaluation(VarName, test_prices, prediction['Signals'])
print("Annualized return is {}, cumulative return is {} and number of trades are {}.".format(fin_res['annualized_return'], fin_res['cumulative_return'], fin_res['all_trades']))
# Out:
# Annualized return is [0.07712554], cumulative return is [0.16019944] and number of trades are 74.

# %% [markdown]
# ## Save Model

# %%
model1.save('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/model.h5")

# %% [markdown]
# ## Save true and pred

# %%
TruePred = pd.DataFrame(y_true, columns = [VarName])
TruePred['Prediction'] = y_pred
TruePred.to_csv('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/True&Pred.csv")

# %% [markdown]
# ## Save Classification Metrics &  Save Times

# %%
Acc = np.float(accuracy_score(y_true=y_true, y_pred=y_pred))
#F1 = np.float(f1_score(y_true = y_true, y_pred = y_pred, average = 'macro'))
Prec = np.float(precision_score(y_true=y_true, y_pred=y_pred, average = 'macro'))
Recall = np.float(recall_score(y_true=y_true, y_pred=y_pred, average = 'macro'))

F1 = 2 * (Prec * Recall) / (Prec + Recall)

print(Acc, F1, Prec, Recall)
# Out:
# 0.5826923076923077 0.381207428155888 0.38220640143941226 0.3802136632942024

# %%
np.savez('drive/My Drive/Colab Notebooks/CNN/Results/' + Test + "/" + Version[1:-1] + "/" + VarName + "/Time&ClassificationEval.npz",
         accuracy = Acc,
         MacF1 = F1,
         MacPrecision = Prec,
         MacRecall = Recall,
         TrainTime = np.float(total_training_time),
         PredTime = np.float(total_prediction_time)
        )
